# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import time
import multiprocessing
from multiprocessing import Pool
import string
#defining the function to remove punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import re
import ipyplot

import os
os.environ["CUDA_VISIBLE_DEVICES"]='2'   # specify which GPU(s) to be used

# %%
def remove_whitespace(text):
    return text.strip()

def lowering(text):
    return text.lower()

def remove_numbers(text):
    return re.sub(r'\d+', '', text)

def remove_punctuation(text):
    return "".join([i for i in text if i not in string.punctuation])

def remove_stopword(text):
    tokens = word_tokenize(text)
    english_stopwords = stopwords.words('english')
    tokens_wo_stopwords = [t for t in tokens if t not in english_stopwords]
    return " ".join(tokens_wo_stopwords)

def stem_words(text):
    word_tokens = word_tokenize(text)
    stems = [stemmer.stem(word) for word in word_tokens]
    return " ".join(stems)
 
def text_preprocessing(text):
    text_1 = remove_whitespace(text)
    text_2 = lowering(text_1)
    text_3 = remove_numbers(text_2)
    text_4 = remove_punctuation(text_3)
    text_5 = remove_stopword(text_4)
    return text_5

# %% [markdown]
# # CC12M vs LAION

# %% [markdown]
# ## Processing CC12M

# %%
path_dir_CC12M = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/Open_clip_training/src/data/cc12m/'):
    for filename in filenames:
        if filename.split('.')[-1] == 'parquet':
            path_dir_CC12M.append(os.path.join(dirname, filename))

# %%
def collect_cc12M_data(path):
    df_cc12M = pd.read_parquet(path)
    N_cc12M = len(df_cc12M)  # number of samples from one parquet of laion 
    small_cc12M = df_cc12M.sample(n=N_cc12M)

    cc12M_texts_array = small_cc12M["caption"].iloc[0:N_cc12M].values
    return cc12M_texts_array.tolist()

# %%
## cal feature info 
start_time = time.time()

processed_CC12M_text = []
for i in range(len(path_dir_CC12M)):
    cc12M_texts = collect_cc12M_data(path_dir_CC12M[i])
    
    cc12M_texts_re = []
    for val in cc12M_texts:
        if val != None :
            cc12M_texts_re.append(val)
    processed_CC12M_text.extend(cc12M_texts_re)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 156.33391046524048 seconds ---

# %%
print(len(processed_CC12M_text))
processed_CC12M_text
# Out:
# 12423374
# ['A sign with yellow lights in Germany',
#  'Man On The Moon Art Print',
#  'Sea Island Wedding, Cloister Chapel, Black Banks Terrace, The Decisive Moment Photography',
#  '<PERSON> Style Sculptural Draped Plaster Floor Lamps - a Pair For Sale - Image 9 of 13',
#  'Gru the kitten, thrown out of a moving vehicle',
#  'Poppy Flower Is One Line Art. Vector abstract contour drawing floral in a Trendy Minimalist Style.',
#  'Otter playing at the Lehigh Valley Zoo',
#  "National Service Of Thanksgiving To Celebrate The Queen's 90th Birthday : News Photo",
#  'Fell off the G Wagon T Shirt Funny On Off the Wagon Short-Sleeve Unisex T-Shirt',
#  'Ventura - the avant-garde brand of Swiss watches | News',
#  'Cornfield Painting - Passing The Time by <PERSON>',
#  'The open space in a Japanese garden can sometimes make people used to Western gardening philosophy feel uneasy. Once they start to understand that the space is as important of an element as any other they can see the value of emptiness. Garden Oasis, Garden Pond, Easy Garden, Home And Garden, Kingston Lacy, Japanese Garden Design, Japanese Gardens, Garden Screening, Home Landscaping',
#  'Wholesale wedding pants suits for brides for sale - Group buy Gorgeous Green Black Embroidery Mother Of The Bride Pant Suits Plus Size 4 3 Sleeve Chiffon Jewel Neck For Wedding Mother Groom Gowns',
#  'April 25 political cartoon: The rope line to Democracy',
#  'This Montessori-inspired caves unit includes ideas for learning about cave formations, growing crystals, creating cave art, building a cave scene, and doing cave-inspired math activities. || Gift of Curiosity',
#  '<PERSON> in Clove Curtains Office Curtain Panel and Some Gold Feathers. Behr Castle Path and the dark board and batten is Sherwin Williams Urbane Bronze. Office Curtains, Drapes Curtains, Curtain Panels, Curtains Grey Walls, Grey Living Room Curtains, Pattern Curtains, Dining Room Curtains, French Curtains, Brown Curtains',
#  'The Elephant Bracelet - Black Smooth',
#  'The hub of the house, the open kitchen is generously scaled.',
#  'A river royalty free illustration',
#  'Ajar first layer of the picture, a blank copy space with folded corner, bed linen folded corner template',
#  "<PERSON> ``The Older I Get, The Better I Was'' T-Shirt",
#  'Motor boat for rent Split at the best price',
#  '<PERSON> bridal wedding portrait at the beach of Aruba',
#  'The cheery spring results of a Fall daffodil planting!',
#  "Say ``I Love You'' with Beautiful Fragrant Flowers presented for Valentine's Day and a Gift selection Box of hand-made Chocolate Truffles from the Award-winning NZ Bennetts of Mangawhai. Tell us your personal Valentine's Day Message or Poem and we'll write it inside a Gift Card. Delivered throughout Auckland.",
#  'Kendall College Scallops by <PERSON> of the Chicago Chic.',
#  "Birendranagar aims to be the country's first 'cycle city'",
#  'Mix All Your Ingredients Together',
#  'Bathing Beauties Do Beach Sculpture Pose! Vintage Reprint Of An Old Photo Bathing Beauties Do Beach Sculpture Pose! Vintage Reprint Of An Old Photo Here is a neat collectible featuring three b Vintage Pictures, Old Pictures, Vintage Images, Old Photos, 1920s Photos, Vintage Love, Vintage Beauty, <PERSON>, Vintage Items',
#  'Chocolate Orange Gingerbread Cookies | The <PERSON>',
#  "``Castle's tower hidden in the woods'' stock image",
#  'Animals pattern on a brown card template vector',
#  'A line graph showing Earnings Before Interest, Tax, Depreciation and Amortization (EBITDA) from the year 1997 to 2016.',
#  'Connect the other end of the blue wire to the switch as shown.',
#  'Be thankful each and everyday. Chakra Meditation, Kundalini Yoga, Mindfulness Meditation, Chakra Healing, Meditation Rooms, Spiritual Symbols, Spiritual Health, Yoga Asanas Names, Pure Yoga',
#  "FILE - This Nov. 5, 1975 file photo shows <PERSON>, creator of the comic strip `` <PERSON>,'' looking up from some her strips in her studio in her apartment in Chicago. Tribune Media Services, which owns <PERSON>, said Thursday, Dec. 9, 2010, it will end the feature's newspaper syndication",
#  'Are you in the midst of a kitchen renovation? Or thinking of starting one? Take our advice and read the 20 Commandments of a Kitchen Renovation!',
#  'Stock Vector: 100 white puzzles pieces arranged in a square. Jigsaw Puzzle template ready for print. Cutting guidelines isolated on white.',
#  'Style & Apply carries a huge amount of love wall decals, including this cats in love wall sticker. Decorating Your Home, Interior Decorating, Wall Tattoo, Tattoo Cat, Cat Stickers, Love Wall, Empty Wall, Cat Wall, Paint Designs',
#  '<PERSON>, Silver Oaks Chateau Wedding, Bride Walking Down the Aisle',
#  'The lion can be seen charging at the toddler. Pic: YouTube',
#  'Electrical Objects: A big pile of colorful plastic cables',
#  'Crowd fires up <PERSON> credits crowd after a ride of 89 points at the Range Days Rodeo',
#  'A bowl filled with grilled vegetables tossed with basil pesto.',
#  'Cottage standing on a rock. Finishing the house with a stone. Small cottage. A natural stone for decorating the territory of the house.',
#  'A pair of 19th century candelabra in bronze and alabaster.',
#  'Fidget Toys for children who have a difficult time focusing their attention. These can be squeezed or twisted.',
#  'The Mean Grinch Christmas Canvas LS T-Shirt',
#  'Close up of a dirty motorcycle chain with a motor oil. On a wheel and metal parts. Abstract background stock images',
#  'A pink flower blooming from a cactus',
#  "An open book lies flat on a table with the page opened to a poem as red roses lie on the book's page.",
#  'Concept of lies and hypocrisy with two men shaking hands with a smile while being armed and ready to kill each other.',
#  'The main entrance to the new 41 room Spectator Hotel. The entrance door pulls were custom made for the project.',
#  'The statue of <PERSON> bedecked with flowers, shirts and messages of support - July 2007',
#  "Full Size of The North Face <PERSON>'s Recon Backpack North Face Recon Review 2018 North Face Borealis Outdoor Gear The North Face Recon",
#  'All About Camping 1962 - Drawing by <PERSON>',
#  'A bathroom at Ikebana Apartment',
#  'A compact apartment that bucks the trend of minimalism and embraces a comfortable homey aesthetic that showcases the personality of the resident.',
#  'Maternity Sibling Photography | Soft, Indoor, Natural Light | Paint the Moon Photoshop Actions',
#  'No entry sign : Do not enter sign',
#  'Painting Bird House Online Shopping - 3d room wallpaper on a wall custom photo mural Hand-painted bird idyllic background wall wallpaper for walls 3 d',
#  "Creation of Don't Bite The Hand That Feeds You: Step 13",
#  'Bowl and a half Sink Kit',
#  'A stack of three chocolate brownies on a plate',
#  'Other Man Cave Garage Fresh On Other Within Room Envy A Briarcliff Becomes An Upscale Atlanta 10 Man Cave Garage',
#  'Acacia trees in the Namib desert located in Namibia Africa',
#  'A view of Brno Cathedral and skyline at night, Brno, Czech Republic, Europe - February 22nd 2018 stock images',
#  '<PERSON>--Photo displayed on a wall',
#  'Photo of a deserted bedroom with single bed and <PERSON> iconography',
#  'View from the Petronas Twin Towers in Kuala Lumpur',
#  '<PERSON> <PERSON> talks to fourth grade students from Olinda Elementary School at the Rosie the Riveter Memorial during an Every Kid In a Park field trip.',
#  'A no-bake Oreo cheesecake topped with swirls of whipped cream and Oreos, on a white cake stand.',
#  'Add a touch of everyday luxury to your handbag collection with the Louis Vuitton Batignolles Vertical handbag.',
#  "Two cars shown in a video about to crash at the exit of a roundabout at Ingleburn. They were in separate lanes and it's caused confusion as to who was at fault.",
#  'Hands with gloves disinfecting a car door with rag and atomizer inside',
#  'Pattern with golden dots on a black background',
#  'The North Face Youth Sprout Backpack',
#  'Royal Caribbean Oasis of the Seas cruise ship quiet spot',
#  'Bride getting dress in <PERSON> wedding dress at the Park Chateau.',
#  "A poster advertising U.S. President <PERSON>'s speech at the Krasinski Square on July 6, in Warsaw, Poland, July 4, 2017.",
#  "Model <PERSON> attends the premiere of Walt Disney Pictures and Lucasfilm's Star Wars: The Force Awakens in Hollywood, Calif. on December 14, 2015.",
#  'Disney Princess Keys to the Kingdom Tiara',
#  'Round Neck T-shirts Unique Summer Tops Shirt Long Sleeve for Men New Design 100% Cotton Miles On The Moon Street Tee Shirts Miles On The Moon grey',
#  '<PERSON> Explains The Differences Between Dealing With Welsh And Irish Players',
#  'Vista 18: Rent the Harbour Room for your next event',
#  'Southwest Airlines logo seen displayed on a smart phone',
#  'Portrait of the 1890 Supreme Court- <PERSON>-Photographic Print displayed on a wall',
#  'Statue of writer <PERSON> sitting in the middle of the monument dedicated to him',
#  "Actor <PERSON> attends the Centerpiece Gala Premiere of Dog Eat Dog Films' ``Where to Invade Next'' during AFI FEST 2015 presented by Audi at the Egyptian Theatre on November 2015 in. Get premium, high resolution news photos at Getty Images Glamour Movie, Dog Films, Egyptian Theater, <PERSON>, <PERSON>, <PERSON>, Hollywood Actor, <PERSON>, Actors & Actresses",
#  'Rustic Boho Bedroom DIY | by Rouse the Room',
#  '<PERSON> with her death grip on the baguette.',
#  'Fir tree branches, pine cones and dried orange fruits, cinnamon stick isolated on a white background',
#  'Cushion Amethyst Ring - Gardens of the Sun Jewelry',
#  'A General <PERSON> toy that resembles <PERSON>',
#  'Pink Flowers on a Vine',
#  'Proud Son Of The Graduate Shirt Black T-Shirt Front',
#  'Letter S from the complete set of characters of the font. Symbol of the Latin alphabet and English language. Copper and brass fantasy mechanical steampunk royalty free illustration',
#  'About the Swim England Water Polo National Age Group Championships',
#  "Swansea City's <PERSON> and Fulham's <PERSON> battle for the ball during the Sky Bet Championship match at Craven Cottage London",
#  'Los Angeles Lakers guard <PERSON> gestures to fans as he walks off of the court after a 2006 NBA basketball game against the San Antonio Spurs in San Antonio. The final NBA All-Star Game for <PERSON> and the first to be staged outside the U.S. is in Toronto, the city that staged the first NBA game 70 years ago and is so enthusiastic for basketball now that it could no longer be ignored no matter what the thermometer says. (AP Photo/ <PERSON>, File)',
#  'The Striding Lion Of Ishtar Gate Classic T-Shirt',
#  'The roomy king bedroom accommodates a desk & large closets -extra blankets &crib',
#  'Diamond of the Forest Full Zip Hoodie',
#  'Sculpture in the Elephanta Caves on Elephanta Island',
#  "Shellfish Cow Restaurant & Bar: That's what I call a birthday lunch!",
#  'Science hand drawn vector doodles illustration. Poster design. Many elements and objects cartoon background. Sketchy funny picture. All items are separated royalty free illustration',
#  'Credits to whoever made this fan art <PERSON>, Pokemon Ships, Pokemon Comics, Pokemon Memes, Cute Pokemon, <PERSON>, Pikachu Drawing, <PERSON>, Masters',
#  'New kids on the block poster in 2020',
#  "A convoy of 100 cars drove past to celebrate <PERSON>'s third birthday party",
#  'Brew Master Sam tasting beer from the barrel at the Sawdust City facility in Downtown Gravenhurst',
#  'Shetland Pony Club Adopt a Pony',
#  'Look <PERSON> in this Off The Shoulder Blouse',
#  'Varadero Beach: Sunset from the International',
#  '<PERSON> in Front of the Mall 2486.64 Kb',
#  'Ghost Lake, <PERSON>, Alberta, Canada - Ghost Dam, Imagine that on a rainy day.',
#  'Yacht on the blue water of the Caribbean',
#  'In the portable aircraft, the businessman rushed out of the trap. royalty free illustration',
#  'The Hawk and Dove Public House',
#  'Girl massage therapist in the salon. Cute girl masseur in the salon. Table, bedside table with oils, a pot of flowers. Cartoon flat style. Vector isolated stock illustration',
#  'A Grade Expository Student Writing Sample - Empowering Writers Expository Essay Examples, Expository Writing, Empowering Writers, Research Projects, Free Resume, Curriculum, Sample Resume, Facts, Student',
#  "There are people who didn't listen to their teacher's grammar lessons and they're driving me nuts flower shirt",
#  'Photo courtesy of, copyright of <PERSON>, a San Diego, <PERSON>.',
#  'Red and Grey Squirrels Grey squirrels were introduced from America in the early 1900s.',
#  'Singer <PERSON> performs onstage during the BET Celebration of Gospel 2013 last month at Orpheum Theatre in Los Angeles.',
#  'Hand drawn typography lettering phrase December on the blue background. Fun brush ink calligraphy inscription for winter royalty free illustration',
#  'Picture of: kitchen chandelier for a small kitchen',
#  'Red Hot Chili Peppers The Getaway Flea Rock Official Tee T-Shirt Mens Unisex (Small)',
#  'Spinosaurus are the only known dinosaur to have adapted to life in water.',
#  'Students of University of Kashmir performing a folk dance at the 28th North Zone Youth Festival at Guru Nanak Dev University in Amritsar on Wednesday.',
#  "Captive breeding employed to rescue Chile's national animal, a shy deer",
#  'Cute girl standing on a rock in the middle of the river stock footage',
#  'The wedding of <PERSON> and Sage & Heart Photography 22',
#  '(Photo)The area (blue frame) in the 20mm wide angle image is zoomed in. The image equivalent to 1000mm in focal length shows the vehicle registration plate of a car (red frame) parked 1km away.',
#  'The Magical Dragon - Girl with Curly Brown Hair Riding Purple Dragon - Art Print Cartoon Drawings, My Drawings, <PERSON>, Human Figure Drawing, Cute Dragons, How To Draw Hair, Girl Cartoon, Fine Art Prints, Painting Prints',
#  'Central Place Theory -- <PERSON> Seeks to explain the number, size and location of human settlements in an urban system; settlements simply function as central places providing services to surrounding areas (hinterlands); organized by hexagons to eliminate unserved or overlapping market areas.',
#  'Bride and dad walk up the aisle at The Mill Barns wedding',
#  "Stock image of 'Welsh Terrier on a summer meadow'",
#  'Black and white drawing of captain smoking a pipe with sea symbols behind his back. royalty free illustration',
#  'A Tale of Three Coins: The Ongoing Saga of BTC, BCH and BSV',
#  'Cinnamon stick poking out of a drink',
#  'Color Psychology For Kids Bedrooms kids bedrooms Fantastic Color Psychology Tips For Kids Bedrooms that you Must Know 1 3',
#  "<PERSON> and <PERSON>'s apartment in NY back to the market.",
#  'Bathroom Wall Art: Have A Nice Poop Wall Art (Wood Frame Ready To Hang)',
#  'By the Light of the Silvery Sea',
#  'A superb complement to a contemporary interior, this coffee table is part of the <PERSON> collection, designed by <PERSON> and introduced at Milan Design Week in 2017. It is characterized by a perfectly cylindrical shape. The base in wood has a',
#  "The Diner: a gift from SL's 16th anniversary",
#  "Stock image of 'A night view of Pienza cathedral, near Siena, Tuscany, Italy'",
#  'Elegant Pottery Barn White <PERSON> Simply Kid AU Glove Delivery Plain Desk Bedding Dish Duvet Tip Crib',
#  'Watching the penguins fly underwater',
#  '<PERSON> shown here with a tight set up. Suit with vest in a nice charcoal blue, mixing up patterns in his tie and poof style pocket square.',
#  'Bathymetric Maps Like a topo map Represents depth BELOW sea rather than height above Numbers low near sea level, get higher the deeper you go',
#  'The Quest for the Perfect Homemade Pizza Lead Us to the Blackstone Pizza Oven-6',
#  'Lapping Everybody on the Couch Poster',
#  '<PERSON>, wearing a black suit jacket, a light purple dress shirt, and a green tie with black horizontal and vertical stripes, speaks into a silver microphone with a black handle. He sits in front of a sky blue background with horizontal dark lines.',
#  'Silhouette of a flock of blackbird flying through a surreal evening sky with a fiery sun',
#  'Maasai Education and Community Support Kenya-The Blonde Maasai - <PERSON>',
#  'Yoga vacation guests use the main yoga hall for satsangs and yoga classes.',
#  'A bed or beds in a room at Best Western Plus Gran Hotel Centro Historico',
#  'Zucchini, Mint, and Goat Cheese Couscous Casserole ... treat your family this cheesy, delicious, and healthy vegetarian casserole recipe tonight! | Hello Little Home',
#  'Vintage cars parading at the Parkes Elvis Festival, Australia',
#  "Lifetime's 8-foot wide Outdoor Storage Sheds are the perfect solution to your storage needs. Built with durable, dual-wall high-density polyethylene, our sheds are steel-reinforced and low-maintenance. With various features including shatter proof windows, skylights, adjustable shelving, and much more, a Lifetime Shed is the perfect addition to your backyard. photo",
#  'The house stands on the drawings and next to it there is a man in a business suit with a drawing in his hands. Real property , an isomeric image stock illustration',
#  "Plant a tree on Valentine's Day, events on Valentine's Day in Tirana, events in Tirana, Valentine's Day in Tirana, activities in Tirana",
#  'The Boat House - other aspect of the bedroom',
#  'Beautiful Handmade Paper Craft Inspired by The Little Prince children& book. Beautiful Handmade Paper Craft Inspired by The Little Prince childrens book. Little Prince Party, The Little Prince, Craft Paper Design, Design Crafts, Paper Crafts For Kids, Book Crafts, Craft Books, Handmade Books, Handmade Crafts',
#  '<PERSON>, <PERSON> at the Freemasons at Wiswell with front of house manager, Aga',
#  'New cars require more skills than this old Trabant needed.',
#  'Life in the soil Science For Kids, Science And Nature, Spring Web, Soil And Water Conservation, Earthworms, Science Fair Projects, Natural History, Ecology, Book Illustration',
#  'Home Elements And Style Medium size Deck Building Materials And Construction Basics Supplies A Step By . Deck Building Ideas Plans. Building A Deck Frame Small.',
#  'The Mulberry tree played a significant role in Pyramus and Thisbe as they planned to meet under the tree to declare their love for each other. When he kills himself, his blood splashes on the white mulberries, turning them dark. Mulberry Fruit, Paper Mulberry, Mulberry Tree, Trees And Shrubs, Trees To Plant, Permaculture, Fast Growing Shade Trees, Short Trees, <PERSON>',
#  'Climb Every Mountain - Mt. Hamburger Graphic T-Shirt Dress',
#  'Soldiers, Mendes from Timor Leste Defence Force and <PERSON> from the New Zealand Army on the Esplanade.',
#  'Elementary Suggestions How To Draw A Anime Hero 2019',
#  'Reserved Resident Parking at The Adelaide, Orlando, FL, 32821',
#  'Distressed Fabric Close up A Level Textiles, Textile Fabrics, Textile Art, Visual Diary, Exotic, Surface, Flaws, Trousers, Cosplay',
#  'The glass and steel facade of 270 Park Avenue.',
#  'The building where the hostel is located',
#  'A photo of a bride and groom dancing at a Boho wedding.',
#  'Cocktail Shaker and a Cocktail Glasses icon. Elements of disco and night life multi colored icons. Premium quality graphic design. Icon. Simple icon for royalty free illustration',
#  '<PERSON> Photo - LOS ANGELES - MAY 3 <PERSON> at the 2019 Creative Daytime Emmy Awards at Pasadena Convention Center on May 3 2019 in Pasadena CA',
#  'American guitarist <PERSON> performing at the Marquee Club London 11th May 1973',
#  'Numbers in circles refer to the Registered Plan that the mapped information was taken from.',
#  "Premiere Of Netflix's ``The Christmas Chronicles'' - Arrivals : News Photo",
#  'Disney Cinderella Music Box Plays A Dream Is A Wish Your Heart Makes by The Bradford Exchange',
#  "At one point in the mansion's history, the property was sold to an oil company, to be used as the site for a gas station!! It was at this time the community banded together and saved the mansion from demolition in the 1950's. Preservation efforts continued through the 1960's and up to this very day!",
#  '<PERSON> speaks at the meeting.',
#  'Picture of the city of Paris from the Arc de Triomphe showing the Eiffel Tower and two main streets with the sunset in the background.',
#  'Branded jewellery is the new darling of investors',
#  '21 Video Game Ads And Packages That Tell The Painful Truth',
#  'Rare behind the scenes pic with <PERSON> and <PERSON>. Check out the vest. 70s Tv Shows, Great Tv Shows, 1980s Tv, 1970s, <PERSON>, <PERSON>, Los Angeles Police Department, Handsome Actors, Old Tv',
#  "Trees Adventure, Belgrave (I want to do this so badly. Looks like it'd be a blast. Doesn't necessarily have to be here though but, it's a great depiction of a tree couse. Melbourne Activities, Tree Rope, Outdoor Play Equipment, Jungle Gym, Holiday Activities, Outdoor Fun, Day Trips, Places To Go, Backyard",
#  'Large metal silver star, hanging on a jute string',
#  'Philippine language relations in a map Easter Island, Pinoy, Philippines, Quotations, Visayas, Mindanao, Motivation, Sibling, Madagascar',
#  'The Art of Dress: Fashion in England: Ms. <PERSON>',
#  'The Feather in Vintage Tan',
#  '<PERSON>, The First Lady Of Luxury Real Estate',
#  'Horsemen section of west frieze from the Elgin Marbles of Parthenon in the Acropolis museum.',
#  'A bed or beds in a room at <PERSON>',
#  "<PERSON> ``The Big Fish'' <PERSON> Poster",
#  "Ambler Farm is just one of the more than 30 submissions for the ``How Sweet It Is In Wilton'' Gingerbread Contest going on now at Wilton Library. The community is invited to pick its favorite, along with three judges who will be choosing winners in three categories out of two groups, for a total of seven entries winning Wilton Chamber of Commerce gift certificates. Voting ends Dec. 18 with winners announced Dec. 19 at 4 p.m. Photo: Contributed Photo / Contributed Photo / Norwalk Hour contributed",
#  "<PERSON>'s Craft Pizza & Pub: ``Fire in the Hole'' Deep-Dish Sicilian Pizza",
#  'Short coffin nails | fall nail art. Are you looking for short coffin acrylic nail design that are excellent for this season? See our collection full of cute short coffin acrylic nail design ideas and get inspired!',
#  'The master bathroom is nearly finished.',
#  'A Policeman Has My Heart Love Sign Cut File SVG DXF PNG PDF example image 1',
#  'Woman looking the pink sunset stock illustration',
#  'Bathrooms walk in tiled shower designs small ideas no door without tile images large with bench alluring',
#  'Clip <PERSON> USB power Led desk lamp Flexible Table Lamp bedside lamp Book light for the bedroom living room home decoration',
#  'A child covers his head against the strong sunlight. The heatwave in Hong Kong reached 34 degrees in the afternoon. 18 July 2005',
#  'Rave to the Grave Classic T-Shirt',
#  'Objective: To make the girl invisible.',
#  'And the Phoenix will Rise Stained Glass Art Print',
#  'Eye open At The Close Hallows Tattoo',
#  'The Biker Jeans - Black Iron Flexi V2 Armoured Riding Jeans',
#  'View an exquisite selection of pure gold jewellery from Tanishq Gold Earrings Designs, Necklace Designs, Ring Designs, Gold Finger Rings, Gold Rings, Gold Jewelry, Jewelery, Gold Chain Design, Pakistani Jewelry',
#  'The Bridal Bouquet near Finsbury Park in London',
#  'Marines from Lima Battery, 3rd Battalion, 10th Marine Regiment embark on a patrol in an M998 High-Mobility Multipurpose Wheeled Vehicle (HMMWV). The Marines and sailors of the 26th Marine Expeditionary Unit (MEU) during Operation JOINT GUARDIAN are helping to enforce the implementation of the military technical agreement and to provide peace and stability to Kosovo',
#  'Ron Hansen Brand & Label Design Co. is a full-service design and marketing company',
#  'Golf club badges logos and labels for any use, On a white background',
#  'Istanbul-based creative firm Make Some Design has come up with a Web Lovers Edition of Monopoly featuring the most popular Internet companies. Retro Arcade Games, Monopoly Board, Monopoly Game, Google Plus, <PERSON>, Star Wars, Back To The Future, Just Kidding, Service Design',
#  '<PERSON>, The holy saint <PERSON>, 1995 Mixed Media Collage, Art Essay, Alternative Art, Lowbrow Art, Pop Surrealism, Visionary Art, Outsider Art, Surreal Art, <PERSON>',
#  'The second table was immediately much darker.',
#  'Which is The Best Car To Learn To Drive In?',
#  'Gleam - Glow-in-the-Dark Garden Pebbles',
#  'Dining room that led to sun room',
#  "<PERSON> and <PERSON> attend the European premiere of 'Dumbo' at The Curzon Mayfair on March 21 2019 in London England",
#  "Avondale, meaning ``valley of the waters'', is the ideal name for this prow and cedar home design by Linwood Homes. It is a much favored design for lakeside living. Log Cabin Floor Plans, Log Home Plans, Small Log Cabin, Log Cabin Homes, Small Cabins, Log Cabins, Cottage Homes, <PERSON>, Linwood Homes",
#  'King Sized Bed in the Master',
#  '10 Cute Dog Breeds That Are a Bad Choice for <PERSON>',
#  'Hills and fields along the Trans-Siberian.',
#  'Interior of a public bus transport',
#  "Round Lake Park police officer <PERSON> prepares a Navy surplus, Arctic Circle-grade snowmobile the department is rolling out to handle blizzard conditions. In the background is an Army surplus Hummer at Round Lake Park's disposal.",
#  'Walkers and dogs at the start at Wistaston Memorial Hall',
#  'A bed or beds in a room at Ravine Lodge',
#  'French elegance exudes from this circa 1800 chocolate pot with original wooden handle offered by Hanes & Ruskin Antiques, Old Lyme, Conn.',
#  'CRS-15: The Graphic Version of the Logo!',
#  '<PERSON> celebrates a goal during the UEFA Champions League Quarter Final second leg match between Juventus and Ajax at Allianz Stadium on April 16, 2019 in Turin, Italy.',
#  'Dreaming of the Day Top',
#  'Maze game for children: fairytales theme. Help Red Riding Hood find way to house. Maze children game: help the Red Riding Hood go through the forest labyrinth stock illustration',
#  'Top 35 countries to be a girl',
#  'Quotes About Lights In The Dark #917199',
#  'Queen I Want it All Graphic T-Shirt',
#  'Persepolis tee - Baseball T-Shirt',
#  'The building in which the lodge is located',
#  'This particular part of the golf course is a popular place for weddings',
#  '373934330179 the best coupon codes <PERSON> t shirts',
#  'CWC trophy at the Adelaide Oval',
#  'Womens Many V-Neck Dress With 3 4-Length Sleeves School Rag To Be Distributed Around The World New',
#  'Since v2 posted a picture of her artwork I thought if post mine! This is the animatronics as human girls. ~v1',
#  'Zodiac sign Sagittarius with snowflakes. Zodiac sign Sagittarius on a blue starry sky, hand drawn vector illustration in winter motif with stylized stars and royalty free illustration',
#  'Crop flared jeans - Reverse of the article',
#  'Galvanized and milk glass dishes for making a DIY Christmas centerpiece on a budget',
#  'Cute candy heart lollipop cartoon character having a box. Vector illustration stock illustration',
#  'All Might Tempered Glass iPhone Case',
#  '1987 Ford F150 (CC-941147) for sale in Online, No state',
#  "15 healthy and weight loss soups: zucchini curried soup recipe by a fork's tale",
#  'Stylized businessman target market, A specific group of consumers at which a company aims its products and service royalty free illustration',
#  'Enjoy The Beauty of Simien Mountains',
#  'Photo of a healthy noodle bowl with grilled chicken.',
#  'Consider these when selling or buying a house with asbestos or meth',
#  'That EGO Power Self-Propelled Mower Is Finally Mine',
#  'First look of the bride and groom at Hotel Monaco Philadelphia',
#  '<PERSON> performs during a concert as part of the Twins of Evil Tour at the U.S. Cellular Center in Cedar Rapids on Sa',
#  'Watercolor vector frame of flowers and branches <PERSON> isolated on a white background.',
#  'Winter frosty trees and old snowy bridge in the winter park',
#  'Vineyard Evensong The Fifth Sunday after Epiphany',
#  'A bed or beds in a room at Church Bay cabin: sunny, great views',
#  'Bible Verse Alphabet Q Psalms 105:40 The people asked, and he brought quails, and satisfied them with the bread of heaven.',
#  'Red houses on the beach stock images',
#  'Spare Keys: Reflections on a Kidney Transplant',
#  'IMAGE: Ramshackle stall at the famous flea market in Budapest',
#  '<PERSON>, <PERSON>, <PERSON> film Valley of the Dolls <PERSON>, <PERSON>, Movie Market, Old Movie Stars, Valley Of The Dolls, Song One, Old Hollywood, Hollywood Style, Classic Hollywood',
#  'Artisan Cheese Festival tour 2018, it started with a blind tasting of 3 yogurts, 3 fresh cheeses, and 3 aged cheeses and learned how to identify between different animal milks used in the products with <PERSON>',
#  '<PERSON> Becomes the Investor of the Magnus Art App',
#  'Korean star with a double opening T diamond bracelet opening titanium woman 18K gold bracelet accessories',
#  '10 Useful Tips for siblings sharing a room',
#  'Seek ye the Lord while He may be found Art',
#  "The World's Best Photos of carnation and ikebana White Carnation, Carnations, World Best Photos, Ikebana, Flower Art, Floral Arrangements, Glass Vase, Floral Design, Flowers",
#  'View from the garden at Broughton Bank Cottage',
#  'First attempt at a beard. 8 weeks in needing advice',
#  "<PERSON>'s High Falls is in the Little River Canyon",
#  'Nike The Nike Polo Tie Dye Shirt Multicolor',
#  'Chinese New Year food for good luck: oranges, whole fish, long noodles and more for Lunar New Year. Chinese New Year Food, Learn Chinese, Learn Cantonese, Noodles And More, Lucky Food, New Recipes, Cooking Recipes, New Years Traditions, Year Of The Monkey',
#  "<PERSON> training for 'The Sisterhood Challenge' on the River Thames, London, Britain - 01 Aug 2007. The 21-mile row on 25 August starts from Dover and finishes at Cap Gris Nez, near Calais, France",
#  'Arch Shaped Door Of A Fort Gate',
#  '3 Delicious Caramel Dips: Butter with a Side of Bread',
#  "<PERSON> plans its move to the Winter Street Industrial Park next year. The rendering shows the company's plan for its 5.8 acre facility, which will be constructed in the spring at the end of Railroad Street in Superior. (Courtesy of <PERSON>)",
#  'Winter in Mallorca | Walking through the empty streets of Palma',
#  'The wedding of <PERSON> and Az-Izz 24',
#  '1929 ford model a roadster photo',
#  'Pace Insole Kit From Tread Labs Fits All Your Footwear',
#  '39 The Volkswagen Touareg 2020 Performance and New Engine',
#  'Last Call For The Lincoln Town Car Automobile Magazine',
#  'Vs the World, Universe and more! Sticker',
#  'Detailed vector poster city map Zagreb. Design of a poster for interior decoration royalty free illustration',
#  'Read more on Key Trends in Canadian Real Estate Amid the Coronavirus',
#  'Safety lock on a vintage door bar. In historical city backyard area stock photos',
#  '1929 ford model a roadster',
#  'Check out this fun variety of letter T activities for preschool! Books, crafts, letter sounds and more!',
#  'Congratulations to the 9th Grade Blue Basketball Team',
#  'Mother and daughter giving each other high five Joy Happy Playing Table Kindergarten Child School Woman Adults Parents Family & Relations Infancy Paper Pen',
#  'Bedroom inspiration and bedding decor | The Pale Pink Studded Velvet Throw Pillows | <PERSON> and Canopy',
#  'The National Flag of the Republic of Uzbekistan',
#  '1945 diary excerpt a p03 20',
#  "<PERSON> (1847--1928), in '<PERSON>-sit-by-the-Fire' (1905), by <PERSON> Barrie",
#  'Waiting For The Rain Canvas Art Print',
#  'Doctor holding an umbrella. Health insurance silhouette icon. Protection concept, care medical. Healthcare concept. Doctor holding an umbrella, protecting the stock illustration',
#  'Flames of War game at the North Shore Wargames Club',
#  'The Hangover Breakfast Sandwich Recipe',
#  'The Dark Tower Comic Wallpapers',
#  'A (cell) culture of laziness Classic Mug',
#  'Is this the most bizarre sponsored post ever? <PERSON> takes a NAP next to her Louis Vuitton bag',
#  'A slice of pepperoni with a side salad',
#  'The Pros and Cons of Teaching English to Adults in China',
#  'Is this what Captain American would drive? <PERSON>, Captain American, <PERSON>, Muscle Power, <PERSON>, Dodge Chrysler, Jeep Dodge, Mopar Or No Car, Long Live',
#  'This should crank it up. Truck Tattoo, Wallpaper Size, Country Girls, <PERSON>, Hot Wheels, Hot Rods, Cool Cars, Beautiful, Women',
#  'In the far distance, loud light. Colour photo Close-up Detail Macro (Extreme close-up) Copy Space top Morning Twilight Light Blur Sun Sunlight Autumn Metal',
#  'Tiny Monochrome Room For A Little Boy',
#  "Moving to <PERSON> soon, can't wait for my own chance to photograph some of these waterfalls. This one is by <PERSON>. Scottish Fashion, British Isles, Great Britain, Outlander, Acre, Landscape Photography, <PERSON>, World, Skye Scotland",
#  'Draw this in your style #02',
#  'The Hunter Chapter 60 Online Free Manga Read Image 21',
#  'The Top Kitchen Collection - <PERSON> 10293',
#  'Rock formations in the ocean',
#  'Complete a White Tee and Boyfriend Jeans With a Chunky Choker and Bright Heels',
#  'The sunrise of the mountains surrounding Lake Tekapo. New Zealand.',
#  'The majority of ALTs are placed in junior high schools. Here, a JET poses with his English class. - JET Program - Japan',
#  'Close-up of logo for the credit bureau Experian on the upper corner of a personal consumer credit report, on a light wooden surface, September 11, 2017.',
#  'Restaurant Design - 8 Key Points on How to Design a Restaurant?',
#  "This cute, colourful picnic bench will brighten up any garden! I'm unfortunately moving to a flat without a garden so selling this on. I have added a new photo, as I've just seen this. Paint has slightly started peeling with this crazy weather the past few weeks. Sits up to 6 people 4 comfortably, only 1 year old. Pick up only from Camden",
#  'Asian <PERSON> Wood Prayer Beads Yoga Wrist Mala Stretch Bracelet with a Charm',
#  'The Equalizer VUDU 4K or iTunes 4K Via Movies Anywhere',
#  'A student dorm room is set up and ready for incoming students during a tour of Blackwell Hall at UC Berkeley on Monday, July 30, 2018.',
#  'Kent, Ramsgate, old photo of the Pavilion and Breakwater in 1907',
#  '10 of the best vintage desks in their home office or office - Decoration Top Home Office, Home Desk, Office Decor, Bureau Design, Living Room Furniture, Living Room Decor, Duplex Design, Workspace Desk, Vintage Room',
#  'A woman is silhouetted against the Baidu logo at a new product launch from Baidu, in Shanghai. Photo: Reuters',
#  'Have too much fun with these guys! Vikings Show, <PERSON> Season 4, <PERSON>, Old Norse, <PERSON>, <PERSON>, History Channel, <PERSON>, Behind The Scenes',
#  'A pair of <PERSON>',
#  'Nordic Home Sofa Iron Flamingo Wall Decoration Metal Bird Wall Decoration in the Living Room Creative Bedside Wall Hanging in Bedroom',
#  '36 the ford maverick 2020 engine for ford maverick 2020',
#  'Historic photo showing the <PERSON> mansion on Park Avenue.',
#  'Another view of the bathroom focusing on the soaking tub, chandelier and a wide TV on the mirror.',
#  '2020 Winter Wheat Crop Plantings Steady in the Southern Great Plains Versus 2019',
#  'All I Care About Is My Yorkie - T Shirt',
#  'Learn more about the Dutch Rabbit Breed. Discover cool facts, pictures, resources and find information about caring for Dutch Rabbits. Tortoise As Pets, Tortoise Food, Rabbits For Sale, Rabbit Breeds, Pet Rabbit, Tortoises, Find Pets, Animals For Kids, <PERSON>',
#  'Funny small baby sitting with dummy. Baby On Board. Funny small smiling boy or girl, sitting in romper with dummy. The sticker on the back window of the car stock illustration',
#  'Daughter Of The King iPhone Case',
#  "<PERSON> will reprise his Snow White role in The Huntsman Winter's War, opposite <PERSON>, <PERSON>, and <PERSON>. <PERSON>, <PERSON>, <PERSON>, Ice Queen, Snow Queen, Queen <PERSON>, <PERSON>, <PERSON>, New Movies",
#  '2.3 Electron Arrangement Describe the electromagnetic spectrum Distinguish between a continuous spectrum and a line spectrum.',
#  'Dining area at the apartment',
#  'Room, <PERSON> by the Galleria',
#  'Plaque given to each department by the Bullitt County Chamber of Commerce. Award accept by a personnel from department and featuring <PERSON> and Judge Executive <PERSON>.',
#  'Business Travel Tip - Never Check a Bag',
#  "Designers Marina and <PERSON> Sent continue their family tradition of Venetian glasswork with the Dual Bubble Earrings are made of glass spheres that bubbles which sparkle with reflected light. Glass Necklace, Glass Jewelry, Necklace Set, Jewelry Gifts, Jewelry Accessories, Jewelry Design, Jewelry Necklaces, Bubble Necklaces, Women's Earrings",
#  '<PERSON> helping get some little bikes ready to race.',
#  'Japanese cartoon anime black/white <PERSON> anime 0.5mm writing No face male cartoon pen',
#  'Lifting the new tower with the helicopter',
#  'Unisex necklace Star with the same paragraph hip hop jewelry with Zircon iced out chain personality <PERSON> mask Pendant necklace wholesale',
#  'A guided tour on Exit Glacier',
#  'Scary Background Lovely Royalty Free sound Fx Scary Ambient Horror Background Dungeon sounds Combination Of Scary Background Beautiful 28 Creepy Backgrounds Wallpapers Of the Day',
#  'Iceberg is melting in this highly detailed image from my last Antartica tour. What makes this image particularly striking is the formation of the ice as the iceberg is melting. Landscape Pictures, Nature Pictures, Travel Pictures, Travel Photos, Ice Pictures, Antarctica Destinations, Glaciers Melting, Polo Norte, Travel Photography',
#  'A Blue Opaque Glass Mantle <PERSON> c 1870',
#  'Migration of water columns around the perforation plate. (A) Water columns (W1 and W2) form at the height of the lower white arrowhead, ascend upward along the xylem vessel, and drain at the height of the upper black arrowhead, where a perforation plate (P-P) exists. (B) Temporal variation in the height of water columns W1 and W2. Here, W1 (black squares) and W2 (red circles) represent the upper and lower ends of the water columns. Dotted lines represent the positions of the perforation plate and the piercing point.',
#  "Volkswagen's New SUV - The T-Roc",
#  'Department 56 2015 Catalog The Village Book NEW 131 pages NEW All Villages for Like the Department 56 2015 Catalog The Village Book NEW 131 pages NEW All Villages? Christmas Village Collections, Christmas Village Display, Christmas Village Houses, Christmas Villages, Christmas Decorations, Christmas Ornaments, Holiday Decor, Christmas Light Pole, Jolly Holiday',
#  "People sitting at table on covered deck overlooking bamboo trees and the Botanical Garden's pond.",
#  'Pizza vector illustration, hand drawn pizza illustration, pizza vector poster, italian pizza. Isolated on a white background royalty free illustration',
#  'The Lion King Movie Poster',
#  'Hand smashing alarm clock with hammer in bed. Closeup of a mans hand smashing alarm clock with hammer in bed at home stock photos',
#  'Woman Reading in a Landscape 1869',
#  'The Patients with Chronic Illness Details on Written Task These will be the exact questions you will be asked on the OSCE Written Task 1 - History Document the subjective portion of a SOAP note.',
#  'A fat cartoon man jogging Royalty Free Vector Image Fat Cartoon, <PERSON>, Key To Losing Weight, Exercise Physiology, Muscle Tissue, Running Man, Weight Loss Goals, Physical Activities, Nice Body',
#  'Beyond the Kingdom Walkthrough Screenshots 33',
#  'Hinkler Building Blocks My Little Library - First Words - Back of the box - 9781743678138',
#  'Hooded jumper with a leopard-print pattern',
#  'The engine of a piston airplane.',
#  '<strong>February 10:</strong> People celebrate in clouds of colored dust after the Color Run 5K in Sydney.',
#  "'The Lonely Libertarian' book cover",
#  'Sherlock Holmes BBC - Inspirational Pencils Engraved With Funny And Motivational Sayings For School And The Office',
#  "``Rowing in the Sun Rise'' by Dorte Verner Photography",
#  'The Benefits of Fiber Connectivity For Your Business',
#  '<PERSON> at 2015 LA Film Festival',
#  '<PERSON> Back to the Future Framed Art Print',
#  'Mother of the bride crying during asian wedding',
#  'Mug of hot chocolate in a holiday setting',
#  'This image may contain Food Bread Plant Bowl Dish Meal and Vegetable',
#  "Whether you're looking a fairytale wedding dress or getting married in forest. Here is an Enchanted Forest Fairytale Wedding in Shades of Autumn inspiration shoot,fairy tale forest wedding Enchanted Forest Wedding, Woodland Wedding, Woodland Theme, Fairytale Weddings, Cinderella Wedding, Garden Wedding Decorations, Wedding Themes, Wedding Photos, Wedding Cakes",
#  'Gas hoses for Wave 8, Baby Q Grill, and outside stove connect to the Quick-Connect fitting outside.',
#  'Cartoon person in front of computer monitor scared. Network. Spider crawls out of the monitor. Phobia, fear of gamers and programmers. Vector illustration isolated on a white background.',
#  "On A Mission 5'5 Super Comp Giraffe Fade Leash",
#  "The Wall: St. Florian's Gate and the City Walls of Krakow",
#  '3 multicolored fin attached to a surfboard',
#  'Man standing on one hand in Side Plank Pose, arm balance yoga Asana in the studio or apartment on a yoga mate. Young man stretches the entire body doing royalty free illustration',
#  'Indian company gets the nod to import GMO cotton seeds',
#  'Girls night out: The model, along with MIC newbies <PERSON> and <PERSON>, made quite the stunning trio as they walked to a club <PERSON>, <PERSON>, Made In Chelsea, Girls Night Out, Bombshells, Ibiza, <PERSON>, Celebrities, Model',
#  'Angry boss and two employees in the form of white and dark eggs. Creative. Concept stock photography',
#  '0302 polished brass along with a cornice installed in a bathroom.',
#  'Overhead shot of photography equipment on a wooden table - photography insurance tips',
#  '<PERSON> with a sand shot on the fourteenth hole during a practice round for the Swinging Skirts LPGA Classic golf tournament at Lake Merced Golf Course, in San Francisco, Calif., on Tues. April 21, 2015.',
#  'No annual fee text buffered stock illustration',
#  'LG The Real Watch, W150, thumbnail 2',
#  'Book - Beauty and the Beast by <PERSON>',
#  '<PERSON> 101: Revelation - The Fifth Gospel - DVD 2',
#  'Branded clothes on sale by the Closet Club',
#  'General <PERSON> seems to be raising his flag in solidarity with those of us below him. The police were getting ready to sweep the hill.',
#  'Hand drawing watercolor pencils machine with the newlyweds stock illustration',
#  'Invicta grand diver watch on 7 Inch Wrist. G Shock, Diesel, <PERSON>, Rolex Watches, Nice, Accessories, Diesel Fuel, Nice France',
#  'All my memories gather round her simply southern shirt',
#  'Close-up of a dark chocolate-coated Irish cream Oreo truffle.',
#  'The building where the hotel is located',
#  'Mini Toddler Belle Beauty & Beast Doll My First Disney Princess <PERSON> for sale online My First Disney Princess, Toddler Dolls, <PERSON>, Merida, Beauty And The Beast, <PERSON>, Treats, Gift Ideas',
#  'Sampling Technology Mainstream sampling - CO2 analysis chamber is in-line between the patient airway and the ventilator circuit.',
#  '<PERSON> was spotted outside her office looking laid-back yet stylish in a white denim jacket layered over a blue print dress.',
#  '5 Ways to Wear a Poncho | The Fresh Exchange',
#  'Room, The Alternative Beach Cottages',
#  'Foliage Plants : we grow these for the shape and colour of their leaves.',
#  "``BACK TO THE FUTURE'' <PERSON> Modern Classic Movie Poster - Poster Size : A4",
#  'Be careful not to cut into any wires or sleeving!',
#  'PowerPoint Template Displaying a Space View of the Sun and Planets of their Orbits',
#  'A tree that is half happy, half sad, climate change solutions on demand',
#  'Consider Gathering Your Crew Around The Table A Lot Of Education Can Take Place Through',
#  "Several rocks in <PERSON>'s Stone Field Sculpture in downtown Hartford were found spray-painted, as though by a utility worker.",
#  'The plane is the last one in line on the runway. This is the last view of it on the ground.',
#  '2020 Sweetwater boat for sale, model of the boat is SW 2186 SB & Image # 5 of 27',
#  '12 Modern Pools That Make a Big Splash in main architecture Category',
#  'Start a Revolution From My Bed - Lyric Quote T Shirt',
#  'Kayak of Plastic Bottles in Argentina Turns Trash into an Outdoors Treasure Row Row Your Boat, Row Row Row, The Row, Reuse Plastic Bottles, Recycled Bottles, Boat Crafts, Water Crafts, Team Building Activities, Pet Bottle',
#  'All I want for Christmas is Janeway iPhone Soft Case',
#  'Magic dark wizard on a mountain with wand stock illustration',
#  "``You Will Rise Above the Ashes'' Phoenix Classic T-Shirt",
#  'The flag-draped casket of former President <PERSON> <PERSON> is carried by a joint services military honor guard Wednesday, Dec. 5, 2018, at Ellington Field in Houston. (AP Photo/ <PERSON>, Pool)',
#  "Greece's <PERSON> (L) fights for the ball with Ivory Coast's <PERSON> during their 2014 World Cup Group C soccer match at the Castelao arena in Fortaleza June 24, 2014. ( <PERSON>/Reuters)",
#  'Training the New Model Army Civil War Art, Civilization, Army, English, Training, Model, Illuminated Manuscript, <PERSON>, Coaching',
#  'The Galilean Moons The next four moons in orbit around Jupiter are the large Galilean moons. _.',
#  '14 fascinating oak furniture the british tradition oak furniture computer table upscale furniture, baroque furniture, vintage furniture, antique furniture, wooden sofa designs, altar, miniature crafts, antique chairs, wainscoting',
#  'Still Life With A Nautilus Cup 1662 | <PERSON> | oil painting',
#  'Betta on the fish tank background. Betta fish of Thailand on the fish tank background stock photos',
#  '<PERSON> with <PERSON> (left) and <PERSON> from the Birmingham Post events team',
#  'Boots walking on the snow view from above.',
#  'Pig Portable Battery Charger featuring the drawing Daddy Pig by <PERSON>',
#  '<PERSON> of Vietnam celebrates with team-mates after scoring in the AFF Suzuki Cup final against Malaysia',
#  'Attaching the Number Disk to Motor and Placing in the Box',
#  'Wallpaper <PERSON>, big backgrounds | <PERSON> in the dew',
#  'City of Tulsa: 1 Contractor Dies After Tree Falls During Removal, Another Injured',
#  'Seeing the Templo Mayor ruins is one of the best things to do in Mexico City',
#  '<PERSON> BS black white red alphabet letter combination logo icon design. BS BS black white red dots alphabet letter combination suitable as a logo icon design for a royalty free illustration',
#  'Green bamboo plant forest in Japan zen garden. The green bamboo plant forest in Japan zen garden stock photography',
#  '<PERSON> dragon and a big cat balloon iPad Snap Case',
#  "<PERSON>'s daughters, <PERSON> and <PERSON>, get a chance to sit in their childhood vehicle, which is now part of the Moving Stories exhibition.",
#  'Holding A Piece Of Paper - Writing #1651951',
#  "Office Birthday Decor- Celebrate your employees' birthday with streamers, confetti, and colorful balloons. This will make their Special Day even more special, with thoughtful decor & colors they are sure to appreciate it. Office Birthday Decorations, White Office Decor, Small Floor Plans, <PERSON>, Harry Potter Decor, Colourful Balloons, Office Parties, Birthday Balloons",
#  '<PERSON> - Brandy Melville Off The Shoulder Top',
#  'Water in the morning and afternoon during summer, and it flowers have a more wafting candy fragrance.',
#  'Nixon& War Room in Watchmen is modeled after a set from Stanley Kubrick& Cold War masterpiece from Dr. Strangelove (pictured below, right). <PERSON>, <PERSON>, Dr <PERSON>, Face Photo, Stanley Kubrick, Comedy Films, Political Satire, Taxi Driver, Video News',
#  'A repeating pattern in purple turquoise black and pink. It is purely decorative',
#  "LOS ANGELES - SEP 27: <PERSON> at the ``Star Wars Rebels'' Premiere Screening at AMC Century City on September 27, 2014 in Century City, CA",
#  'Free art print of A happy worm reading book',
#  '<PERSON> <PERSON> chandelier hanging in the void area',
#  '#bloodborne#titan comics#comics #the death of sleep #greater viper pit',
# ...
#  "Rangers <PERSON> and Rangers <PERSON> tackle Oxford's <PERSON> during the preseason friendly at Ibrox Stadium Glasgow",
#  'Disease in mango that causes the skin of mango fruits and leaves to become black spots.',
#  'Evening Drinks by the Fire',
#  "A few of the villas at Elements. ``The resort is laidback but with a bit of luxe,'' says owner <PERSON>, whose plans involved planting 65,000 native trees and plants.",
#  'Photo Wallpaper an Retro Flower Pots Metope Living Room Sofa Cafe Backdrop Wall Mural Wallpaper 3D',
#  'May Girl 2020 The One Where Celebrate My Birthday In Quarantine vintage Shirt',
#  'Puppy dog outside a hut in the banana fields near Fort Portal, Uganda.',
#  'Born Free Suites by the Sea: upper deck',
#  'A Bullock Cart and a Dog running in Seawater at a Beach stock photography',
#  'A set teddy bear and yarn for knitting hand',
#  'A bed or beds in a room at Radisson Blu Royal Garden Hotel, Trondheim',
#  'Get Ready For The Spring 20 Charming DIY Window Boxes Ideas',
#  'Autumn foliage in the great smoky mountains.',
#  "There were lots of great floats in this year's Westville Parade of Lights which was held Dec. 7 in Westville.",
#  'No Touch Digital Forehead Thermometer Infrared IR Baby Body Skin Fever Temporal Measurement',
#  '<PERSON> pees on a grass field. At open zoo stock photography',
#  'A white dog with strong teeth playing biting a stick stock photography',
#  'Full Size of And Trim Same Color White Paint Floor As Wall Ceiling Design Do You Walls The Different Should',
#  '<PERSON> and the view of Serene Lake',
#  'Bride and bridesmaids smile at each other downtown.',
#  'A calculator, social security, and financial statement.',
#  'Cavatina (from The Deer Hunter): For piano by Stanley Myers Dance Music, Hunters, Piano, Deer, Sheet Music, My Love, My Boo, Music Notes, Pianos',
#  'Wedding at The Acre Orlando',
#  'The Wedding Industry Awards 2015',
#  '3D Map outline and flag of Czech Republic, two equal horizontal bands of white (top) and red with a blue isosceles triangle based on the hoist side.',
#  "<PERSON> wore a gown with a floral back by <PERSON> from Blackburn Bridal for her Summer wedding held at her husband's family home. Photography by <PERSON>.",
#  'This image may contain Clothing Apparel Footwear and Shoe',
#  'In this photo from Feb. 11, 1980, <PERSON> was hoisted aloft by his players after Northeastern defeated Boston College in overtime in the annual Beanpot hockey tournament.',
#  'Pink pig cute on brown background. Isolated cartoon vector character. No gradients Illustration',
#  "Stock image of 'Stuck in traffic jams in the rain'",
#  'Shirt Pink Floyd Have a Cigar T-Shirt',
#  'Representative image of a cloaked druid in a forest.',
#  'Comfort Stylus slimline twist pen (Polymer Clay in a Gun Metal finish)',
#  "Looks like the beach is <PERSON>'s favourite place to be.",
#  'Sonic The Hedgehog Eggman Enterprises T-Shirt, BLACK, alternate',
#  'The <PERSON> house on a postcard that looks in an easterly direction from Lake of the Isles at the west side of the mansion and its southwest corner.',
#  "'The Last Supper' by El Greco Painting Print on Wrapped Canvas",
#  'A guest laughing during the wedding speeches',
#  'The Colors Of Photography ~ Part Six Poster',
#  'Mason Full Over Full Bunk Bed in <PERSON>. View a larger version of this product image.',
#  'Just bought the most expensive socks I ever have owned.',
#  'The UFO has Landed Short Sleeve Baby One-Piece',
#  'Senior <PERSON> (Left) teaches <PERSON> (Right) the basics of swimming.',
#  '3% Animals with a spinal column Vertebrates Mammals Birds Reptiles',
#  'Main view of <PERSON> - Red',
#  'Would You Pay US$1,000 For A Durian?',
#  'Back Open Blouse Designs With Hooks At The Back',
#  "Southeast Polk High School's ``Beauty and the Beast'' will be presented Friday, Nov. 11, at 7 p.m., and Saturday, Nov. 12, at 7 p.m. In addition, on Nov. 12 from 10 to 11:30 a.m. the players will host a VIP Enchanted Event in which guests can meet <PERSON>, the Beast and other characters.",
#  'The Room nightclub Hamburg view of empty inside',
#  'Star Wars tire swing - Star Wars Family - Ideas of Star Wars Family - Star Wars tire swing Star Wars Rebels, Star Trek, Star Wars Art, Geeks, Star Wars Humor, Star Wars Puns, The Force Is Strong, <PERSON>, Geek Out',
#  'The Marietta Diner Greeting Card for Sale by Corky Willis Atlanta Photography',
#  'Junkyard car for sale 1:18 scale diecast model 1961 Lincoln image 6',
#  'Modern Mediterranean villa with a pool',
#  "Magazine logo with the title 'House of Desiderata'",
#  'Have a nice day background with cup of tea. Vector illustration.',
#  '<PERSON> mascot <PERSON>! joins <PERSON> and <PERSON> in the Global News Morning studio. Friday, Dec. 9, 2016.',
#  'Home Of The Blues Hoodie',
#  'Looking to customize your Audi? We carry a wide variety of Audi accessories including dash kits, window tint, light tint, wraps and more. Ferrari, Maserati, Bugatti, My Dream Car, Dream Cars, Audi R8, Black Audi, Matte Black, Black Cars',
#  'Happy Snail Skincare Sunday - you know I love any korean beauty products that come with snails! Put it on mah face right away! Face Mask For Pores, Face Masks, Oil Free Foundation, Tanning Cream, How To Make Greens, Cosmetic Design, Prevent Wrinkles, Korean Skincare, Skin Treatments',
#  'Madison wedding DJ playing tunes at a theater wedding',
#  'Portrait photography in Sydney on a beach. Family and dogs',
#  'Over the Moon Melon Drink',
#  'A worker at the dump yard looks at the camera, while a garbage disposal truck unloads waste in the foreground.',
#  'A Little Bolt of Life: The Fish Extender Experience Disney Halloween Cruise, Disney Cruise Door, Disney Cruise Tips, Disney Vacations, Disney Trips, Disney Travel, Disney Magic, Family Travel, Gift Tags',
#  "Radhe: Your Most Wanted Bhai is Salman Khan's Next: Release Date Eid 2020 Trailer, <PERSON>, <PERSON>, Yash Raj Films, <PERSON>, Motion Poster, Next Film, The Best Films",
#  'Dog statue in the gardens',
#  '<PERSON> Whatever Scary Thought Green Eyes Sticker',
#  'The lobby or reception area at Premier Inn Doha Airport',
#  'A general sea view or a sea view taken from the resort',
#  'The indoor climbing wall at Chill Factor in Manchester.',
#  'Final Look-Back at the Impressive Rampart Walls of Valença on day nineteen on the Central Route of the Portuguese Camino',
#  'A rendering of the proposed mixed-use development at Church and Division streets in New Rochelle.',
#  '<PERSON> is nominated for <PERSON> at the upcoming Grammy Awards. (Photo by <PERSON>)',
#  'Sans Carlos De Bariloche, Rio Negro, Argentina - August 25, 2012: A Skiers Hikes Up A Ridge With His Skis On His Back In Argentina',
#  'Los Angeles Rams running back <PERSON> rushes the ball against the Dallas Cowboys in an NFL playoff game earlier this month',
#  'Springtime on the Malvern Hills',
#  'Straight-fit leather pants - Details of the article 8',
#  'Vector business illustration in linear style with a picture of willpower as brain and muscle hand on yellow background poster or banner template. Illustration',
#  'Builders Warehouse : Having All The Tools',
#  'Cute Amphibian - My Spirit Animal Is An Axolotl Duvet Cover',
#  'A 773-stall parking ramp in downtown Minneapolis has opened to the public.',
#  'Voyager Insurance wins at the NIA Awards',
#  'No Drama llama Premium T-Shirt',
#  'President <PERSON> picnics in the woods with a companion during his term of office',
#  'Vector festive illustration of a goblet with wine splash â€`` par royalty free illustration',
#  "-betta fish no. 3 i started drawing fish a few years ago but i've always had trouble with drawing scales because of the complicated... realistic pencil drawings, fish drawings, colorful drawings, animal",
#  'The graph of pressure verses volume is shown for a constant pressure. The pressure P is along the Y axis and the volume is along the <PERSON> axis. The graph is a straight line parallel to the <PERSON> axis for a value of pressure P. Two points are marked on the graph at either end of the line as A and B. A is the starting point of the graph and B is the end point of graph. There is an arrow pointing from A to B. The term isobaric is written on the graph. For a length of graph equal to delta V the area of the graph is shown as a shaded area given by P times delta V which is equal to work W.',
#  'An office chair with a designated headrest.',
#  'Lobby The Leaf Jimbaran Luxury Villas',
#  'Eat These 12 Foods If You Want Better Hair',
#  "``The Real L Word'' Premiere : News Photo",
#  'Save water save earth concept. Save The Water Concept. save earth, <PERSON>, protection vector illustrations for all kids of use stock illustration',
#  'Fairy style with a single shoes female 2019 summer new sandals small fresh students pointed wild high heels',
#  'The Third in our range of novel decor door stoppers. Oscar the Owl door stopper',
#  'Stock Photo: India, Rajasthan state, Baneshwar, the annual fair of <PERSON> tribes is both an ancient fair, a religious festival and a carnival.',
#  'Slide 3 of 26: In 1980 The Empire Strikes Back (arguably the best of the Star Wars lineup) was released and the solar system revealed the ultimate fan tribute: a full-scale model of the Death Star. Mimas is an icy, almost perfectly rounded moon, the smallest of those in orbit around Saturn. The massive crater stretching across a third of its face makes it a dead ringer for the galactic superweapon.',
#  'Pomegranate on the tree, pomegranate is very useful, contains vitamins stock photography',
#  "Liverpool's <PERSON> and Olympiakos' <PERSON> battle for the ball",
#  'Map of The Line Urban Flats',
#  'Contemporary kitchen featuring an oversized kitchen island with sink',
#  'Modern sliding door with kitchen in the background, white minimal architecture interior royalty free illustration',
#  "'Shooting Star Bracelet, 14k gold star on sterling silver chain. Also available in all gold or all silver.'",
#  'Inspirational ideas that we are fond of! Black Garage Doors, Garage Door Panels, Panel Doors, Contemporary Garage Doors, Barrel Furniture, Garage Shelving, Blinds For Windows, House Front, Contemporary Architecture',
#  '<PERSON> poster for a pilsner brewed with plantains Inwood Manhattan',
#  "Photo by <PERSON> Minister for Corrections, the Hon <PERSON> MP, returned to Westbury to attend a public meeting to discuss the State Government decision to place the new Northern Regional Prison on a site close to the town. Hostility and cynicism dominated the meeting, which was attended by many local residents who are opposed to the State Government's plans or angry that the decision was made without consulting the community beforehand.",
#  'A bathroom at Hotel Luna',
#  'Bottom view of bridge on a foggy day',
#  'Medium Size of Mermaid Wall With Name Au Decal Under The Sea Australia Design Decals Walmart Little',
#  'Wooden airplane on a white background. biplane model. 3D rendering. Toy wooden airplane on a white background. biplane model. 3D rendering royalty free illustration',
#  'Tv shelf on the in modern living room the concrete wall.',
#  'Elegant brickwork defined the San Luis Obispo building.',
#  'Child ENT check - doctor examining ear of a little girl with otoscope',
#  '<PERSON> of the Kangaroos runs the ball',
#  '<PERSON> leads <PERSON> and <PERSON> out of the space centre on the Apollo 11 space mission to the moon, 1969',
#  'A bathroom at Destiny Scotland - Broughton St Lofts',
#  'Both sofa and table have prime spots by the window.',
#  '777 FLIGHT DECK OVER THE ATLANTIC - Stock Image',
#  'A fragment of a bamboo roof. Against a blue sky stock photos',
#  'Roman style pool with minimal white decking and a hedge for privacy',
#  'A plate of Vietnamese grilled pork',
#  'U.S. Marines with Marine Attack Squadron 311 (VMA-311), Marine Corps Air Station (MCAS) Yuma, participate in the Change of Command Ceremony where Lt. Col. <PERSON>, commanding officer for VMA-311 relinquished command to Lt. Col. <PERSON> on MCAS Yuma, Ariz., Dec. 13, 2018. The Change of Command Ceremony represents the transfer of responsibility, authority, and accountability from the outgoing commanding officer to the incoming commanding officer. (U.S. Marine Corps photo by <PERSON>. <PERSON>)',
#  'Businessman taking out book from a virtual shelve. Businessman hands taking out book from a virtual library shelve on a tablet computer or big smartphone. Flat royalty free illustration',
#  'Does a burrito bowl a day do the body good?',
#  'The building in which the homestay is located',
#  '(Mural, Joy and Memory, by <PERSON>, in the Jefferson Building, Library of Congress)',
#  'Petani beach, Kefalonia, Greece - View to the beach - Large Size',
#  'Living room with a view at The Corniche. We love the interior design at the show apartment. Stunning glass dining table and contrasting sofas are a great finish against the Just For Today, 3 Bedroom Apartment, Glass Dining Table, New Property, Pent House, Sofas, Home And Family, New Homes',
#  'Camelia - Flamingo - <PERSON> fading to fiery orange on fabric made from viscose, cotton and linen, behind a large, ornate, white leafy pattern',
#  'A big bowl with Black-eyed peas salad, on the right at the back is another bowl out of focus. On the left is an out of focus blue and white dinner napkin.',
#  '3D rendering of a clown, with eyes closed in cartoon style Stock Photo - 7999693',
#  'Wholesale genie body shaper for sale - Group buy <PERSON> Belt Slimming 2019 Shaper Miss Waist Trainer Belt -body Shaper Belt For An Hourglass Shape',
#  'Pretty summer wedding flowers were displayed in a crate at this barn wedding in Hampshire',
#  'A mural dedicated to late Cuban leader <PERSON> in Naples, Italy.',
#  '5 Color Trends To Use for a Cheerful Interior Design luxury homes Luxury Homes That Give Modern Living A Whole New Meaning 5 Color Trends To Use for a Cheerful Interior Design 2 luxury homes Luxury Homes That Give Modern Living A Whole New Meaning 5 Color Trends To Use for a Cheerful Interior Design 2',
#  'Find the slope of each line',
#  'Off the Shoulder Mother of the Bride Dresses',
#  'The Function Rooms Meeting and Conference Rooms The Fort BGC; Event Spaces; Event Spaces Manila; Event Spaces The Function Rooms; The Function Rooms Manila',
#  'Lazy girl wanna take nap doing nothing all day. Silly cute european woman yawning hands raised stretching body feel. Energized waking up afternoon standing stock images',
#  'Anchor Bottom looking east up the hill with Ragwort',
#  "<PERSON>, the Arlington Cat Clinic's resident feline, sits in the Kitten Shower donation basket asking for your donations to help shelter kittens.",
#  'Life Is Better At The Lake | Lake Life Sign | Life Is Better At The Lake Sign | Lake House Sign | Farmhouse Lake Sign | <PERSON>',
#  'Pictures quality, NS-97, The sky and the ocean',
#  'The Surreal Architectural Collages By Matthias Jung Look Like Mirage',
#  'A bed or beds in a room at Luxury room & studio <PERSON>',
#  'The Duke and Duchess of Cambridge along with B.C. Premier <PERSON> walk through the Great Bear rainforest in Bella Bella, B.C., Monday.',
#  'A restaurant or other place to eat at Sheraton Chongqing Hotel',
#  'The Qiao Sisters Game Costumes, Sisters, Princess Zelda, Games, Fictional Characters, Gaming, <PERSON>, Toys, Playing Games',
#  'Storm Shadow (Character) - Comic Vine --- <PERSON> who has fought for and against <PERSON> and Cobra. Most known for his deadly rivalry with <PERSON> member<PERSON> who is also the closest thing he has to a brother. Thundercats, Anime Comics, Marvel Comics, Dark Knight, Comic Books Art, Comic Art, Drawn Art, Cartoon Wallpaper, Paladin',
#  'Edge Cabinets Melbourne, Kitchens Melbourne, cabinet making Melbourne, all victorian suburbs',
#  'Brand identity and illustration for Bridging the Divide research projects, based at De Montfort University in Leicester',
#  "Harrods, the world's most famous department store online with the latest men's and women's designer fashion, luxury gifts, food and accessories Brown Nail Polish, Long Lasting Nail Polish, Brown Shades, Nail Polish Designs, Luxury Gifts, Harrods, <PERSON>, Camo, Perfume Bottles",
#  ...]

# %%
# %%time
print("Number of cpu : ", multiprocessing.cpu_count())

p = Pool(processes=16)
processed_CC12M = p.map(text_preprocessing, [processed_CC12M_text[i] for i in range(len(processed_CC12M_text))])
p.close()

print(f" the length of text processed data is ============================ {len(processed_CC12M)}")
print(processed_CC12M)
# Out:
# Number of cpu :  64
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOStream.flush timed out

# %%
len(processed_CC12M_text)

# %% [markdown]
# ## Processing LAION

# %%
path_dir_laion = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/LAION/dataset/laion/laion400m-meta/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        path_dir_laion.append(os.path.join(dirname, filename))

# %%
def collect_laion_data(path):
    df_laion = pd.read_parquet(path)
    N_laion = len(df_laion)  # number of samples from one parquet of laion 
    small_laion = df_laion.sample(n=N_laion)

    laion_texts_array = small_laion["TEXT"].iloc[0:N_laion].values
    return laion_texts_array.tolist()

# %%
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())
# Out:
# Number of cpu :  64

# %%
## cal feature info 
start_time = time.time()

common_lst = []
for i in range(len(path_dir_laion)):
    laion_texts = collect_laion_data(path_dir_laion[i])
    
    laion_text_re = []
    for val in laion_texts:
        if val != None :
            laion_text_re.append(val)

    p = Pool(processes=16)
    laion_text_processed = p.map(text_preprocessing, [laion_text_re[i] for i in range(len(laion_text_re))])
    p.close()    
    common = set(laion_text_processed).intersection(set(processed_CC12M)) 
    print(f"length of common set {len(common)}")
    print("--- %s seconds ---" % (time.time() - start_time))
    common_lst.append(common)

# %%
common_lst_re = []
for common_ in common_lst:
    common_lst_re.extend(common_)

# %%
np.save('./CC12M_LAION_commonset.npy',common_lst_re)
np.save('./CC12M_LAION_unqiue_commonset.npy',np.unique(np.array(common_lst_re)))

# %% [markdown]
# # LAION vs CC3M

# %% [markdown]
# ## Processing CC3M

# %%
df_cc_3M =  pd.read_csv("/home/myeongseob/clip-privacy/Open_clip_training/src/data/dataset/3M/Train_GCC-training.tsv", sep='\t')
print(f"the lenghth of data is {len(df_cc_3M)}")

N_cc_3M = len(df_cc_3M)
print(df_cc_3M.keys())

# %%
cc_3M_images_array = df_cc_3M["url"].iloc[0:N_cc_3M].values
cc_3M_texts_array = df_cc_3M["caption"].iloc[0:N_cc_3M].values
ipyplot.plot_images(cc_3M_images_array, cc_3M_texts_array, max_images=5, img_width=200)

# %%
# %%time
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())

#pool = multiprocessing.Pool(64)
#processes = [pool.apply_async(text_preprocessing, args=(cc_3M_texts_array[i],)) for i in range(len(cc_3M_texts_array))]
p = Pool(processes=16)
processed_cc_3M = p.map(text_preprocessing, [cc_3M_texts_array[i] for i in range(len(cc_3M_texts_array))])
p.close()
# Out:
# --- 64.63366556167603 seconds ---

# %%
len(processed_cc_3M)
# Out:
# 3318333
# ['the raincoat worn while kissing the heck out of actor .',
#  'the concession centred this is a contemporary construction of astyle hotel atop the original building .',
#  'talk show host is seen on a motorcycle outside building',
#  'female hands painted easter eggs in a yellow color with a brush , top view',
#  'little boy playing in the autumn park , shaking the tree and leaves are falling on him',
#  'black sand beaches that stretch for miles upon miles with winds so wild they will literally rip your doors off .',
#  'a musician with his saxophone',
#  'vector illustration of an abstract complex structure consisting of geometric shapes on a white background .',
#  'person paint up with white clay for fun',
#  'pets a white pony at the zoo on her 80th birthday',
#  'close - up of puppy wearing a wig , in front of white background',
#  'marching through the streets protesting the capitalist system under which we live .',
#  'red - haired girl with red lips with a black hat with long hair .',
#  'view with decorations at night',
#  'actor was also seen at the event .',
#  'vector silhouette of family on a white background .',
#  'soccer player in action during the football match against football team on .',
#  'ripe onion on a white background .',
#  'loved up : on the streets with person the model opted for a casual look and dressed down in a black hooded top and a pair of short white shorts',
#  'young couple with kid having fun in the kitchen while preparing spaghetti and vegetable salad',
#  'small balls pouring from an open medical capsule',
#  'graffiti adorns the front wall of the temple .',
#  'interesting statistics from the first games .',
#  'a poster for comedy starring actor .',
#  'person drives through a huge sheet of glass .',
#  'this is a representational photograph of the work displayed in paintings',
#  'the family dog resting inside the home',
#  'here is a map of person',
#  'man walking alone in the park',
#  'female secret agent in a hat and sunglasses , vector illustration , no transparencies , eps',
#  'person has country pop artist inspired # wedding champagne toasting flutes .',
#  'city centre at the rear with high - rise office buildings',
#  'young kids , or siblings with a laptop computer in an empty living room',
#  'american football player before the game against sports team',
#  'the ruins sits atop the cliffs overlooking geographical feature on the coast',
#  'the clock tower dominated by newer buildings',
#  'ships lined up in the harbor at sunset .',
#  'the pieces of pizza on a gray background .',
#  'second longest river in the world',
#  'salad on a wooden table',
#  'officials have revealed more about the high - flying system coming soon to the park .',
#  'i deliberately framed this image with the fir tree on the right for added depth and interest .',
#  'biological species standing on a cat lying',
#  'rocket carries the first ever - g 3d printer to satellite',
#  'hard rock artist performs onstage at festival by brand .',
#  'lot - an oil on canvas of a seated period lady and child , bears author',
#  '# celebrates a first quarter touchdown reception with # during a game against sports team .',
#  'cute doll with a hat',
#  'actor at an event for holiday',
#  'lily pads and pastel coloured flowers on a shallow pond surrounded by palm trees and lawns',
#  'illustration of person with calligraphy for the celebration of community festival',
#  'actor during an interview with comedian',
#  'hand swiping a credit card .',
#  'some of the old cars around the town look like the kind of people would have driven',
#  'pineapple on the beach with blue sky',
#  'the north coast can be seen through the clouds',
#  'what to know when moving during the winter time',
#  'beautiful stylized image of a fluffy black cat with big ears and a tail .',
#  'pages from a photo album showing views .',
#  'motorcycle riding on dirt road high up',
#  'happy dolphins jumping out of the water',
#  'if military commander or fictional character !',
#  'insane bicycle jump from the roof',
#  'baseball player is introduced to the crowd .',
#  'the sitting area on the second floor .',
#  'black silhouette of a young man on a bike',
#  'to the left , we have larger buildings , which can accommodate parties of guests .',
#  'organism resting on a stone',
#  'a shopping list written in a notebook',
#  'how to layer paint on a piece of furniture',
#  'machine is a device , like a bicycle , with moving parts that work together to accomplish a task .',
#  'false books in this one makes it lighter',
#  'black cat sitting and looking up acting curious and focused on a dark background .',
#  'decorating with globes around the home .',
#  'museum will host the regional conference in photo courtesy',
#  'a plane takes off from a runway',
#  'horse with stars as a symbol of vector art illustration',
#  'athlete scores a try during the match .',
#  'fishing boats in the harbour on the island',
#  "football player celebrates scoring his side 's first goal of the game with football player during the match",
#  'new ads for the truck',
#  "against the backdrop of the hotel 's vast pool",
#  'biological species crossing a road in front of an oncoming car',
#  'dessert that is made of a mixture consisting of grains , fruits and nuts',
#  'accessible footwear for the homeless .',
#  'the woman in cabin by person',
#  'i will always be jealous of these people who came at concert ... it really looks like fire',
#  'photo of shirts laying on table .',
#  'armed force were put on standby in case the violence escalated',
#  'qualities that women love in men',
#  'person with her dogs on the back porch of her home .',
#  "it 's a girl ~ vintage postcard with stork",
#  'hand made chair in royal line , made of solid wood',
#  'the view from a boat approaching the port on the north coast',
#  'ship on the river in winter .',
#  'sad couple after breaking up sitting on a couch in the living room in a house indoor with a dark background',
#  'rider jumping over a jump in great style',
#  'friday putts on the 8th green during a tournament held .',
#  'figurine in the form of a golden snake .',
#  'cc ... i could see myself in this !',
#  'the groom giving his bride a kiss on the forehead .',
#  'i know a couple of little boys this would be so cute on !',
#  'hip hop artist performs onstage during festival',
#  'fashion week fall see every celebrity in the front row',
#  'people walking in one of the busy streets',
#  'country support a partial ban on immigration',
#  'actor and guest attend the premiere of animation film .',
#  'football fans on the main square , watching football team vs parliamentary republic',
#  'actor attends person during festival',
#  "photos show ladders stretched to the roof of the - story building that 's",
#  'a naval ship undergoing maintenance at the dry dock',
#  'how to organize , clean , and edit your closet and wardrobe like a pro stylist for cheap .',
#  'rear view of a young woman with a tattoo on her back',
#  'planet earth from the space .',
#  'a locket belonging to author containing a picture of her fiancé',
#  'a long living room is divided into separate and distinct spaces .',
#  'retro filtered picture of flags on a beach .',
#  'the tourist is resting in hotel room',
#  'reflection of lights inside a casino',
#  'person and the choir after singing carols at the escalator .',
#  'dead roses in a vase on table',
#  "captain 's grille : the globe in the hallway",
#  'actors who turned down the part of film character',
#  'pour water into a glass',
#  'shredded chicken served with vegetables .',
#  'the white house closeup of southern facade',
#  'baseball pitcher pitches against sports team',
#  'cute young girl writing diary seated on the playground at dusk',
#  'a giant balloon is marched down a city during event thursday .',
#  'portrait of a young man',
#  'flying over the coral reef',
#  'pretty , cheerful girl well talking on the phone in cafe',
#  "how swimming , and lots of love , saved person the puppy 's life",
#  'make a firm dough and cut it into quarters , then let it chill for mins .',
#  'chicken in ice cube isolated on a white background',
#  'the contour of the ancient sailing ship .',
#  'person looks straight ahead in a black suit in tv political drama',
#  'novelist gives person a hug at ceremony to honor the retired publisher',
#  'a closed sign hanging on a door',
#  'red and yellow flags fluttering in the wind against blue sky',
#  'plaque embedded into a rock in front of a wooden fence',
#  'players celebrate after person scored the opening',
#  'bowling ball and pin vector set isolated from the background .',
#  'a group of business people make a happy business team',
#  'cricketer is likely to face a few challenges as the coach of the cricket team .',
#  'in the style of actor !',
#  'low angle view of a weathered stone wall',
#  'the opening of the new building .',
#  "not sure if it 's too late or not , but i went out during the rain today to take pictures of the confluence while it 's flooded to show how much water it can hold .",
#  'lantern in a blooming spring park',
#  'the graduate photo of high school senior in suit wearing glasses and looking at the camera by photographer',
#  'the businessman looks at his shadow and sees the super hero as a symbol of leadership , power and success .',
#  'file : an airplane prepares to land .',
#  'a young successful farmer is working in the field .',
#  'garden shed ... my husband built this and the bridge for me .',
#  'laying low : dressed down in a black t - shirt and jeans , the soccer player is seen keeping his head held down as he made his way solo to his - star hotel room',
#  'the combination of the lighting and the colors in this outdoor kitchen makes it looking more modern .',
#  "i think there 's a sign on my forehead that saysuse me",
#  'the shrimp was so good they named their team after it .',
#  'a cartoon illustration of a fox looking angry .',
#  'pass is long but not difficult .',
#  'actor walks the red carpet during film festival .',
#  'a cartoon illustration of a doctor with an idea .',
#  'young girl in bed holding the sheets looking scared',
#  'a shelf in the bathroom packed with linens picked up at markets , and photos of sculptor .',
#  'formal form fitting coral formal dress .',
#  'politician decorated the white house for western christian holiday',
#  'biological species with a beak full of insects',
#  'rhythm and blues artist as a child',
#  'this cat should be in a movie',
#  'drawing the balloons on the crumpled paper',
#  'overlook , in the far distance .',
#  'decorative panels in the style',
#  'animal perched on a branch',
#  'this turtle tucked next to a pot of ivy and other plants belonged to mother .',
#  "dance group unity perform on stage during the third live show of 2014 's",
#  'adventures of a subversive reader',
#  'view over a coffee plantation',
#  'singer holding a microphone during a concert performance',
#  'musical artist performs during the festival',
#  "person sent feet of ocean water into a city as the storm 's center passed miles away .",
#  'a city from the high street',
#  'actor is photographed for trade journal magazine during festival',
#  'stone - like porcelain grotto with all the chip and moisture protection of hard - wearing ceramic .',
#  'large outdoor setting on the deck',
#  'abstract background with a cup of coffee .',
#  'young person playing the piano with both hands',
#  'person looks so cute in this green dress holding her award at awards .',
#  'guitarist and bassist for protopunk artist , hard rock artist performs live .',
#  'blurred people in the train',
#  'royal purple -- a favorite jewel tone of ours , especially when paired with teal .',
#  'snow covered , colorful mountains with the rising moon above',
#  'images from the basketball game .',
#  'river overflows onto a section .',
#  'according to the company , the minerals removed from the sand through mining comprise % of the dunes total volume .',
#  'industry trim just got schooled with these book shelves .',
#  'i have seen this many of times and never fails to take my breath away !',
#  'politician and his wife descending the steps to their motor car .',
#  'fireworks display for new year and all celebration',
#  'the above box was among several gold pieces by the late artist stolen .',
#  "eventneeded urban design because it 's a city says organisation founder",
#  'a baby girl stuffs lasagna into her mouth as she sits in a high chair .',
#  'athlete watches his shot closely in the match at sports league championship .',
#  'bride heading to the church',
#  'small tower on the hill',
#  'a car with parking ticket',
#  'biological genus is a reptile endemic .',
#  'film producer and actor pose at the after party for the premiere .',
#  'wedding dress from the atlas',
#  'seamless pattern of the fireplaces',
#  'mural by the train station',
#  'graphic black and white drawing of a happy little boy and girl',
#  'magazine is available to read .',
#  'how to make a fake fireplace out of paper',
#  "actor teamed a casual striped jumper with a pleated skirt for the launch of her sister 's bridal collection .",
#  'a couple exchanging the garlands at their wedding',
#  'family with little boys playing in the grass on a summer meadow - they have a football',
#  'i am digging this color .',
#  'polar bear stands on the edge of sea ice , looking up with reflection in the water',
#  'digital art selected for the #',
#  'humans and chimpanzees share percent of the same dna .',
#  'a christmas vector illustration in shades of blue and white with a large shooting star above tree lined snowy hills with room for text',
#  'food around the world , hand drawn and colored vector vector graphics',
#  'women take a break , checking their phones , as they celebrate the night',
#  'actor named most beautiful woman in the world',
#  'reinforcing mesh and plaster on a building',
#  'driving through mountain range in december',
#  'a model walks the runway at the presentation for fashion week spring .',
#  'best - lettering typographical vector background .',
#  'photo - master and commander',
#  'love this window display for business .',
#  'stairs to the top of the bell tower',
#  'complete package : the new owners will have the chance to buy collection of paintings , furniture and accessories',
#  'young man sitting on front of laptop found a solution .',
#  'message in a bottle thank you notes .',
#  'players celebrate a goal versus football team',
#  'the silhouette of male hands opening brown beer bottle',
#  "woman 's hands on the keyboard of the piano",
#  'still life artwork , by - my favorite painting',
#  "a dog in a new year 's dress",
#  'a poster from when artist played in hometown .',
#  'the queen in a pink coat , holding a bunch of flowers',
#  'shelves around the kitchen for arranging cups and plates',
#  'flags with a gazebo in the background',
#  'person attends the performance and album signing .',
#  'locked down shot in the foreground on an overcast day',
#  'lovely illustration of a lion in flat cartoon style .',
#  'tracking shot of a pod of dolphins with baby',
#  'soccer player scores his sides first goal during the group f match .',
#  'located miles northwest is the most accessible mountain lake .',
#  'map in gray on a black background 3d illustration',
#  'determine the number of excess labor hours daily that will need to be adjusted current paid labor hours less desired paid labor hours - reduction needed',
#  'puzzle of majesty and spike the dragon .',
#  'home design : plans with regard to really encourage',
#  'rear and grounds of the property',
#  'the cockpit of aircraft model',
#  'artist performs on stage at festival',
#  'a girl and her family , migrate .',
#  "english civil parish or bust ... whoever is headlining the iconic festival can expect person heckling them all night if he 's not on the stage .",
#  'turn a regular dining room into a den with a change of paint and furniture .',
#  'vector silhouette of businessman on a white background .',
#  'american football team running back american football player has been ruled out of the game',
#  'sports team outside person person forces a fumble from american football wide receiver during the first half of their game .',
#  "she 's person by book character",
#  'person and actor attends the show as part of event >',
#  'a man wades through his flooded driveway outside his home',
#  'ground squirrel on log with yellow flowers and grass',
#  'huge flock of sheep grazing .',
#  'some new friends in the mountains .',
#  'decorations in country for western christian holiday : ornaments christmas wreath a reason to craft',
#  "if you wore pumps with this dress you 'd want to be sitting .",
#  'landing as seen from the water , 1930s',
#  '... this honeybee got down to business , really got into the work of getting nectar .',
#  'the organisation - run building is at the former site in the town .',
#  'illustration of a rabbit and radish',
#  'a-bedroom town house has hit the market .',
#  'keeping healthy ; a fan of green juices , person tried one of the purple variety',
#  'illustration of a price tag with figure and percent',
#  'cute kitten drinks milk , isolated on a white background',
#  'a building under construction will house when it starts up next fall .',
#  'the intense lights shine off the surrounding buildings .',
#  'yellow pear isolated on the white background',
#  'political party but t - shirts for holiday .',
#  'this is the interior hall .',
#  'business and skyscrapers along river',
#  'lanterns outside the main hall of tourist attraction',
#  'actor and person attend premiere',
#  'a real estate sold sign hangs in front of a west - end property .',
#  'kick your new year off right with this huge list of the must - read books !',
#  'mom reading a book with her baby girl',
#  'a model walks the runway at the fashion show during event .',
#  'family photo session on the beach featuring a handpainted chair !',
#  'accessories for a red dress',
#  'portrait of beautiful happy female friends in the city',
#  'close - up of a gardener splitting perennial plants',
#  'golden a letter logo for your company .',
#  'actor attends the gala screening .',
#  'athlete takes a snap during the game against american football team .',
#  'person said he brought craftsmen to work on the house .',
#  'pop artist performs onstage during the awards14 .',
#  'lying on the white desk',
#  'shiny happy person : finalist has met with music video performer and pop artist as she prepares to launch her solo career',
#  'a biological species at a festive candy cane .',
#  'shape animated on the admin map of the globe',
#  'bride looking into the distance',
#  'our stand up desk can be customized for just the right working height for you .',
#  'a reflection of the sole flamingo in the lagoon',
#  'an aerial skyline at night',
#  'a warthog running on grassland',
#  'a huge cake to be cut by local leaders and workers to celebrate the 60th birthday of their leader .',
#  'i raised a guide dog this was her as a baby .',
#  'portrait of a large group of happy and diverse business people who are standing together , isolated on white .',
#  'a downy woodpecker photographed by person .',
#  'american football running back at the taping',
#  'view off in the distance',
#  'a view towards the cliffs',
#  'professional road racing cyclist at the summit on the final lap',
#  'automobile model at the stop sign',
#  'feet of hanged man over the rotten swamp',
#  'celebrities attend the fall fashion show during fashion week in the salon .',
#  'house is a country house with formal gardens south - east in the valley',
#  'pop artist talking with fans whilst leaving his hotel .',
#  'person is , no offense to person of course , my favorite from the band .',
#  'actor arrives at the premiere',
#  'a horse is taken for a run on a road .',
#  'vector illustration of a greeting card for celebration .',
#  'beef steak served with fried egg , chips and salad on a restaurant table',
#  'need to update the bathroom ? a new vanity is a great way to change your style .',
#  'an acacia tree is silhouetted against the sunset',
#  'a tractor is driving between lines of hay .',
#  'wild kitty matching tattoo on both of calves .',
#  'the yellow sands where the invasion happened : modern images',
#  'busy lady : the blonde beauty regularly shares her workouts on social media and juggles staying on top of her fitness with her thriving career',
#  'an eye in the sky',
#  'aerial view of industrial park in the winter',
#  'needle in a sewing machine close - up',
#  'surrounded by several elected officials , person speaks of recent events against the community .',
#  'actor attends a press conference for his new new movie',
#  'a man surfing in the background',
#  'ice floe on top of a stone',
#  'footballer reacts during a match against football team as part .',
#  'emotions running high : person gave an emotional performance in concert',
#  'picture taken at the seating area by the lake while walking through the gardens .',
#  'folk rock artist singer - songwriter , playing the guitar while sitting on a chair during a concert',
#  'eye and eyelashes closeup of the eye of a cow',
#  'psych folk artist poses for a portrait',
#  'mother putting baby to sleep at the crib',
#  'young businessman commuting to job .',
#  'daisies in an aerial view',
#  'spot the butterfly in the wild meadow',
#  'the big road sign against clear blue sky',
#  'handle the universe with care',
#  'project focus carrying cargo to and from the space station',
#  'basketball player of the national basketball throws the ball during a training session .',
#  'person sits in his car outside a house .',
#  'portrait of a middle age woman during autumn , yellow maple tree at the back during fall season',
#  'boy band artist in concert .',
#  'statues of noble person and person',
#  'actor attends los angeles premiere of red carpet arrivals',
#  'glow in the dark bedroom',
#  'a large home of colonial architecture',
#  'warming up : members of the team during a practice session',
#  'the water is so clear , you might spot tiny little fish scurrying in the water',
#  'farmers transporting charcoal on a bicycle .',
#  'a map with just a little bit showing in the north',
#  'lance installing wainscoting on the kitchen island .',
#  "american football player celebrates throwing the winning touchdown pass in monday night 's game against sports team",
#  'the truck is first spotted at a beach .',
#  'field in front of the bistro',
#  'christmas bells with red bows on a white background',
#  'i need this picture at my wedding !',
#  'one of my favorite plants in walking stick .',
#  'musicians give a private concert for tourists in a private home',
#  'a bride holds a bouquet of roses',
#  'south korean metropolitan city : modern sculpture at the entrance in the neighborhood',
#  'a big sea breaking onto the golden sandy beach',
#  'religious leadership title speaks onstage .',
#  'members compete in amateur wrestling in style',
#  'a woman standing beside a sofa on grass',
#  'if you never break ... quote tattoo .',
#  'a gallery exposed ceilings , detail',
#  'illustration toa week of kindness',
#  'for sale sign thin line icon for web and mobile minimalistic flat design .',
#  'police officers engaged in public order training',
#  'tools that will turn your cooking into magic',
#  'the designers updated this small kitchen with a cutout in the wall for a small bar .',
#  'this image was made by vector graphics editor software',
#  'tv personality hosts a dance party',
#  'actor arrives at the world premiere .',
#  'another view of the red rocks',
#  'the poster for the upcoming tour this summer .',
#  'geometric tile and stripes in the powder room .',
#  'stretching stick figure isolated web icon on a background .',
#  'people were stuck on a rock face',
#  'industry by the available in colors',
#  'file photo dated at the scene , as detectives continue to question',
#  'human heart in a cage .',
#  'statue of monarch in front of a section of the wall .',
#  'national team runs during training ahead of the international friendly match against england in german city .',
#  'orange and white contrast on a smooth black leather strap .',
#  'rule the game with higher visibility',
#  "invitation for a little girl 's tea party",
#  'person and his son share an office on farm , where their family has been growing peaches for photo',
#  'private yard with hot tub on deck , perennial gardens and creek flowing through the yard !',
#  'a mural , street art or graffiti of spoken word artist on the streets',
#  'christmas cookies and milk with decorations on a wooden table',
#  'capturing the beautiful wedding ceremony by person',
#  'big eyes on these moths',
#  'a glazed ceiling invites you to gaze up at the towers , which begin from a garden on the third floor .',
#  'man relaxing by the tree in the park , dolly shot',
#  'flying bus in the city traffic , rush hour',
#  'actor arrives at the premiere',
#  'a portrait of an old man',
#  'digital art selected for the #',
#  'vector illustration of the snowman with a broom in his hand and an old pot on his head',
#  'lightning strike on the cloudy dark sky',
#  'a triangular structure of wood and glass inside the grounds of an old gothic building .',
#  'keeping your house cool in the heat - solar panels',
#  'image may contain : person , playing a musical instrument and on stage',
#  'biological species resting on a foliage',
#  'pop artist attends the show during spring summer',
#  'be very careful around downed power lines , or trees which can hide those lines .',
#  'the colorful illustrations of musical artist',
#  'soldiers engage targets in a vehicle',
#  "how to help babies sleep : what to do when you 're exhausted and you need help with not sleeping well !",
#  'woman in front of the sea',
#  'mapping - map of obesity in the us',
#  'y letter colorful logo in the circle .',
#  'automobile model bursts into flames on a quiet street',
#  'some of the items stored',
#  'a cartoon illustration of work of fiction waving',
#  'you merely adopted the wealth i was born into it , molded by it .',
#  'cricket player became only the player to smash double centuries in a single venue as football team dominated region .',
#  'person and his team preparing programs for the children',
#  'garment & glitter dress , perfect for the holidays !',
#  'a village in the mountains',
#  'biological species in a tire',
#  'vintage stove may be the way to go to fit ovens in our kitchen .',
#  'illustration of automobile model brandishing holding a flag set inside crest shield with stars and stripes',
#  'customers shop for clothing following the opening of first store',
#  'sports team running back person carries the football during a game against sports team .',
#  'why should boys have all the fun ? person strikes a funny pose on the sets .',
#  'woman yelling into a megaphone',
#  'old invalid banknotes as a background',
#  'trees , building , and human body are closely related to each other .',
#  'a guide to living and working in this city',
#  'a car is balanced on a rock in a developed area .',
#  'football player poses during the team presentation',
#  'flag blows in the wind .',
#  'hands in a circle isolated on white background .',
#  'beautiful young couple embracing , standing on a pier near water',
#  'photo of a guest room at the hotel',
#  'artist takes his wheels for a spin .',
#  "mermaid 's tail at person on 39 .",
#  'man in a pensive pose .',
#  'white kittens on the road',
#  'a woman plucks a pear from a tree .',
#  'author attends a private view',
#  'view from above over the city of person with buildings , hotels , trees and mountain',
#  'couple with their daughter sitting in the waiting area of a hospital',
#  'sunlight breaks through the trees on a summer day .',
#  'one of these rooms has a bathroom with bath with shower over , the other two share a shower room .',
#  'celebrity , soft rock artist and hard rock artist appear .',
#  'actor entered the venue a bit late and was seen greeting everyone at the event .',
#  'common symbols can be seen in a dream with strange items , so as in the case with person',
#  'biological species hunting in the arctic snow in october',
#  'daily paintings : rainbow - shows steps in creating the painting - excellent',
#  'girls going to a birthday party with balloons in hand',
#  'the skyline at sunset , seen',
#  'cricketer celebrates the wicket of martial artist',
#  'rugby player ties up a young fans shoe lace during a training session .',
#  "if the path before you is clear , you 're probably on someone else 's .",
#  'a view of the chateau from the coach house',
#  'my heart is a wolf ruled by moons ...',
#  'a model walks the runway at the fashion show during event .',
#  'dog sleeping next to the wall',
#  'the eagle hunts from above',
#  'man behind wheel in a retro car',
#  'biological species on a tree branch during winter',
#  'large , white coloured dogs , sitting in the shade',
#  'if your space is too small for biological species , or you just want to try something out - of - the - ordinary this year , give one of these clever diy ideas a go .',
#  'the raised bridge at white nights in the city',
#  'example of a minimalist family room design in other',
#  'grasslands are extremely hot in summer and really cold in the winter .',
#  'a phase diagram summarizes the conditions at which a substance exists as a solid , liquid , or gas .',
#  'image may contain : person , playing a musical instrument , on stage and indoor',
#  'cute couple : the pair were holding hands as they headed home in style',
#  'visualization of a house with a swimming pool',
#  'organisation founder and football player on the touchline',
#  'dice with letter c : character on the cube',
#  'boxer lands a punch on boxer .',
#  'decorative portrait of an animal .',
#  'close - up of blue eye of an old woman aged 80s',
#  "close - up of a young woman 's eye",
#  'see classic vehicles on display when show returns',
#  'cross section of a tree trunk in a horizontal format',
#  'heart of kisses for holiday .',
#  'illustration of a boy watching an insect',
#  'a set of white arrows in the colored circles on a white background',
#  'photo of a traditional water fountain landscape .',
#  'actor walks the runway at the fashion show during event .',
#  'person and battle for the ball',
#  'country artist performs day of festival .',
#  'coastal white - story exterior home photo with a hip roof and a metal roof',
#  "i 'm tired of wearing out lesser boots .",
#  "these french dish with food may look complicated to make -- but believe us , they 're surprisingly simple .",
#  'a map showing approximate areas .',
#  'large breeds or small breeds , all dogs need a lot of love , care and affection to prove themselves as good pets .',
#  'girl shows on a toy they would like',
#  'charity is approached via a winding mountain road',
#  'happy weekend inscription on a blue background vector art illustration',
#  'rustic swamp with a tree',
#  'it takes light from the sun to reach the earth !',
#  'talk about a town on the water',
#  'golfer attempts a putt during the first round',
#  'one of the many statues , that honour illustrious ancestor .',
#  'actors walk the red carpet ahead of the screening during festival at person .',
#  'a map of the country',
#  'set of signatures isolated on a white background .',
#  'person performs live on stage at a city',
#  'this homemade costume for women entered contest .',
#  'we eat a lot of candy !',
#  'the back exterior of the home where there is also a grill .',
#  'night winter sky seen through the frozen window .',
#  'not much space in the car',
#  'sharp edge and rigorous modern forms are trendy in the entire fashion industry , so and when it talk about hairstyles .',
#  'black and white cows on a farm',
#  'view of the pipe on the roof installed by expert',
#  'man of races during recurring competition',
#  'ask owner for photos of the car',
#  'property image # , walk to the beach',
#  'window frames : narrow and symmetrical .',
#  'era uniforms , equipment and memorabilia is on display during the 12th annual luncheon honoring country',
#  'a city going , next to the lock .',
#  'this woke nail art is making us want to throw our manicured fists in the air and inspire change',
#  'the bridge across 16th street .',
#  'top off a crop top and high - waist trousers with a cropped bomber .',
#  'the kayak allows to reach beaches that would certainly be accessible on foot , but after long walks .',
#  'hand drawn in sugar skull in a lovely frame .',
#  "remember this closet ? it 's person from film !",
#  'could person and a group of other men be behind the crime ?',
#  'photo of shoppers browsing in the new shop',
#  'i chose to leave spaces between groups of three .',
#  'dressing at the office has never been that easy .',
#  'solid gold presidential with mother of pearl face & diamonds .',
#  'hands playing a gentle piece on a beautiful grand piano .',
#  'full refurbishment of an apartment',
#  'biological subspecies climbing down a tree',
#  'the bleachers on top have been replaced',
#  'a panoramic cityscape with the building at dusk .',
#  'a golden oak , nineteenth century , break front open bookcase with adjustable shelves',
#  'custom made hoodie - with reflective piping - get us to add your custom pattern on to these ones',
#  'person , along with his daughter , and person , made the long trip from person last week to compete in annual regatta .',
#  'bud close - up on a background of spring garden',
#  'gothic skater dress sewn by the finished garment',
#  'pier lined with tires as fenders for the boats , sea and mountains in background',
#  'an awards ceremony took place after completion of 210th competitions',
#  'actor attends the premiere of at festival .',
#  'black and white illustration of disease of person',
#  'additional photo for property listing at cloisters',
#  'close profile of man , walking along the wall , steadicam',
#  'model returns to her car after leaving the gym .',
#  'alpine skier holds her dog during a news conference in january .',
#  'image may contain : person , riding on a horse , horse and outdoor',
#  'happy new year poster with a champagne bottle',
#  'hand drawn watercolor isolated romantic floral compositions , made like a floral borders with pink roses , leaves and other flowers on the white background #',
#  'actor arrives at the screening held',
#  'lack of storage space is definitely not an issue in this large laundry room .',
#  'fossils on the rocks beach royalty - free',
#  'tree grows at the hill and waves',
#  '# makes a pass against sports team .',
#  'hands of the old man beggar on a black background',
#  'riding boots taken to the next level .',
#  'island is shown in this undated file photo .',
#  'aerial view over cooling towers of nuclear power plant close to a city',
#  'the many bags of celebrities at the couture week fall',
#  'the marketplace at the end of our tour',
#  'the equestrian statue of military commander',
#  'gangsta rap artist opened up about being a black man and his relationships with pop artist and music video performer .',
#  'fairy garden in a tier fountain by person',
#  'national register of historic places location has some beautiful old homes',
#  'an aerial shot of the site .',
#  'person is brought down with the help of person .',
#  'dog spilled paint and leave muddy footprints on the floor',
#  'actors at the premiere of - photo',
#  'room # - queen bed and is best suited for a couple',
#  'left hand got pain on wrist holding a retro dumbbell isolated on white background',
#  'view of an unfinished building with only beams for walls',
#  'black and blue : person wore a blue t - shirt and button up combo , completing his look with a pair of jeans and black vans',
#  'things that are orange the blog for all things things that are orange',
#  'fans celebrate as surfer is given a key to the city tuesday .',
#  'a vehicle drives toward the camera below mountain range',
#  'baseball pitcher throws against sports team in the first inning of their baseball game',
#  'a surgeon is ready for work on a green key',
#  'galaxy over the mountain in winter',
#  'day of the dead holiday seamless pattern with sugar skulls .',
#  'rubble from demolition at the old building , now',
#  'family traveling in the car .',
#  "free - kick against football team was one of the finest set - piece goals we 've seen all season",
#  'movement of continents over millions of years',
#  'summer you might end up just doing your hair like this .',
#  'actor attends the world premiere at theater',
#  'fans attend the concert at the university last july .',
#  'lifting the car by tools for maintenance in garage',
#  "football player scores his team 's second goal during the first leg match .",
#  'person stands outside the office block taken over by activists .',
#  'portrait of hard rock artist , guitarist , photographed before a live performance',
#  'navy blue pants with a high waist',
#  'trendy girl in a short dress on a floral background -- stock vector #',
#  'painting artist - from the series',
#  'sunset over a field of fictional object and wild flowers above beach',
#  'pop artist attends a live performance from the cast of person .',
#  'carrying mountain bike over rocks on the mountain top',
#  'photos of action film on the beam',
#  'camera attached on the outside of a car while driving in the meadow',
#  'used for transport of sugar cane and slaves , old locomotive and tender , series',
#  'soft rock artist , actors attend the premiere .',
#  'image may contain : person , on stage and playing a musical instrument',
#  'image may contain : person , on stage , playing a musical instrument , guitar , concert and night',
#  'beautiful woman dancing barefoot in a long blue dress -- stock photo #',
#  'comedic man plays on a computer at home photo',
#  'a helicopter coming into land on ship',
#  'competitors receive commands from a crew chief before exiting aircraft model during armed force',
#  'beautiful venetian street with old houses in a sunny summer day',
#  'the ornately tiled and decorated frontage',
#  'city in the sunny day',
#  'the winter storm : preparing for and surviving a blizzard',
#  'a hat for the tea party',
#  'ruins on the banks close',
#  'golden cup on the podium .',
#  'a basketball is falling through the rim .',
#  'video from the window of a moving train .',
#  'sheep in the style of person',
#  'gold and silver hearts on a black background .',
#  'rain boots are university must - have .',
#  'glow in the dark flower',
#  "bird of prey ... i think this is a plug in that i 've been looking for .",
#  'young boy carrying water on a bicycle in a village',
#  'person was voted out in a right stitch up',
#  'black and white landscape photograph .',
#  'a model presents a creation of a designer during fashion week .',
#  'a man rides a scooter on a small road',
#  "a beach hut advertised in an estate agent 's window",
#  'for the love of horses',
#  'person performs during day of the festival .',
#  'transition into fall with this nautical inspired off the shoulder top !',
#  'employees work on automobile model at transparent factory',
#  'singer of synthpop artist performs on stage at show at theatre .',
#  'actor speaks during the press conference',
#  'before : a home prior to it being renovated .',
#  'not even a paved road in site !',
#  'questions are already being asked about how fans were able to bring flares , which are prohibited into the ground',
#  'exploring the streets of the towns around a city leads here',
#  'these are flying ducks from the 1950s which graced homes .',
#  'large - scale mosaic this refers to the juxtaposition of different habitats within a landscape , such as grasslands and wetlands adjacent to woodlands .',
#  'every seed contains a living plant ready to sprout as soon as it encounters the proper conditions for growth .',
#  'a train with wagons arrives at the railway station on rails .',
#  'all good here : vet seemed to be in good spirits as she strolled with women',
#  'water flows from the roof after the rain .',
#  "vintage makes me wish i 'd spent learning how to make clothes instead of jewellery .",
#  'referee shows football player a red card .',
#  'down into the city from the slums .',
#  'we put together a tutorial for drawing eyes .',
#  'round bolster * want additional info ? click on the image .',
#  'illustration of a woman in front of the building on a white background vector',
#  'thin font on a blurred background .',
#  'the pub in the village',
#  'american football team defeated american football team 17 - 16 in their first ever playoff game .',
#  'person attend sports league championship .',
#  'love this short hair cut on pop artist',
#  'orange blooms that are starting to turn apricot then pink with age .',
#  'the trail through the woods',
#  'students at a critical thinking class',
#  'a sunny day has villa with lamp , plants and grasses',
#  'these were so popular in the 60s and so easy to sew !',
#  'truck carrying hay in his body .',
#  'a tropical smoothie on a red napkin',
#  'not too heavy : person held onto north with both hands as the child slept',
#  'cumulus clouds are gathering on sunny sky before the rain',
#  'uk constituent country £ 5 , £ 10 notes and pound coins , legal tender a city',
#  'activists of forum for indian state wrap a flag around a dog during a protest',
#  'close up of arms holding a soccer ball with flag background',
#  'colorful photo of a blue sky and trees in a forest covered in frost during winter',
#  'happy father and son lying on the grass with a soccer ball in the countryside',
#  'a young man with a braided hairstyle',
#  'motorcycle racer after wining the race .',
#  'view from under the umbrella on a clear summer day .',
#  'aisle of style of runway to wedding !',
#  'a long straight road going thought the desert to some mountains',
#  'person examines a quilt as she judges entries',
#  'long walks on the beach !',
#  'vector illustration of the sun symbol',
#  'tents in the middle of desert with mountains in the background , on a sunny day',
#  'the statue is an instantly recognisable symbol',
#  'passengers get off the bus .',
#  'pattern in the small flower',
#  'actor arrives at the premiere',
#  'cherry blossoms around the gate',
#  'person in the pink shirt',
#  'the plug - in electric car on display at show',
#  'triangles of the neck ppt year',
#  'a pile of socks are available for students that need them .',
#  "football player tries his luck at goal with a left - footed drive that fails to find the back of their opponent 's goal",
#  'make sure you are getting all the nutrients you need .',
#  'the most famous apple tree in the world ?',
#  'bunch of grape at the market',
#  'organisation founder has no right to talk on farmers',
#  'northern lights , polar light or aurora borealis in the night sky time lapse over island',
#  'actor , actor , music video performer , guest and dancer are seen .',
#  'fresh river go over the cliff , water drops splash',
#  'sits majestically amidst acres of wooded parkland .',
#  'person , actors attend the build series to discuss the new film .',
#  'actor and person attend the premiere .',
#  'person using crutches on a runway',
#  'the before and after on this clock is amazing ... what a transformation .',
#  'old beautiful car near the water',
#  'frangipani on the isolated white background .',
#  'the young man and the girl going around on green field',
#  'country at confluence along road',
#  'person , who hails , works inside her recreational vehicle on one of her acrylic oceanic paintings .',
#  'tv personality and her daughter attend awards .',
#  'tips for planning a successful corporate holiday party',
#  'actor does not look happy in this photo of her and organization leader at an event',
#  'close up on an ice cube .',
#  'mother tying a hat on her baby boy .',
#  'fictional object is biological species produced by person',
#  'benefits of handmade tile - on the blog now !',
#  'sheep -- the most common sight along a city .',
#  'tennis player competes against tennis player during day of the tournament',
#  'a large 17th century naive oil painting of monarch',
#  'fashion designer poses backstage at show in the tent .',
#  'shot of a creative dining room with a big table and different chairs',
#  'heart shaped cookies falling out of the red bucket',
#  'actor and person attend awards .',
#  'family members raised their glasses with wine at the festive dinner',
#  '# handles the ball during the preseason game against sports team .',
#  'trimming a tree in front of a commercial building',
#  'a fashion illustration of pop artist at awards .',
#  'barn door with a built full length mirror .',
#  'actor and her husband professional hockey player make an in - store appearance ...',
#  'image may contain : person , on stage , playing a musical instrument , night and concert',
#  'dream pop artist performs live .',
#  'a lamp on top of an arch .',
#  'making noise : the main singers , seen are poised to tour country with their show this month',
#  'small boy playing with stones on a beach',
#  'a sudden storm hits a canyon',
#  'caucasian kid with a donkey',
#  'interpretation of a dream in which you saw helicopter',
#  'illustration of a boy catching butterflies at the flower garden',
#  'the chairman hopes the falcon will find a mate in spring .',
#  'silhouette of the girl at night on the river bank',
#  'studio still life close up female hand inserting a piece in a partially completed jigsaw puzzle',
#  'overhead view of a prickly cactus plant in a pot',
#  'wave of river and little birds flying over the river',
#  'toucan in rain forest with tree and foliage , early in the morning after rain',
#  'sample views of the brochure',
#  'an outdoor atrium along wing of the home .',
#  'a motorist at a station pumps gas .',
#  'pasta in the form of animals and a wooden spoon on a blue background',
#  'image taken from page of people .',
#  'pop artist at a recording session',
#  'contemporary christian artist attends the movie premiere',
#  'the smart mobile bars in the streets',
#  'ghost in the window #',
#  'garment and keep : how to shorten your denim jeans like a professional tailor',
#  'actor attends the launch party',
#  'decay & a tuned car',
#  'actor attends the los angeles premiere',
#  'a worker rolls tobacco into a cigar at a facility',
#  'palm trees along a path',
#  'while i love me some summer , i look forward to wearing my favorite coat again .',
#  'image may contain : person , riding on a horse , tree , outdoor and nature',
#  'set of beautiful watercolor flowers and leaves on a white background for your design .',
#  'dogs playing in a dog park',
#  'the large entryway is open concept and in a bright reddish - pink color .',
#  'person attends premiere during festival .',
#  'person performs at the annual fest of university',
#  'people are seen amid heavy fog on the outskirts .',
#  'muzzle of a black horse .',
#  'illustration of a hand holding a trophy',
#  'planets in a space against stars and nebula .',
#  'person was first used for the cover of the passport',
#  'the girl dances on the beach at sunset .',
#  'smiling couple with young child picking out a pumpkin at a pumpkin patch .',
#  'the lawn sloped to the back fence - a challenge for the lawnmower but an invitation to me !',
#  'american football player hangs back to defend .',
#  'actor , actor and comedian attend the premiere .',
#  'this painting by painting artist was stolen it has recently been retrieved .',
#  'organization leader and chef at awards',
#  "couples are flocking to the - room hotel on an island to enjoy a night inside the colon , saying it 's",
#  'after perching in the wrong spot , a red - shouldered hawk is dive - bombed by a white - tailed kite',
#  'artist watches his wife perform during the festival',
#  'cartoon illustration of a human skull with a burning cigarette between its teeth .',
#  'detail photo of a coin from the year',
#  'football player puts in a tackle on footballer during clash',
#  'a tractor collecting up bales of straw from a recently harvested field',
#  'the village on the way',
#  'i love to interest .',
#  'person carries the ball against a city in the game .',
#  'photo of students at an event',
#  'circles and stars in a festive , seamless gold and white pattern',
#  "soccer player has told tv network that he is relishing the opportunity to take on last season 's winners .",
#  'an exterior view of the building .',
#  'drawing of a sheet of paper with deck chair and umbrella illustration in hands .',
#  'image may contain : person , on stage , playing a musical instrument and guitar',
#  'walking in the street i saw this girl practicing dancing at the curb .',
#  'family walking on the beach',
#  'clothes hanging on the clothes line owned by photographer',
#  'players are seen in this undated image .',
#  'wooden egg in a natural shell',
#  'horse runs on the sand slow motion',
#  'a view looking down the ridge , about midway to the summit .',
#  "there 's a story behind every door .",
#  'a garden within the premises',
#  'director arrives for the premiere',
#  'time lapse , the sunset with sail on the river in garden',
#  'happy couple meeting on the street at night',
#  'tv host attends award honoring fashion designer .',
#  'man on wheelchair with a female nurse for assistance',
#  'solo album , was released in february .',
#  "today 's face was the fourth f children born to her parents",
#  'image of bamboo isolated on a white background .',
#  'person watches his drive during the - cardinal meet .',
#  'i love the vintage trunks when they are used in home decor',
#  'a woman stands on a rock with a view of the drainage',
#  'peace activist performs on stage with wings he plays a guitar',
#  'indigenous people blocked the only highway with tree branches .',
#  'getting higher on the mountain .',
#  'stock vector illustration yellow ball for billiards isolated on a transparent background .',
#  'head and shoulders detail of the ancient sculpture',
#  'happy young woman open a christmas gift with her daughter on the sofa near the fireplace',
#  'relaxed : the star looked laid - back on set following his family vacation',
#  'keeping hydrated : she carried with her a bottle of water to keep her healthy and hydrated in the sun',
#  'gentle paths lead visitors through the site , while split - rail fences protect newly planted native plants .',
#  "viewer - submitted photo of a downed tree following this weekend 's storms",
#  'sports team left olympic athlete warms up in a game , thursday',
#  "little boy 's graffiti in the bathroom mirror",
#  'golfer , captain of the team addresses the media at the announcement of his wild',
#  'automotive industry business stalking through the jungle',
#  'politician and actor pose at awards .',
#  'how to draw a deer for kids',
#  'wooden table and sofa in the cockpit of a boat',
#  'black hands of a man held together in a heart shape in front of blue sky background .',
#  'flag on a boat at sea',
#  'actor is absolutely chic in a black dress from person',
#  'luggage for a round the trip',
#  'trees , wind and blue sky in good weather all the movements',
#  '4k zoom , elements of this image furnished by spacecraft manufacturer',
#  'built in the fourteenth and fifteenth centuries , this timber framed medieval building is the hospital',
#  'artist performs on stage at festival',
#  'halloween costume ideas for guys with beards',
#  'say cheese : this dog appears to be enjoying a lay down in the summer sunshine as he smiles for the camera',
#  'tourist attraction has a fantastic facade .',
#  'goat eating happy green lush grass on the summer meadow .',
#  'image titled install operating system on an external drive step',
#  'the flag flying in front',
#  'independent entrance into the living room',
#  'the best summer style secrets and outfit ideas to steal from curvy girls like celebrity in this all - white ensemble .',
#  'hip hop artist attends build to discuss person .',
#  'pins and needles trellis dress view more of this outfit here .',
#  'players line up for the national anthem',
#  'shot in slow motion at 60fps through filming location looking up at the buildings',
#  'general view of the crowd .',
#  'person on the wave of the winter ... so far .',
#  'portrait of a sad , white - red - haired cat',
#  'astrological symbols in the circle .',
#  'the crooked wood framed house',
#  'local authorities are parked outside the apartment building of man',
#  'colourful earth globe against a black background .',
#  'rufous - tailed hummingbird sitting on a nest',
#  'young woman walking alone with eyes closed in a busy city .',
#  'actor arrives for the premiere',
#  'get lost in a private paradise .',
#  'a bushfire burning orange and red at night',
#  'close view detail of a woman with red lips',
#  'built this historic building once served as a tavern and public library system .',
#  'a monument honoring soldiers at the complex was cleaned after being vandalized .',
#  'blackboard with a chalk and the shape drawn onto .',
#  'young man throwing out the garbage and smiling isolated on white background',
#  'the audience watching the concert on stage',
#  'heavy snow fall in the forest',
#  'fitness girl with dumbbells on a dark background',
#  'diy : how to remove the existing label from wine a bottle',
#  'person playing a game of marbles',
#  'small pot of strawberry jam on a wooden board',
#  'festival has become a very popular annual event for locals and tourists alike',
#  'until the 1970s , bodybuilding had its tiny audience worldwide .',
#  'my little auto mechanic super set toy .',
#  'property image # , walk to the beach',
#  'wedding photography and the price of - by mrs twig',
#  'illustration of month with intricate calligraphy for the celebration of community festival .',
#  'the beautiful girl the ballerina in a pink dress with flowers on a white background photo',
#  'issue , featuring actor on the cover',
#  'a logo sign outside of a facility occupied by computer hardware business',
#  'image may contain : person , smiling , playing a musical instrument and on stage',
#  'the little girl , who may be depicted in this image with a baby , told her biological father that would routinely beat and abuse her',
#  "the aurora borealis came out in all it 's beauty .",
#  'blue fronted biological suborder on a rock cleaning its eye',
#  'property image # villa with heated pool , city views & a walk',
#  'master bathroom with jetted tub',
#  'paint roller with a strip of paint on the blue wall .',
#  'injured cat to lead organisation to her newborn kittens',
#  'no one sleeps like a cat sleeps',
#  'woman in hammock using laptop swayed by a breeze between over hanging palm tree and white sandy beach',
#  'aerial view of the city with densely packed residential homes and buildings',
#  'majestic lion with a shield and trident , other tattoo',
#  'high angle view of boys crouching by bucket at the edge of a river',
#  'teenage boy trying on shoes in a shoe store',
#  'your host poses at the north rim .',
#  "men 's cut with a fade",
#  'actor attends film premiere held .',
#  'young family sitting on a large tree and uses the tablet',
#  'person : ready for the rain .',
#  'vector illustration of an abstract background with music notes .',
#  'biological species through the air',
#  'a worker waits to rescue sheep from the farm .',
#  'a class train at speed',
#  'a man is led away by police .',
#  'antique c1920 photograph , family members pose in front .',
#  'garden shed in teamwork with person , who build the house',
#  'a briefcase full of cash in dollar bills',
#  'gothic structure and the shrine',
#  'an elderly but very athletic busker .',
#  'a man types on a laptop on his desk .',
#  'a child draws with marker on first saturday',
#  'view northward to the church across a valley clothed with trees and shrubs .',
#  'car fire - blazing car',
#  'in the summer sky hovering kite',
#  'baseball player of the band performs live during a concert .',
#  'across the pond by person',
#  'keeping warm with reality tv program : the family had a busy day as they were spotted out and about between attending events on holiday , as music video performer showed off his brand new shoes once again',
#  'a spider in cobweb , close - up',
#  'leopard on a branch and looking something .',
#  'that wallpaper makes me dizzy !',
#  'be sure to stop by a city to see the famous statue on your trip !',
#  'actor arrives to the premiere',
#  'image may contain : person , riding on a horse , horse and outdoor',
#  'tips for choosing the right gym',
#  'teams organize their tools and materials , and prep their stations before the build begins .',
#  'a general view of stadium .',
#  'this photo shows the exterior damage to a house hit by a bus',
#  'the mist descending on the trees will silence even the loquacious types .',
#  'floor lamp would never buy it but i love style with these colors , gorgeous .',
#  'shoppers are expected to hit the high street for the sales',
#  'view of a hut on person',
#  'actor has packed since we saw him in march .',
#  'individual chocolates isolated on a white background',
#  "the most hilarious texts from parents we 've ever seen , text messages boyfriend",
#  'follow some basic rules to keep yourself safe and protect your vehicle from extreme weather .',
#  'a flaming soccer ball flies through outer space',
#  'people who are out having fun .',
#  'i have a weird obsession with some things , mushrooms being on that list',
#  'a city is one of the local gardens where person has gathered all manner of driftwood and creatively constructed statues .',
#  'doll house in a box : diy tutorial on how to make a simple and portable dollhouse for children',
#  'wreath of autumn leaves on a wooden background for your text .',
#  'a dog on a snow covered beach',
#  'person being burned for charcoal in the rainforest',
#  'actor arrives at the premiere',
#  'a bit of a stretch : actor stretches her limbs as she shoots scenes for comedy on monday',
#  'a fresh look at fresh water -- researchers create a-lake database',
#  'person looks for an open receiver in the second quarter against defense .',
#  'rusted car in the drainage of a city during the winter months .',
#  'image may contain : person , playing a musical instrument , on stage , shoes , guitar and night',
#  'lead by person , the surgical team has performed the first robotic assisted surgery in the area .',
#  'crib on the beach premium photo',
#  'coupe & sedan original vintage advertisement .',
#  'shot from underwater young man dive into the water',
#  'clothing store with closing down signs on the windows',
#  'a model walks the runway at the summer fashion show during event',
#  'a woman tourist takes a photo as she enjoys a street performer playing saxophone in front',
#  'this dog has better vocals than me',
#  'before heading out trick - or - treating , eat a healthy snack so you are not tempted to eat all of your candy at once .',
#  'icon isolated on white background .',
#  'stock photo of a western grey kangaroo hopping',
#  'actor taking actor by the arm in the film',
#  'showing item 10 of 11 .',
#  'husband helping smiling housewife to use washing machine indoors .',
#  'software mounted on a car',
#  'a crowd of people relaxing and cooling off on the beach',
#  'a life like depiction of earth and the space around it',
#  'adorable baby wearing a diaper standing in a white round crib',
#  'drives baseline against sports team .',
#  'illustration with the ball , splashes and words without goals on black background .',
#  'smoke and steam bellows from the chimneys and cooling towers of power station',
#  'the replica of an ancient boat , a junk in the waters of a port .',
#  'street scene with a billboard',
#  'people relaxing and having fun on the beach to have their holidays',
#  'lit light bulbs line up on a green background focusing on a bulb .',
#  'person with her artwork from the installation grounded .',
#  'a dancer pours a bucket of water over other crouching dancers in a performance',
#  'walls , an upholstered stool , and a patterned rug in a dressing room',
#  'be still off the shoulder dress',
#  'island of the many beaches thumbnail',
#  'actor attends the premiere during festival at festivals .',
#  'actor with her hair past her shoulders and a hat',
#  'images from the girls basketball game .',
#  'clouds rise over a grassy hill',
#  'would love to do something like this in the boys common room ... definitely going to try to put one in person',
#  'bottles of consumer product in a pack .',
#  'laundry on the balcony of an old colonial building',
#  ...]

# %% [markdown]
# ## Processing LAION

# %%
def collect_laion_data(path):
    df_laion = pd.read_parquet(path)
    N_laion = len(df_laion)  # number of samples from one parquet of laion 
    small_laion = df_laion.sample(n=N_laion)

    laion_texts_array = small_laion["TEXT"].iloc[0:N_laion].values
    return laion_texts_array.tolist()

# %%
## cal feature info 
import time
start_time = time.time()

common_lst = []
for i in range(len(path_dir)):
    laion_texts = collect_laion_data(path_dir[i])
    
    laion_text_re = []
    for val in laion_texts:
        if val != None :
            laion_text_re.append(val)

    p = Pool(processes=16)
    laion_text_processed = p.map(text_preprocessing, [laion_text_re[i] for i in range(len(laion_text_re))])
    p.close()    
    common = set(laion_text_processed).intersection(set(processed_cc_3M)) 
    print(f"length of common set {len(common)}")
    print("--- %s seconds ---" % (time.time() - start_time))
    common_lst.append(common)

# %%
common_lst_re = []
for common_ in common_lst:
    common_lst_re.extend(common_)
# Out:
# Number of cpu :  64
#  the length of text processed data is ============================ 3318333
# CPU times: user 2.56 s, sys: 1.59 s, total: 4.15 s
# Wall time: 2min 23s

# %%
np.save('./CC3M_LAION_commonset.npy',common_lst_re)
np.save('./CC3M_LAION_unqiue_commonset.npy',np.unique(np.array(common_lst_re)))
# Out:
# ['raincoat worn kissing heck actor',
#  'concession centred contemporary construction astyle hotel atop original building',
#  'talk show host seen motorcycle outside building',
#  'female hands painted easter eggs yellow color brush top view',
#  'little boy playing autumn park shaking tree leaves falling',
#  'black sand beaches stretch miles upon miles winds wild literally rip doors',
#  'musician saxophone',
#  'vector illustration abstract complex structure consisting geometric shapes white background',
#  'person paint white clay fun',
#  'pets white pony zoo th birthday',
#  'close puppy wearing wig front white background',
#  'marching streets protesting capitalist system live',
#  'red haired girl red lips black hat long hair',
#  'view decorations night',
#  'actor also seen event',
#  'vector silhouette family white background',
#  'soccer player action football match football team',
#  'ripe onion white background',
#  'loved streets person model opted casual look dressed black hooded top pair short white shorts',
#  'young couple kid fun kitchen preparing spaghetti vegetable salad',
#  'small balls pouring open medical capsule',
#  'graffiti adorns front wall temple',
#  'interesting statistics first games',
#  'poster comedy starring actor',
#  'person drives huge sheet glass',
#  'representational photograph work displayed paintings',
#  'family dog resting inside home',
#  'map person',
#  'man walking alone park',
#  'female secret agent hat sunglasses vector illustration transparencies eps',
#  'person country pop artist inspired wedding champagne toasting flutes',
#  'city centre rear high rise office buildings',
#  'young kids siblings laptop computer empty living room',
#  'american football player game sports team',
#  'ruins sits atop cliffs overlooking geographical feature coast',
#  'clock tower dominated newer buildings',
#  'ships lined harbor sunset',
#  'pieces pizza gray background',
#  'second longest river world',
#  'salad wooden table',
#  'officials revealed high flying system coming soon park',
#  'deliberately framed image fir tree right added depth interest',
#  'biological species standing cat lying',
#  'rocket carries first ever g printer satellite',
#  'hard rock artist performs onstage festival brand',
#  'lot oil canvas seated period lady child bears author',
#  'celebrates first quarter touchdown reception game sports team',
#  'cute doll hat',
#  'actor event holiday',
#  'lily pads pastel coloured flowers shallow pond surrounded palm trees lawns',
#  'illustration person calligraphy celebration community festival',
#  'actor interview comedian',
#  'hand swiping credit card',
#  'old cars around town look like kind people would driven',
#  'pineapple beach blue sky',
#  'north coast seen clouds',
#  'know moving winter time',
#  'beautiful stylized image fluffy black cat big ears tail',
#  'pages photo album showing views',
#  'motorcycle riding dirt road high',
#  'happy dolphins jumping water',
#  'military commander fictional character',
#  'insane bicycle jump roof',
#  'baseball player introduced crowd',
#  'sitting area second floor',
#  'black silhouette young man bike',
#  'left larger buildings accommodate parties guests',
#  'organism resting stone',
#  'shopping list written notebook',
#  'layer paint piece furniture',
#  'machine device like bicycle moving parts work together accomplish task',
#  'false books one makes lighter',
#  'black cat sitting looking acting curious focused dark background',
#  'decorating globes around home',
#  'museum host regional conference photo courtesy',
#  'plane takes runway',
#  'horse stars symbol vector art illustration',
#  'athlete scores try match',
#  'fishing boats harbour island',
#  'football player celebrates scoring side first goal game football player match',
#  'new ads truck',
#  'backdrop hotel vast pool',
#  'biological species crossing road front oncoming car',
#  'dessert made mixture consisting grains fruits nuts',
#  'accessible footwear homeless',
#  'woman cabin person',
#  'always jealous people came concert really looks like fire',
#  'photo shirts laying table',
#  'armed force put standby case violence escalated',
#  'qualities women love men',
#  'person dogs back porch home',
#  'girl vintage postcard stork',
#  'hand made chair royal line made solid wood',
#  'view boat approaching port north coast',
#  'ship river winter',
#  'sad couple breaking sitting couch living room house indoor dark background',
#  'rider jumping jump great style',
#  'friday putts th green tournament held',
#  'figurine form golden snake',
#  'cc could see',
#  'groom giving bride kiss forehead',
#  'know couple little boys would cute',
#  'hip hop artist performs onstage festival',
#  'fashion week fall see every celebrity front row',
#  'people walking one busy streets',
#  'country support partial ban immigration',
#  'actor guest attend premiere animation film',
#  'football fans main square watching football team vs parliamentary republic',
#  'actor attends person festival',
#  'photos show ladders stretched roof story building',
#  'naval ship undergoing maintenance dry dock',
#  'organize clean edit closet wardrobe like pro stylist cheap',
#  'rear view young woman tattoo back',
#  'planet earth space',
#  'locket belonging author containing picture fiancé',
#  'long living room divided separate distinct spaces',
#  'retro filtered picture flags beach',
#  'tourist resting hotel room',
#  'reflection lights inside casino',
#  'person choir singing carols escalator',
#  'dead roses vase table',
#  'captain grille globe hallway',
#  'actors turned part film character',
#  'pour water glass',
#  'shredded chicken served vegetables',
#  'white house closeup southern facade',
#  'baseball pitcher pitches sports team',
#  'cute young girl writing diary seated playground dusk',
#  'giant balloon marched city event thursday',
#  'portrait young man',
#  'flying coral reef',
#  'pretty cheerful girl well talking phone cafe',
#  'swimming lots love saved person puppy life',
#  'make firm dough cut quarters let chill mins',
#  'chicken ice cube isolated white background',
#  'contour ancient sailing ship',
#  'person looks straight ahead black suit tv political drama',
#  'novelist gives person hug ceremony honor retired publisher',
#  'closed sign hanging door',
#  'red yellow flags fluttering wind blue sky',
#  'plaque embedded rock front wooden fence',
#  'players celebrate person scored opening',
#  'bowling ball pin vector set isolated background',
#  'group business people make happy business team',
#  'cricketer likely face challenges coach cricket team',
#  'style actor',
#  'low angle view weathered stone wall',
#  'opening new building',
#  'sure late went rain today take pictures confluence flooded show much water hold',
#  'lantern blooming spring park',
#  'graduate photo high school senior suit wearing glasses looking camera photographer',
#  'businessman looks shadow sees super hero symbol leadership power success',
#  'file airplane prepares land',
#  'young successful farmer working field',
#  'garden shed husband built bridge',
#  'laying low dressed black shirt jeans soccer player seen keeping head held made way solo star hotel room',
#  'combination lighting colors outdoor kitchen makes looking modern',
#  'think sign forehead saysuse',
#  'shrimp good named team',
#  'cartoon illustration fox looking angry',
#  'pass long difficult',
#  'actor walks red carpet film festival',
#  'cartoon illustration doctor idea',
#  'young girl bed holding sheets looking scared',
#  'shelf bathroom packed linens picked markets photos sculptor',
#  'formal form fitting coral formal dress',
#  'politician decorated white house western christian holiday',
#  'biological species beak full insects',
#  'rhythm blues artist child',
#  'cat movie',
#  'drawing balloons crumpled paper',
#  'overlook far distance',
#  'decorative panels style',
#  'animal perched branch',
#  'turtle tucked next pot ivy plants belonged mother',
#  'dance group unity perform stage third live show',
#  'adventures subversive reader',
#  'view coffee plantation',
#  'singer holding microphone concert performance',
#  'musical artist performs festival',
#  'person sent feet ocean water city storm center passed miles away',
#  'city high street',
#  'actor photographed trade journal magazine festival',
#  'stone like porcelain grotto chip moisture protection hard wearing ceramic',
#  'large outdoor setting deck',
#  'abstract background cup coffee',
#  'young person playing piano hands',
#  'person looks cute green dress holding award awards',
#  'guitarist bassist protopunk artist hard rock artist performs live',
#  'blurred people train',
#  'royal purple favorite jewel tone especially paired teal',
#  'snow covered colorful mountains rising moon',
#  'images basketball game',
#  'river overflows onto section',
#  'according company minerals removed sand mining comprise dunes total volume',
#  'industry trim got schooled book shelves',
#  'seen many times never fails take breath away',
#  'politician wife descending steps motor car',
#  'fireworks display new year celebration',
#  'box among several gold pieces late artist stolen',
#  'eventneeded urban design city says organisation founder',
#  'baby girl stuffs lasagna mouth sits high chair',
#  'athlete watches shot closely match sports league championship',
#  'bride heading church',
#  'small tower hill',
#  'car parking ticket',
#  'biological genus reptile endemic',
#  'film producer actor pose party premiere',
#  'wedding dress atlas',
#  'seamless pattern fireplaces',
#  'mural train station',
#  'graphic black white drawing happy little boy girl',
#  'magazine available read',
#  'make fake fireplace paper',
#  'actor teamed casual striped jumper pleated skirt launch sister bridal collection',
#  'couple exchanging garlands wedding',
#  'family little boys playing grass summer meadow football',
#  'digging color',
#  'polar bear stands edge sea ice looking reflection water',
#  'digital art selected',
#  'humans chimpanzees share percent dna',
#  'christmas vector illustration shades blue white large shooting star tree lined snowy hills room text',
#  'food around world hand drawn colored vector vector graphics',
#  'women take break checking phones celebrate night',
#  'actor named beautiful woman world',
#  'reinforcing mesh plaster building',
#  'driving mountain range december',
#  'model walks runway presentation fashion week spring',
#  'best lettering typographical vector background',
#  'photo master commander',
#  'love window display business',
#  'stairs top bell tower',
#  'complete package new owners chance buy collection paintings furniture accessories',
#  'young man sitting front laptop found solution',
#  'message bottle thank notes',
#  'players celebrate goal versus football team',
#  'silhouette male hands opening brown beer bottle',
#  'woman hands keyboard piano',
#  'still life artwork favorite painting',
#  'dog new year dress',
#  'poster artist played hometown',
#  'queen pink coat holding bunch flowers',
#  'shelves around kitchen arranging cups plates',
#  'flags gazebo background',
#  'person attends performance album signing',
#  'locked shot foreground overcast day',
#  'lovely illustration lion flat cartoon style',
#  'tracking shot pod dolphins baby',
#  'soccer player scores sides first goal group f match',
#  'located miles northwest accessible mountain lake',
#  'map gray black background illustration',
#  'determine number excess labor hours daily need adjusted current paid labor hours less desired paid labor hours reduction needed',
#  'puzzle majesty spike dragon',
#  'home design plans regard really encourage',
#  'rear grounds property',
#  'cockpit aircraft model',
#  'artist performs stage festival',
#  'girl family migrate',
#  'english civil parish bust whoever headlining iconic festival expect person heckling night stage',
#  'turn regular dining room den change paint furniture',
#  'vector silhouette businessman white background',
#  'american football team running back american football player ruled game',
#  'sports team outside person person forces fumble american football wide receiver first half game',
#  'person book character',
#  'person actor attends show part event',
#  'man wades flooded driveway outside home',
#  'ground squirrel log yellow flowers grass',
#  'huge flock sheep grazing',
#  'new friends mountains',
#  'decorations country western christian holiday ornaments christmas wreath reason craft',
#  'wore pumps dress want sitting',
#  'landing seen water',
#  'honeybee got business really got work getting nectar',
#  'organisation run building former site town',
#  'illustration rabbit radish',
#  'abedroom town house hit market',
#  'keeping healthy fan green juices person tried one purple variety',
#  'illustration price tag figure percent',
#  'cute kitten drinks milk isolated white background',
#  'building construction house starts next fall',
#  'intense lights shine surrounding buildings',
#  'yellow pear isolated white background',
#  'political party shirts holiday',
#  'interior hall',
#  'business skyscrapers along river',
#  'lanterns outside main hall tourist attraction',
#  'actor person attend premiere',
#  'real estate sold sign hangs front west end property',
#  'kick new year right huge list must read books',
#  'mom reading book baby girl',
#  'model walks runway fashion show event',
#  'family photo session beach featuring handpainted chair',
#  'accessories red dress',
#  'portrait beautiful happy female friends city',
#  'close gardener splitting perennial plants',
#  'golden letter logo company',
#  'actor attends gala screening',
#  'athlete takes snap game american football team',
#  'person said brought craftsmen work house',
#  'pop artist performs onstage awards',
#  'lying white desk',
#  'shiny happy person finalist met music video performer pop artist prepares launch solo career',
#  'biological species festive candy cane',
#  'shape animated admin map globe',
#  'bride looking distance',
#  'stand desk customized right working height',
#  'reflection sole flamingo lagoon',
#  'aerial skyline night',
#  'warthog running grassland',
#  'huge cake cut local leaders workers celebrate th birthday leader',
#  'raised guide dog baby',
#  'portrait large group happy diverse business people standing together isolated white',
#  'downy woodpecker photographed person',
#  'american football running back taping',
#  'view distance',
#  'view towards cliffs',
#  'professional road racing cyclist summit final lap',
#  'automobile model stop sign',
#  'feet hanged man rotten swamp',
#  'celebrities attend fall fashion show fashion week salon',
#  'house country house formal gardens south east valley',
#  'pop artist talking fans whilst leaving hotel',
#  'person offense person course favorite band',
#  'actor arrives premiere',
#  'horse taken run road',
#  'vector illustration greeting card celebration',
#  'beef steak served fried egg chips salad restaurant table',
#  'need update bathroom new vanity great way change style',
#  'acacia tree silhouetted sunset',
#  'tractor driving lines hay',
#  'wild kitty matching tattoo calves',
#  'yellow sands invasion happened modern images',
#  'busy lady blonde beauty regularly shares workouts social media juggles staying top fitness thriving career',
#  'eye sky',
#  'aerial view industrial park winter',
#  'needle sewing machine close',
#  'surrounded several elected officials person speaks recent events community',
#  'actor attends press conference new new movie',
#  'man surfing background',
#  'ice floe top stone',
#  'footballer reacts match football team part',
#  'emotions running high person gave emotional performance concert',
#  'picture taken seating area lake walking gardens',
#  'folk rock artist singer songwriter playing guitar sitting chair concert',
#  'eye eyelashes closeup eye cow',
#  'psych folk artist poses portrait',
#  'mother putting baby sleep crib',
#  'young businessman commuting job',
#  'daisies aerial view',
#  'spot butterfly wild meadow',
#  'big road sign clear blue sky',
#  'handle universe care',
#  'project focus carrying cargo space station',
#  'basketball player national basketball throws ball training session',
#  'person sits car outside house',
#  'portrait middle age woman autumn yellow maple tree back fall season',
#  'boy band artist concert',
#  'statues noble person person',
#  'actor attends los angeles premiere red carpet arrivals',
#  'glow dark bedroom',
#  'large home colonial architecture',
#  'warming members team practice session',
#  'water clear might spot tiny little fish scurrying water',
#  'farmers transporting charcoal bicycle',
#  'map little bit showing north',
#  'lance installing wainscoting kitchen island',
#  'american football player celebrates throwing winning touchdown pass monday night game sports team',
#  'truck first spotted beach',
#  'field front bistro',
#  'christmas bells red bows white background',
#  'need picture wedding',
#  'one favorite plants walking stick',
#  'musicians give private concert tourists private home',
#  'bride holds bouquet roses',
#  'south korean metropolitan city modern sculpture entrance neighborhood',
#  'big sea breaking onto golden sandy beach',
#  'religious leadership title speaks onstage',
#  'members compete amateur wrestling style',
#  'woman standing beside sofa grass',
#  'never break quote tattoo',
#  'gallery exposed ceilings detail',
#  'illustration toa week kindness',
#  'sale sign thin line icon web mobile minimalistic flat design',
#  'police officers engaged public order training',
#  'tools turn cooking magic',
#  'designers updated small kitchen cutout wall small bar',
#  'image made vector graphics editor software',
#  'tv personality hosts dance party',
#  'actor arrives world premiere',
#  'another view red rocks',
#  'poster upcoming tour summer',
#  'geometric tile stripes powder room',
#  'stretching stick figure isolated web icon background',
#  'people stuck rock face',
#  'industry available colors',
#  'file photo dated scene detectives continue question',
#  'human heart cage',
#  'statue monarch front section wall',
#  'national team runs training ahead international friendly match england german city',
#  'orange white contrast smooth black leather strap',
#  'rule game higher visibility',
#  'invitation little girl tea party',
#  'person son share office farm family growing peaches photo',
#  'private yard hot tub deck perennial gardens creek flowing yard',
#  'mural street art graffiti spoken word artist streets',
#  'christmas cookies milk decorations wooden table',
#  'capturing beautiful wedding ceremony person',
#  'big eyes moths',
#  'glazed ceiling invites gaze towers begin garden third floor',
#  'man relaxing tree park dolly shot',
#  'flying bus city traffic rush hour',
#  'actor arrives premiere',
#  'portrait old man',
#  'digital art selected',
#  'vector illustration snowman broom hand old pot head',
#  'lightning strike cloudy dark sky',
#  'triangular structure wood glass inside grounds old gothic building',
#  'keeping house cool heat solar panels',
#  'image may contain person playing musical instrument stage',
#  'biological species resting foliage',
#  'pop artist attends show spring summer',
#  'careful around downed power lines trees hide lines',
#  'colorful illustrations musical artist',
#  'soldiers engage targets vehicle',
#  'help babies sleep exhausted need help sleeping well',
#  'woman front sea',
#  'mapping map obesity us',
#  'letter colorful logo circle',
#  'automobile model bursts flames quiet street',
#  'items stored',
#  'cartoon illustration work fiction waving',
#  'merely adopted wealth born molded',
#  'cricket player became player smash double centuries single venue football team dominated region',
#  'person team preparing programs children',
#  'garment glitter dress perfect holidays',
#  'village mountains',
#  'biological species tire',
#  'vintage stove may way go fit ovens kitchen',
#  'illustration automobile model brandishing holding flag set inside crest shield stars stripes',
#  'customers shop clothing following opening first store',
#  'sports team running back person carries football game sports team',
#  'boys fun person strikes funny pose sets',
#  'woman yelling megaphone',
#  'old invalid banknotes background',
#  'trees building human body closely related',
#  'guide living working city',
#  'car balanced rock developed area',
#  'football player poses team presentation',
#  'flag blows wind',
#  'hands circle isolated white background',
#  'beautiful young couple embracing standing pier near water',
#  'photo guest room hotel',
#  'artist takes wheels spin',
#  'mermaid tail person',
#  'man pensive pose',
#  'white kittens road',
#  'woman plucks pear tree',
#  'author attends private view',
#  'view city person buildings hotels trees mountain',
#  'couple daughter sitting waiting area hospital',
#  'sunlight breaks trees summer day',
#  'one rooms bathroom bath shower two share shower room',
#  'celebrity soft rock artist hard rock artist appear',
#  'actor entered venue bit late seen greeting everyone event',
#  'common symbols seen dream strange items case person',
#  'biological species hunting arctic snow october',
#  'daily paintings rainbow shows steps creating painting excellent',
#  'girls going birthday party balloons hand',
#  'skyline sunset seen',
#  'cricketer celebrates wicket martial artist',
#  'rugby player ties young fans shoe lace training session',
#  'path clear probably someone else',
#  'view chateau coach house',
#  'heart wolf ruled moons',
#  'model walks runway fashion show event',
#  'dog sleeping next wall',
#  'eagle hunts',
#  'man behind wheel retro car',
#  'biological species tree branch winter',
#  'large white coloured dogs sitting shade',
#  'space small biological species want try something ordinary year give one clever diy ideas go',
#  'raised bridge white nights city',
#  'example minimalist family room design',
#  'grasslands extremely hot summer really cold winter',
#  'phase diagram summarizes conditions substance exists solid liquid gas',
#  'image may contain person playing musical instrument stage indoor',
#  'cute couple pair holding hands headed home style',
#  'visualization house swimming pool',
#  'organisation founder football player touchline',
#  'dice letter c character cube',
#  'boxer lands punch boxer',
#  'decorative portrait animal',
#  'close blue eye old woman aged',
#  'close young woman eye',
#  'see classic vehicles display show returns',
#  'cross section tree trunk horizontal format',
#  'heart kisses holiday',
#  'illustration boy watching insect',
#  'set white arrows colored circles white background',
#  'photo traditional water fountain landscape',
#  'actor walks runway fashion show event',
#  'person battle ball',
#  'country artist performs day festival',
#  'coastal white story exterior home photo hip roof metal roof',
#  'tired wearing lesser boots',
#  'french dish food may look complicated make believe us surprisingly simple',
#  'map showing approximate areas',
#  'large breeds small breeds dogs need lot love care affection prove good pets',
#  'girl shows toy would like',
#  'charity approached via winding mountain road',
#  'happy weekend inscription blue background vector art illustration',
#  'rustic swamp tree',
#  'takes light sun reach earth',
#  'talk town water',
#  'golfer attempts putt first round',
#  'one many statues honour illustrious ancestor',
#  'actors walk red carpet ahead screening festival person',
#  'map country',
#  'set signatures isolated white background',
#  'person performs live stage city',
#  'homemade costume women entered contest',
#  'eat lot candy',
#  'back exterior home also grill',
#  'night winter sky seen frozen window',
#  'much space car',
#  'sharp edge rigorous modern forms trendy entire fashion industry talk hairstyles',
#  'black white cows farm',
#  'view pipe roof installed expert',
#  'man races recurring competition',
#  'ask owner photos car',
#  'property image walk beach',
#  'window frames narrow symmetrical',
#  'era uniforms equipment memorabilia display th annual luncheon honoring country',
#  'city going next lock',
#  'woke nail art making us want throw manicured fists air inspire change',
#  'bridge across th street',
#  'top crop top high waist trousers cropped bomber',
#  'kayak allows reach beaches would certainly accessible foot long walks',
#  'hand drawn sugar skull lovely frame',
#  'remember closet person film',
#  'could person group men behind crime',
#  'photo shoppers browsing new shop',
#  'chose leave spaces groups three',
#  'dressing office never easy',
#  'solid gold presidential mother pearl face diamonds',
#  'hands playing gentle piece beautiful grand piano',
#  'full refurbishment apartment',
#  'biological subspecies climbing tree',
#  'bleachers top replaced',
#  'panoramic cityscape building dusk',
#  'golden oak nineteenth century break front open bookcase adjustable shelves',
#  'custom made hoodie reflective piping get us add custom pattern ones',
#  'person along daughter person made long trip person last week compete annual regatta',
#  'bud close background spring garden',
#  'gothic skater dress sewn finished garment',
#  'pier lined tires fenders boats sea mountains background',
#  'awards ceremony took place completion th competitions',
#  'actor attends premiere festival',
#  'black white illustration disease person',
#  'additional photo property listing cloisters',
#  'close profile man walking along wall steadicam',
#  'model returns car leaving gym',
#  'alpine skier holds dog news conference january',
#  'image may contain person riding horse horse outdoor',
#  'happy new year poster champagne bottle',
#  'hand drawn watercolor isolated romantic floral compositions made like floral borders pink roses leaves flowers white background',
#  'actor arrives screening held',
#  'lack storage space definitely issue large laundry room',
#  'fossils rocks beach royalty free',
#  'tree grows hill waves',
#  'makes pass sports team',
#  'hands old man beggar black background',
#  'riding boots taken next level',
#  'island shown undated file photo',
#  'aerial view cooling towers nuclear power plant close city',
#  'many bags celebrities couture week fall',
#  'marketplace end tour',
#  'equestrian statue military commander',
#  'gangsta rap artist opened black man relationships pop artist music video performer',
#  'fairy garden tier fountain person',
#  'national register historic places location beautiful old homes',
#  'aerial shot site',
#  'person brought help person',
#  'dog spilled paint leave muddy footprints floor',
#  'actors premiere photo',
#  'room queen bed best suited couple',
#  'left hand got pain wrist holding retro dumbbell isolated white background',
#  'view unfinished building beams walls',
#  'black blue person wore blue shirt button combo completing look pair jeans black vans',
#  'things orange blog things things orange',
#  'fans celebrate surfer given key city tuesday',
#  'vehicle drives toward camera mountain range',
#  'baseball pitcher throws sports team first inning baseball game',
#  'surgeon ready work green key',
#  'galaxy mountain winter',
#  'day dead holiday seamless pattern sugar skulls',
#  'rubble demolition old building',
#  'family traveling car',
#  'free kick football team one finest set piece goals seen season',
#  'movement continents millions years',
#  'summer might end hair like',
#  'actor attends world premiere theater',
#  'fans attend concert university last july',
#  'lifting car tools maintenance garage',
#  'football player scores team second goal first leg match',
#  'person stands outside office block taken activists',
#  'portrait hard rock artist guitarist photographed live performance',
#  'navy blue pants high waist',
#  'trendy girl short dress floral background stock vector',
#  'painting artist series',
#  'sunset field fictional object wild flowers beach',
#  'pop artist attends live performance cast person',
#  'carrying mountain bike rocks mountain top',
#  'photos action film beam',
#  'camera attached outside car driving meadow',
#  'used transport sugar cane slaves old locomotive tender series',
#  'soft rock artist actors attend premiere',
#  'image may contain person stage playing musical instrument',
#  'image may contain person stage playing musical instrument guitar concert night',
#  'beautiful woman dancing barefoot long blue dress stock photo',
#  'comedic man plays computer home photo',
#  'helicopter coming land ship',
#  'competitors receive commands crew chief exiting aircraft model armed force',
#  'beautiful venetian street old houses sunny summer day',
#  'ornately tiled decorated frontage',
#  'city sunny day',
#  'winter storm preparing surviving blizzard',
#  'hat tea party',
#  'ruins banks close',
#  'golden cup podium',
#  'basketball falling rim',
#  'video window moving train',
#  'sheep style person',
#  'gold silver hearts black background',
#  'rain boots university must',
#  'glow dark flower',
#  'bird prey think plug looking',
#  'young boy carrying water bicycle village',
#  'person voted right stitch',
#  'black white landscape photograph',
#  'model presents creation designer fashion week',
#  'man rides scooter small road',
#  'beach hut advertised estate agent window',
#  'love horses',
#  'person performs day festival',
#  'transition fall nautical inspired shoulder top',
#  'employees work automobile model transparent factory',
#  'singer synthpop artist performs stage show theatre',
#  'actor speaks press conference',
#  'home prior renovated',
#  'even paved road site',
#  'questions already asked fans able bring flares prohibited ground',
#  'exploring streets towns around city leads',
#  'flying ducks graced homes',
#  'large scale mosaic refers juxtaposition different habitats within landscape grasslands wetlands adjacent woodlands',
#  'every seed contains living plant ready sprout soon encounters proper conditions growth',
#  'train wagons arrives railway station rails',
#  'good vet seemed good spirits strolled women',
#  'water flows roof rain',
#  'vintage makes wish spent learning make clothes instead jewellery',
#  'referee shows football player red card',
#  'city slums',
#  'put together tutorial drawing eyes',
#  'round bolster want additional info click image',
#  'illustration woman front building white background vector',
#  'thin font blurred background',
#  'pub village',
#  'american football team defeated american football team first ever playoff game',
#  'person attend sports league championship',
#  'love short hair cut pop artist',
#  'orange blooms starting turn apricot pink age',
#  'trail woods',
#  'students critical thinking class',
#  'sunny day villa lamp plants grasses',
#  'popular easy sew',
#  'truck carrying hay body',
#  'tropical smoothie red napkin',
#  'heavy person held onto north hands child slept',
#  'cumulus clouds gathering sunny sky rain',
#  'uk constituent country £ £ notes pound coins legal tender city',
#  'activists forum indian state wrap flag around dog protest',
#  'close arms holding soccer ball flag background',
#  'colorful photo blue sky trees forest covered frost winter',
#  'happy father son lying grass soccer ball countryside',
#  'young man braided hairstyle',
#  'motorcycle racer wining race',
#  'view umbrella clear summer day',
#  'aisle style runway wedding',
#  'long straight road going thought desert mountains',
#  'person examines quilt judges entries',
#  'long walks beach',
#  'vector illustration sun symbol',
#  'tents middle desert mountains background sunny day',
#  'statue instantly recognisable symbol',
#  'passengers get bus',
#  'pattern small flower',
#  'actor arrives premiere',
#  'cherry blossoms around gate',
#  'person pink shirt',
#  'plug electric car display show',
#  'triangles neck ppt year',
#  'pile socks available students need',
#  'football player tries luck goal left footed drive fails find back opponent goal',
#  'make sure getting nutrients need',
#  'famous apple tree world',
#  'bunch grape market',
#  'organisation founder right talk farmers',
#  'northern lights polar light aurora borealis night sky time lapse island',
#  'actor actor music video performer guest dancer seen',
#  'fresh river go cliff water drops splash',
#  'sits majestically amidst acres wooded parkland',
#  'person actors attend build series discuss new film',
#  'actor person attend premiere',
#  'person using crutches runway',
#  'clock amazing transformation',
#  'old beautiful car near water',
#  'frangipani isolated white background',
#  'young man girl going around green field',
#  'country confluence along road',
#  'person hails works inside recreational vehicle one acrylic oceanic paintings',
#  'tv personality daughter attend awards',
#  'tips planning successful corporate holiday party',
#  'actor look happy photo organization leader event',
#  'close ice cube',
#  'mother tying hat baby boy',
#  'fictional object biological species produced person',
#  'benefits handmade tile blog',
#  'sheep common sight along city',
#  'tennis player competes tennis player day tournament',
#  'large th century naive oil painting monarch',
#  'fashion designer poses backstage show tent',
#  'shot creative dining room big table different chairs',
#  'heart shaped cookies falling red bucket',
#  'actor person attend awards',
#  'family members raised glasses wine festive dinner',
#  'handles ball preseason game sports team',
#  'trimming tree front commercial building',
#  'fashion illustration pop artist awards',
#  'barn door built full length mirror',
#  'actor husband professional hockey player make store appearance',
#  'image may contain person stage playing musical instrument night concert',
#  'dream pop artist performs live',
#  'lamp top arch',
#  'making noise main singers seen poised tour country show month',
#  'small boy playing stones beach',
#  'sudden storm hits canyon',
#  'caucasian kid donkey',
#  'interpretation dream saw helicopter',
#  'illustration boy catching butterflies flower garden',
#  'chairman hopes falcon find mate spring',
#  'silhouette girl night river bank',
#  'studio still life close female hand inserting piece partially completed jigsaw puzzle',
#  'overhead view prickly cactus plant pot',
#  'wave river little birds flying river',
#  'toucan rain forest tree foliage early morning rain',
#  'sample views brochure',
#  'outdoor atrium along wing home',
#  'motorist station pumps gas',
#  'pasta form animals wooden spoon blue background',
#  'image taken page people',
#  'pop artist recording session',
#  'contemporary christian artist attends movie premiere',
#  'smart mobile bars streets',
#  'ghost window',
#  'garment keep shorten denim jeans like professional tailor',
#  'actor attends launch party',
#  'decay tuned car',
#  'actor attends los angeles premiere',
#  'worker rolls tobacco cigar facility',
#  'palm trees along path',
#  'love summer look forward wearing favorite coat',
#  'image may contain person riding horse tree outdoor nature',
#  'set beautiful watercolor flowers leaves white background design',
#  'dogs playing dog park',
#  'large entryway open concept bright reddish pink color',
#  'person attends premiere festival',
#  'person performs annual fest university',
#  'people seen amid heavy fog outskirts',
#  'muzzle black horse',
#  'illustration hand holding trophy',
#  'planets space stars nebula',
#  'person first used cover passport',
#  'girl dances beach sunset',
#  'smiling couple young child picking pumpkin pumpkin patch',
#  'lawn sloped back fence challenge lawnmower invitation',
#  'american football player hangs back defend',
#  'actor actor comedian attend premiere',
#  'painting painting artist stolen recently retrieved',
#  'organization leader chef awards',
#  'couples flocking room hotel island enjoy night inside colon saying',
#  'perching wrong spot red shouldered hawk dive bombed white tailed kite',
#  'artist watches wife perform festival',
#  'cartoon illustration human skull burning cigarette teeth',
#  'detail photo coin year',
#  'football player puts tackle footballer clash',
#  'tractor collecting bales straw recently harvested field',
#  'village way',
#  'love interest',
#  'person carries ball city game',
#  'photo students event',
#  'circles stars festive seamless gold white pattern',
#  'soccer player told tv network relishing opportunity take last season winners',
#  'exterior view building',
#  'drawing sheet paper deck chair umbrella illustration hands',
#  'image may contain person stage playing musical instrument guitar',
#  'walking street saw girl practicing dancing curb',
#  'family walking beach',
#  'clothes hanging clothes line owned photographer',
#  'players seen undated image',
#  'wooden egg natural shell',
#  'horse runs sand slow motion',
#  'view looking ridge midway summit',
#  'story behind every door',
#  'garden within premises',
#  'director arrives premiere',
#  'time lapse sunset sail river garden',
#  'happy couple meeting street night',
#  'tv host attends award honoring fashion designer',
#  'man wheelchair female nurse assistance',
#  'solo album released february',
#  'today face fourth f children born parents',
#  'image bamboo isolated white background',
#  'person watches drive cardinal meet',
#  'love vintage trunks used home decor',
#  'woman stands rock view drainage',
#  'peace activist performs stage wings plays guitar',
#  'indigenous people blocked highway tree branches',
#  'getting higher mountain',
#  'stock vector illustration yellow ball billiards isolated transparent background',
#  'head shoulders detail ancient sculpture',
#  'happy young woman open christmas gift daughter sofa near fireplace',
#  'relaxed star looked laid back set following family vacation',
#  'keeping hydrated carried bottle water keep healthy hydrated sun',
#  'gentle paths lead visitors site split rail fences protect newly planted native plants',
#  'viewer submitted photo downed tree following weekend storms',
#  'sports team left olympic athlete warms game thursday',
#  'little boy graffiti bathroom mirror',
#  'golfer captain team addresses media announcement wild',
#  'automotive industry business stalking jungle',
#  'politician actor pose awards',
#  'draw deer kids',
#  'wooden table sofa cockpit boat',
#  'black hands man held together heart shape front blue sky background',
#  'flag boat sea',
#  'actor absolutely chic black dress person',
#  'luggage round trip',
#  'trees wind blue sky good weather movements',
#  'k zoom elements image furnished spacecraft manufacturer',
#  'built fourteenth fifteenth centuries timber framed medieval building hospital',
#  'artist performs stage festival',
#  'halloween costume ideas guys beards',
#  'say cheese dog appears enjoying lay summer sunshine smiles camera',
#  'tourist attraction fantastic facade',
#  'goat eating happy green lush grass summer meadow',
#  'image titled install operating system external drive step',
#  'flag flying front',
#  'independent entrance living room',
#  'best summer style secrets outfit ideas steal curvy girls like celebrity white ensemble',
#  'hip hop artist attends build discuss person',
#  'pins needles trellis dress view outfit',
#  'players line national anthem',
#  'shot slow motion fps filming location looking buildings',
#  'general view crowd',
#  'person wave winter far',
#  'portrait sad white red haired cat',
#  'astrological symbols circle',
#  'crooked wood framed house',
#  'local authorities parked outside apartment building man',
#  'colourful earth globe black background',
#  'rufous tailed hummingbird sitting nest',
#  'young woman walking alone eyes closed busy city',
#  'actor arrives premiere',
#  'get lost private paradise',
#  'bushfire burning orange red night',
#  'close view detail woman red lips',
#  'built historic building served tavern public library system',
#  'monument honoring soldiers complex cleaned vandalized',
#  'blackboard chalk shape drawn onto',
#  'young man throwing garbage smiling isolated white background',
#  'audience watching concert stage',
#  'heavy snow fall forest',
#  'fitness girl dumbbells dark background',
#  'diy remove existing label wine bottle',
#  'person playing game marbles',
#  'small pot strawberry jam wooden board',
#  'festival become popular annual event locals tourists alike',
#  'bodybuilding tiny audience worldwide',
#  'little auto mechanic super set toy',
#  'property image walk beach',
#  'wedding photography price mrs twig',
#  'illustration month intricate calligraphy celebration community festival',
#  'beautiful girl ballerina pink dress flowers white background photo',
#  'issue featuring actor cover',
#  'logo sign outside facility occupied computer hardware business',
#  'image may contain person smiling playing musical instrument stage',
#  'little girl may depicted image baby told biological father would routinely beat abuse',
#  'aurora borealis came beauty',
#  'blue fronted biological suborder rock cleaning eye',
#  'property image villa heated pool city views walk',
#  'master bathroom jetted tub',
#  'paint roller strip paint blue wall',
#  'injured cat lead organisation newborn kittens',
#  'one sleeps like cat sleeps',
#  'woman hammock using laptop swayed breeze hanging palm tree white sandy beach',
#  'aerial view city densely packed residential homes buildings',
#  'majestic lion shield trident tattoo',
#  'high angle view boys crouching bucket edge river',
#  'teenage boy trying shoes shoe store',
#  'host poses north rim',
#  'men cut fade',
#  'actor attends film premiere held',
#  'young family sitting large tree uses tablet',
#  'person ready rain',
#  'vector illustration abstract background music notes',
#  'biological species air',
#  'worker waits rescue sheep farm',
#  'class train speed',
#  'man led away police',
#  'antique c photograph family members pose front',
#  'garden shed teamwork person build house',
#  'briefcase full cash dollar bills',
#  'gothic structure shrine',
#  'elderly athletic busker',
#  'man types laptop desk',
#  'child draws marker first saturday',
#  'view northward church across valley clothed trees shrubs',
#  'car fire blazing car',
#  'summer sky hovering kite',
#  'baseball player band performs live concert',
#  'across pond person',
#  'keeping warm reality tv program family busy day spotted attending events holiday music video performer showed brand new shoes',
#  'spider cobweb close',
#  'leopard branch looking something',
#  'wallpaper makes dizzy',
#  'sure stop city see famous statue trip',
#  'actor arrives premiere',
#  'image may contain person riding horse horse outdoor',
#  'tips choosing right gym',
#  'teams organize tools materials prep stations build begins',
#  'general view stadium',
#  'photo shows exterior damage house hit bus',
#  'mist descending trees silence even loquacious types',
#  'floor lamp would never buy love style colors gorgeous',
#  'shoppers expected hit high street sales',
#  'view hut person',
#  'actor packed since saw march',
#  'individual chocolates isolated white background',
#  'hilarious texts parents ever seen text messages boyfriend',
#  'follow basic rules keep safe protect vehicle extreme weather',
#  'flaming soccer ball flies outer space',
#  'people fun',
#  'weird obsession things mushrooms list',
#  'city one local gardens person gathered manner driftwood creatively constructed statues',
#  'doll house box diy tutorial make simple portable dollhouse children',
#  'wreath autumn leaves wooden background text',
#  'dog snow covered beach',
#  'person burned charcoal rainforest',
#  'actor arrives premiere',
#  'bit stretch actor stretches limbs shoots scenes comedy monday',
#  'fresh look fresh water researchers create alake database',
#  'person looks open receiver second quarter defense',
#  'rusted car drainage city winter months',
#  'image may contain person playing musical instrument stage shoes guitar night',
#  'lead person surgical team performed first robotic assisted surgery area',
#  'crib beach premium photo',
#  'coupe sedan original vintage advertisement',
#  'shot underwater young man dive water',
#  'clothing store closing signs windows',
#  'model walks runway summer fashion show event',
#  'woman tourist takes photo enjoys street performer playing saxophone front',
#  'dog better vocals',
#  'heading trick treating eat healthy snack tempted eat candy',
#  'icon isolated white background',
#  'stock photo western grey kangaroo hopping',
#  'actor taking actor arm film',
#  'showing item',
#  'husband helping smiling housewife use washing machine indoors',
#  'software mounted car',
#  'crowd people relaxing cooling beach',
#  'life like depiction earth space around',
#  'adorable baby wearing diaper standing white round crib',
#  'drives baseline sports team',
#  'illustration ball splashes words without goals black background',
#  'smoke steam bellows chimneys cooling towers power station',
#  'replica ancient boat junk waters port',
#  'street scene billboard',
#  'people relaxing fun beach holidays',
#  'lit light bulbs line green background focusing bulb',
#  'person artwork installation grounded',
#  'dancer pours bucket water crouching dancers performance',
#  'walls upholstered stool patterned rug dressing room',
#  'still shoulder dress',
#  'island many beaches thumbnail',
#  'actor attends premiere festival festivals',
#  'actor hair past shoulders hat',
#  'images girls basketball game',
#  'clouds rise grassy hill',
#  'would love something like boys common room definitely going try put one person',
#  'bottles consumer product pack',
#  'laundry balcony old colonial building',
#  ...]

# %% [markdown]
# # LAION vs MSCOCO

# %% [markdown]
# ## Processing MSCOCO

# %%
path_dir = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/Open_clip_training/src/data/mscoco/mscoco/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        if filename.split('.')[-1] == 'parquet':
            path_dir.append(os.path.join(dirname, filename))

# %%
def collect_mscoco_data(path):
    df_mscoco = pd.read_parquet(path)
    N_mscoco = len(df_mscoco)  # number of samples from one parquet of laion 
    small_mscoco = df_mscoco.sample(n=N_mscoco)

    mscoco_texts_array = small_mscoco["caption"].iloc[0:N_mscoco].values
    return mscoco_texts_array.tolist()

# %%
## cal feature info 
import time
start_time = time.time()

processed_MSCOCO_text = []
for i in range(len(path_dir)):
    mscoco_texts = collect_mscoco_data(path_dir[i])
    
    mscoco_texts_re = []
    for val in mscoco_texts:
        if val != None :
            mscoco_texts_re.append(val)
    processed_MSCOCO_text.extend(mscoco_texts_re)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1.7311735153198242 seconds ---

# %%
print(len(processed_MSCOCO_text))
processed_MSCOCO_text
# Out:
# 591753
# ['Three young men playing a game of frisbee.',
#  'A kitchen area with a sink, refrigerator and stove.',
#  'A bear resting on top of some rocks at a zoo',
#  'A couple of dogs fighting over a red frisbee.',
#  'A bathroom sink with soap on it and a urinal beside it.',
#  'A sunset lit sky with traffic with street light.',
#  'Well kept kitchen with marble counter tops and stainless steel fridge',
#  'A zebra standing out alone in the grassy field',
#  "A baseball player stands in the batter's box awaiting the pitch.",
#  'Group of three horses sitting in the middle of the grass.',
#  'there is a old truck parked in the grass',
#  'A person snowboarding down a snowy hill. ',
#  'A group of military officers cutting a cake',
#  'A man on a skateboard that is on the sidewalk.',
#  'Two goats or sheep are crossing the road.',
#  'A man in a beanie sitting with a red and white snowboard.',
#  'White bathroom sink with tile countertop and wood cabinet.',
#  'A brown tiled bathroom with a large bath and shower.',
#  'a clock, a fan a desk and a chair in a room',
#  'An egg and vegetables sits on top of a plate.',
#  'A metal dark green park bench at the base of an incline.',
#  'A man at home plate swinging a bat.',
#  'A plate of food looks delicious with broccoli, onions, and potatoes.',
#  'A young man is leaving the water with his surf board.',
#  'A group of friends sitting down together sharing a meal.',
#  'An office with a desk and desk top computer and a lap top ',
#  'A ball player crouches with his glove close to the ground.',
#  'a small boy holding a frisbee with many vehicles behind him',
#  'This is a beautiful kitchen in a nice house.',
#  'Skateboarder flying off concrete stairs at the park',
#  'a bed with a big grey comforter on it ',
#  'a television is on a small wood stand',
#  'Three men on a tennis court photographed through a metal gate',
#  'A remote control car from the movie Back to the Future.',
#  'Black, white, and yellow bird sitting on the edge of a plastic cup. ',
#  'THERE IS A CLOCK TOWER THAT IS ON TOP OF A BUILDING ',
#  'A giraffe is standing in a fenced enclosure.',
#  'The people watch the little boy holding a tennis racquet.',
#  'A woman is posing on the beach with a surfboard',
#  'It appears an elephant is eating green straw.',
#  'a video camera sitting in front of a counter ',
#  'a baseball field with a man at home plate',
#  'A large bus is parked in front of a red building.',
#  'Groups of young men and women are playing Frisbee on a grassy field.',
#  'a bathroom with a toilet and a bath tub',
#  'A sheep is standing in the green grass.',
#  'A pitcher getting ready to throw pitch at a game.',
#  'a little girl smiling at the camera while holding a hair dryer',
#  'There is a red double decker bus at the side of the street.',
#  'This woman is holding a donut that is decorated with confetti.',
#  'A woman stands next to a fenced in horse.',
#  'some snow skiers snow and a tower and mountain',
#  'a baseball player playing catcher with an umpire behind them',
#  'a cheese pizza with mushrooms and olives ',
#  'two people in formal wear standing right next to each other ',
#  'A man taking a photo of a mirror.',
#  'A guy is smiling while standing on the grass.',
#  'A kitchen with a refrigerator, stove, and microwave. ',
#  'A young man, who is dressed formally, is posing for the camera. ',
#  'A man and woman ride on a red motorcycle with others in the background.',
#  'Two giraffes standing up next to one another, in between two tree and in the grass.',
#  'Three people standing in the grass playing frisbee.',
#  'A man pressing buttons on his cell phone.',
#  'A pizza with white sauce is on a white cutting board.',
#  'A child is petting a small horse that he stands beside.',
#  'A young person is jumping to catch the Frisbee between his legs.',
#  'three smiling people posing for a picture ',
#  'An airplane is going over a steep mountain.',
#  'A bathroom with a bath tub, toilet and different designed light beige tile.',
#  'A small boat is anchored in the water while the couple explores.',
#  'a lizard eating brussels sprouts, next to carrots. ',
#  'The New York Mets play the Atlanta Braves.',
#  'A man riding skis down the side of a snow covered slope.',
#  'A dog is lying in bed with its head on a pillow and it is sleeping.',
#  'A sony computer with a website about theory istherreason ',
#  'Three elephants surround a calf behind a fence.  ',
#  'a living room with a television, rug and sitting chair',
#  'A large crowd of people gathered at a water event.',
#  'a person with one foot in a snowboard',
#  'Two sheep stand near each other on the grassy pasture.',
#  'an empty street and signals that are red',
#  'A modern kitchen has large and clear counter space.',
#  'Kids playing a game of soccer in the rain.',
#  'A set of three wall mounted urinals with pictures of men on top of them.',
#  'people at a beach watching what looks like kites flying in the air.',
#  'A man sitting on a barrel and talking on a cellular phone. ',
#  'An elderly man cutting a cake with white frosting.',
#  'A young boy is holding a putter golf club and is practicing his swing.',
#  'Man in red jacket and red tie walking in a crowd. ',
#  'Old dirty freight train parked by itself near the tracks.',
#  'a close up of a bowl of food with broccoli',
#  'A street sign hangs over a city intersection.',
#  'Guys in the park playing Frisbee golf on a cold day.',
#  'A brown dog trying to hump a black dog.',
#  'A small bathroom, lacking only a toilet tissue dispenser.  ',
#  'It is dusk, and the skiers have abandoned their skis and snow boards for social interaction.',
#  'A girl sits in a chair on a porch in summer',
#  'Two men are playing together in a park.',
#  'There is a toilet with a push button plunger',
#  'An outdoor market has red umbrellas over the food.',
#  'Two dogs in the back seat looking out the windows.',
#  'Black and white photo of park benches, with people in the background.',
#  'BASE BALL GAME WITH MAN AT BAT AND UMPIRE READY',
#  'A red stop sign sitting on the side of a street.',
#  'a stop sign at the end of a road by a block wall fence',
#  'Three ladies using music instruments in a living room.',
#  'There is a person jumping in the air on a pair of skis.',
#  'A bowl of something next to two fruits.',
#  'Zebras standing on a grass plain, with other animals in the background.',
#  'An overhead sign leads three lanes for three destinations.',
#  'A display full of giraffe figurines are made of glass.',
#  'A man on skis walking on skis across the grass',
#  'Laptop sitting next to the computer monitor, keyboard, and tablet pad.',
#  'One lama in front of another lama standing outdoors.',
#  'PEOPLE WAITING FOR DINNER IN A BUSY RESTAURANT.',
#  'An open box of pastries in front of a stack of boxes with doughnuts in them.',
#  'A home work station with two laptop computers on it.',
#  'two dogs are playing with a frisbee in the snow',
#  'A large green couch sitting on top of a wooden floor.',
#  'A new unopened toothbrush is on a plate near eating utensils and glasses.',
#  'A man holding a drink and a game controller.',
#  'An article is seen here in this extraordinary picture. \n',
#  'a table that has a couple of computers on it',
#  'A young boy attempts to hit a ball with a tennis racquet.',
#  'Two horses running around a dirt race track',
#  'Scissors are chained to prevent them from being stolen.',
#  'A toilet outside covered in snow next to a house. ',
#  'A group of men are playing a Nintendo Wii',
#  'A white clock tower towering over a small town.',
#  'A young girl wearing a tie that matches her skirt.',
#  'Three cats are sitting by a window looking outside.',
#  'Three men are playing tennis on an outdoor court.',
#  'A group of young men playing a game of frisbee.',
#  'Two cows lined up at the door of a house',
#  'A zebra stands by itself in brown grass.',
#  'A white vase with a fully opened red rose stands next to an overflowing bowl of apples next to a mirror on a window ledge. ',
#  'A woman rolling down a sand dune with a red frisbee.',
#  'Smiling children who are holding stuffed animals are at an outdoor event.',
#  'The two boys have two teddy bears and one Frisbee. ',
#  'A pair of orange and white Vans steps upon the underside of a skateboard.',
#  'a dog with a frisbe in its mouth walking through the water ',
#  'A man on a skateboard performing a trick.',
#  'A plate of food being cut by a pair of scissors',
#  'A stack of suitcases on brown table next to a wall.',
#  'A dog has a frisbee in his mouth and a person is trying to take it.',
#  'A black puppy chewing on a blue sheet.',
#  'Five kids playing with frisbees on a sunny day.',
#  'Two giraffes eating off the top of trees together. ',
#  'A home kitchen showing a desk area and the refrigerator ',
#  'Wood bathroom with white porcelain fixtures and dark wood accents',
#  'A person taking a jump of a snowy peak on a snowboard',
#  'many bunches of bananas on a table ',
#  'Three zebras standing together as they drink water',
#  'A kitchen counter with a glass sitting on a saucer.',
#  'a parking meter with the word "fail" written on it',
#  'A sign reading "factory trained technicians" on a glass wall.',
#  'A  blurry skateboarder in the foreground catches some air in what looks like a rail yard.',
#  'Two passenger jets sit in wait at the airport.',
#  'A hotel room made up for the next guest.',
#  'two zebras walking around their pen at the zoo',
#  'African american man flies a kite in a field. ',
#  'A large building on the corner of a city street.',
#  'Tennis player in white shirt holding racket on green court. ',
#  'A  yellow fire hydrant on a green piece of grass next to a road.',
#  'Two people standing next to each other and holding snowboards.',
#  'Two men riding their own respective elephants. ',
#  'two trains parked on the tracks next to some platforms ',
#  'A cell phone that is placed on top of a keyboard.',
#  'A man in a wetsuit is holding a surfboard on a dirt path. ',
#  'sandwich sits on plate with dipping bowl next to a cup',
#  'A box filled with cakes next to other boxes of cakes.',
#  'A phone mounted to an apparatus next to a desk.',
#  'People standing on a dock waiting to board a boat.',
#  'A red bus that is sitting in front of a building.',
#  'A kitchen with black appliances and beautiful wood cabinets.',
#  'car on a highway following signs in France',
#  'Simple office with red chair and wooden table.',
#  'A group of people on motorcycles in a street.',
#  'a room wit ha chair a bed multiple windows ',
#  'a man cuts the cake at a wedding',
#  'A photo taken from behind a fence of tennis players on the court.',
#  'Someone taking a slefie with a large camera in a large mirror.',
#  'A group of small children playing with each other on a pebble covered ground.',
#  'A traffic light with a misty mountain in the backdrop.',
#  'A professional baseball player in the middle of a swing.',
#  'The sheep and the dog always travel together.',
#  'A sign hangs above the road pointing in the direction of cities. ',
#  'A cat looking down at the person lying on the bed.',
#  'A boy jumping over a fire hydrant on a skateboard.',
#  'A young woman on the beach jumps into the air.',
#  'people standing besides a bus taking to each other',
#  'A frisbee sitting in a sports bag sitting on the ground.',
#  'Dental instruments are pinned to a whiteboard with holes in it.',
#  'A man ridding a surfboard into the air as the wave crashes.',
#  'A person with a scarf cooking with a wok',
#  'A young person standing in the middle of a half pipe.',
#  'A bathroom with a toilet and sink attached to the wall.',
#  'a couple of zebras that are standing behind some cows',
#  'a stop sign sits in front of a building ',
#  'A young girl smiles as she holds a piece of luggage.',
#  'Flowers are landscaped to make a design of a clock.',
#  'A small blue tray of different types of food.',
#  'An elephant is inspecting the top of a womans head with its trunk.',
#  'A wooden table with a ripe yellow banana cut up.',
#  'A small herd of sheep grazing in a grassy field.',
#  'Clean ultra modern kitchen with island and hood.',
#  'A frisebeedisc standing up along side other objets.',
#  'A white table with chairs and an umbrella.',
#  'An old apple sitting next to a spotted banana. ',
#  'A bathroom with a walk in shower next to a toilet.',
#  'A crowded city street filled with traffic at night.',
#  'a person standing up playing nintendo wii ',
#  'A man and a woman eating a meal while being watched by onlookers.',
#  'A white and red train traveling over a city.',
#  'A woman making pizzas inside of a professional kitchen.',
#  'A dog is gripping the skateboard on the ground. ',
#  'A woman cooking in a wok while wearing a scarf.',
#  'some yellow bananas hanging on a holder and some cabinets',
#  'A bench that looks like a round hut.',
#  'Four bears walk around in the sun in a field.',
#  'a person with a red top and a gray cat',
#  'A man makes a face while a woman holds up her phone.',
#  'A bathroom that has a toilet with buttons.',
#  'A neatly made bed in the hotel room. ',
#  'A man holding a smoking device by some tents.',
#  'A toilet with a soap dispenser above it.',
#  'A baseball batter about to make an attempt to hit a baseball.',
#  'Traffic is stopped on the road because of a red light.',
#  ' a person sitting in a bed with no pants on',
#  'Two women are standing on the beach holding surfboards.',
#  'A band wearing suits playing in a room. ',
#  'A young person holding a golf club and looking at a frisbee on the ground. ',
#  'A person with ripped jeans on riding on a skateboard. ',
#  'A individual entering a Cat & Dog shop with four dogs. ',
#  'a person in glasses is holding a white plate',
#  'A web page displayed on a laptop screen.',
#  'Two men standing over a table eating food.',
#  'Multiple people on a beach, some playing with kites.',
#  'Three people smile as they pose standing together.',
#  'A plane is taking off from a runway.',
#  'this is a computer chair with an umbrella ',
#  'An older floor light sits deserted in an abandoned hospital.',
#  'Three dogs are fighting over a red Frisbee.',
#  'A snowboarder performing a trick in the air.',
#  'A fruit stand with many varieties of fruit with price signs.',
#  'A blissful dog laying against a windscreen of a car',
#  'A small boy is feeding the elephants through a fence.',
#  'strawberries, fruits and cream on an english muffin',
#  'A white bowl holding ramen, broccoli and carrots.',
#  'A cat laying on top of tie dyed pillow.',
#  'A woman is seen in the ocean holding a surfboard.',
#  'a number of elephants standing near one another',
#  'A woman is holding a tennis racquet on the tennis court',
#  'Small white and black cat sitting in front of a bright red light. ',
#  'a close up of an electric blender on a counter',
#  'A kichen with dirty dishes in the sink.',
#  'A large white bird flying over a sandy beach.',
#  "The skyscraper has a bright clock lit above it's brightly lit name. ",
#  'A person holding a plate with strawberry cake on it.',
#  'A man riding skis on top of a snow covered slope.',
#  'A giraffe running in an open barren desert.',
#  'I cannot tell if those are plantains or unripe bananas.',
#  'The two cups are sitting in front of the mirror.',
#  'A man sitting at a table in front of a laptop computer.',
#  'An athlete with a snow board is performing on a city street.',
#  'An L shaped desk fits well in the window space.',
#  'A kid on a bike and several smiling onlookers under a tent.',
#  'a ball player running to reach the goal',
#  'White bag with its contents sitting on top of a bed. ',
#  'Two boys are playing soccer and a girl is watching them.',
#  'A helmeted baseball player is swinging a bat.',
#  'a skinny cat looking over the side of a ledge next to some bottles ',
#  'A couple of men on a field playing baseball.',
#  'Girl in a bakery pointing at a donut display.',
#  'A skier in an orange jacket takes to the air over a small jump.',
#  'a train on a train track near a building',
#  'A bathroom with four urinals together on a stainless steel wall.',
#  'A man kneeling on top of a tennis court with a racquet.',
#  'Two young men holding Nintendo Wii controllers standing next to each other.',
#  'A  black and white dog is in with some sheep.',
#  'A hot dog with toppings in a piece of foil.',
#  'A person riding a bike on a street about to cross a path.',
#  'A little girl with a stamp on her hand stands beside a fire hydrant.',
#  'The men are trying to play a game of Frisbee on the grassy field in the park. ',
#  'Water is slowly flowing from a fire hydrant.',
#  'Two people on a motorcycle are at the head of the line making a turn.',
#  'a do nut and a cup of coffee on a table',
#  'a little boy snow boarding in the snow by his self',
#  'Two horses, one brown and one gray, stand behind a fence in a field with trees behind them.',
#  'The warning sign is on a busy street near a large, three story building.',
#  'an image of a kitchen setting with ceramic backsplash\n',
#  'a parking meter with some graffiti on it ',
#  'A young man plays with a Frisbee in a park.',
#  'A person in red jacket snowboarding down a slope.',
#  'The man holds a cell phone at a striped cross walk.',
#  'A cat that is laying down on a couch.',
#  'A woman is tying her shoe on the bench',
#  'A beautiful young girl riding a skateboard on a sidewalk.',
#  'A small bird perched on top of a tree branch.',
#  'A black and white cat with a ball next to it',
#  'A thin crust pizza is next to a wrapped knife and fork on a plate.',
#  'The Ceresota Building at the intersection of S 2nd St and S 5th Av in Minneapolis.',
#  'Two people wearing snowboards sitting on a snowy slope.',
#  'Open living room with a large window in front of a forrest. ',
#  'two small birds perched on two tree branches',
#  'a person some chairs and a black cellphone',
#  'Three mature men wearing suit and tie sitting at a table.',
#  'Two sheep poking their heads over a white cement wall',
#  'A group of boys playing with kites in a field.',
#  'A man and two small children with a luggage cart filled with luggage.',
#  'A city street with a blue and white informational sign set in a flower garden.',
#  'A lot of people in the snow with horses and cats.',
#  'Two soldiers are slicing a cake with a knife.',
#  'A living room with photos, carvings, knick knacks and television',
#  'a couple of dogs that are playing with a frizbee',
#  'A woman walking next to a snowboard on a ski covered slope.',
#  'A person is fixing a window in the kitchen.',
#  'A white and red aircraft is sitting in the grass.',
#  'A large black bear trekking through a grass covered field.',
#  'Airplanes lineup at the airport ready to go on their next flight.',
#  'A large kitchen with a metallic refrigerator freezer next to a   microwave.',
#  'A man in suit and tie with umbrella in rain.',
#  'A person trying to get up after falling while skiing.',
#  'Serving boxes full of fresh vegetables,rice, and meats.',
#  'Several umbrella covered areas are placed in a field.',
#  'A small plate holds pieces of assorted fruits. ',
#  'A man leans inside a refrigerator door and examines the contents. ',
#  'A group of men in a green field playing Frisbee.',
#  'A double-decker bus with people sitting inside of it.',
#  'A man riding a snowboard down the side of a rail.',
#  'These suitcases are sitting next to a chair.',
#  'A display case of many different kinds of a donuts. ',
#  'A pitcher about to throw a baseball on a baseball diamond.',
#  'The black cat is turning away from the large computer screen.',
#  'a woman taking a selfie in the bathroom while using a regular camera ',
#  'Two zebras walking together across a barren savanah',
#  'A glazed donut is displayed next to an open styrofoam cup on a table with circular patterns.',
#  'A woman approaching a kiosk selling wood ties ',
#  'Two skiers are traveling down a snowy mountain.',
#  'Two cold glasses of Chardonnay on a wicker table.',
#  'A group of three different mobile phones, one showing the time.',
#  'An elephant stands amidst trees white eating leaves held in his trunk,',
#  'A view of an anime character eating a slice of pizza.',
#  'A cell phone showing the date and time on its display screen.',
#  'A baseball player standing at home base with a bat.',
#  'A red double decker bus driving past a building.',
#  'A man with  a green hat, glasses, an Oregon State t-shirt, and blue jeans sits on a closed toilet.',
#  'A person with an umbrella on a city street.',
#  'One long hot dog and bun, a order of onion rings and a tall drink await a hungry diner.',
#  'A man in a suit on a plaza, holding a blue umbrella in the rain.',
#  'A well designed entertainment area with a TV set to play a video game. ',
#  'A business sign attached to a wooden post.',
#  'a skier going down a slop in the snow',
#  'A woman wearing a military uniform injecting a cow.',
#  'there is a young boy rinding a skateboard on a ledge',
#  'A baseball player swinging a bat on top of a field.',
#  'A clock between two archways on a castle',
#  'a man sitting behind a counter preparing some food ',
#  'A person jumps on a snow hill on skis.',
#  'Four small loaves of bread baking inside the oven.',
#  'a big sign leaning in the middle of a bare field ',
#  'A striped cat lays on top of a striped blanket. ',
#  'a close up of a knife and an orange on a desk',
#  'Multiple electronic items in a pile with their cords tangled up.',
#  'Elephant in a sandy ring entertaining entertaining zoo guests. ',
#  'A cooked pizza with olives, onions, and peppers on a pizza stone.',
#  'A tooth brush and pair of pliers sit together on a table.',
#  'a number of large air planes on a run way',
#  'Several cows grazing in a fenced in area.',
#  'A bed with lamps, night stands, a clock and a phone.',
#  'A shepherd dog walks through a puddle as a horse grazes in the background.',
#  'Black and white photo of teddy bears on counter next to photos.',
#  'Street signs shown in front of a Public Market and fish market.',
#  'A couple of men on hot rod motorcycles parked in a lot.',
#  'Hands move among a hot dog and other foods on a counter.',
#  'A plate of food including meat, carrots, and a dipping sauce.',
#  'There is an empty cup of coffee next to a laptop and open book at a cafe. ',
#  'Two people with snowboards on their feet on their knees in the snow.',
#  'An airplane that is on the landing strip.',
#  'A tractor trailer truck being loaded with cargo.',
#  'A large brick building is sitting behind a tree. ',
#  'There is a desk in the corner by the window.',
#  'A holder with toothbrushes, toothpaste, make-up and earrings.',
#  'A person ridding an elephant on a road in the jungle. ',
#  'A vase filled with flowers and greens on a shelf.',
#  'a green traffic light and a few different signs',
#  'Two dogs walking on a rocky beach while one carries a frisbee.',
#  'A man in a canoe with his dog about to get on deck .',
#  'A motorcycle, moped and a bus parked by the street.',
#  'A gray teddy bear leaning up a counter next to the ocean.',
#  'A brown bear walking through a lush green forest.',
#  'A neon sign sitting on top of a building with a giant clock.',
#  'A man wearing glasses checks his camera by the street.',
#  'a brown bear is laying on a rock and some trees',
#  'A steamboat travels along a river with large green hills on the side.',
#  'a truck drives down a street with a bunch of bananas in the back ',
#  'A person surfs a wave in the blue ocean near green cliffs.',
#  'Close-up picture of pizza and salad on wooden',
#  'A contemporary living room features leather furniture, oak storage and a garden view.',
#  'A professional ball team with fans in the stands and they have Mastercard as a sponsor.',
#  'A Golden Statue on top of a Clock Tower next to an American Flag.',
#  'A pizza is sitting on the plate on the dining table',
#  'A bed with a brown head board and an orange cover on the bed.',
#  'a close up of a jet flying in the air',
#  'A skateboarder is performing an aerial manuever during a competition.',
#  'An adult and a child on horseback heading towards three cows in some barren land ',
#  'Several people playing frisbee in a suburban park.',
#  'A kid wearing a backpack rides his bike near a beach.',
#  'THERE IS A GIRAFEE THAT IS RUNNING IN THE OPEN FIELD ',
#  'The championship series of a minor league baseball league',
#  'a laptop with a drink and a doughnut next to it',
#  'A sandwich and some fries on a plate.',
#  'A man flying in the air over a halfpipe on a skateboard.',
#  'a toothbrush is laying on a white sink',
#  'A baseball player standing next to home plate.',
#  'A white car with chrome rims parked next to an older lady.',
#  'a man on a snow mobile watching a skier ',
#  'The man is holding a package of a brand new toothbrush. ',
#  'An airport with red and white airplanes in wait.',
#  'A boy jumping up over a bench on a skateboard.',
#  'A woman rides on a horse drawn carriage.',
#  'Two giraffes are against trees and grass, one is sitting.',
#  'The black dog is asleep next to a person reading a book. ',
#  'A kitchen with white appliances and tile flooring',
#  'A small dog playing tug of war with his owner.',
#  'Long knife and leftover cake on a platter.',
#  'The bathroom is clean and ready for us to use. ',
#  'A bathroom scene with a cat under the bathtub.',
#  'A stop sign has graffiti on it that reads "capitalism". ',
#  'A man holding a child in high water.',
#  'A lobster roll with a side of sauce on a plate.',
#  'A parking area with various buses and vehicles parked bumper to bumper together and a building in the background.',
#  'there are many different foods in tis fridge',
#  'A bunch of giraffes standing around in a grassy field.',
#  'Many young children kick around a ball on grass',
#  'Two people riding parasols are in the background while a man who is riding a jet ski is holding on to a rope.',
#  'A man and a dog who are on a yellow kayak.',
#  'Two pizzas being served at a restaurant with water.',
#  'There are fruits in a blend and a carton of icecream next to it.',
#  'A towel rack hangs on the wall between two mirrors.',
#  'An American Airlines airplane is parked on the tarmac.',
#  'Women in cheerleader outfits carrying umbrellas walk down a city street.',
#  'Two computers, a phone, books, and paper on an office desk.',
#  'a sign in blue showing a direction besides a road',
#  'Bird with a long neck sitting on a pole in the water. ',
#  'A women lying in her underwear on a bed.',
#  'A man leaping while doing skateboard tricks in a city',
#  'A dog that is in the water with a frisbee.',
#  'A street sign sitting on the corner of a city block.',
#  'There is a man catching a frisbee under his leg.',
#  'A boat dock and harbor with a number of boats tied off to the dock.',
#  'A man standing next to a red and silver fire hydrant.',
#  'A kite with a pirate symbol is hanging from a pole on a beach. ',
#  'Group of people on skies going down a snowy slope.',
#  'A city bus drives down a dark city road.',
#  'Two tan dogs are sitting on a fancy tiled bench.',
#  'Little kids play a game of soccer in a field.',
#  'A small train sitting empty on a train track that kids can ride on.',
#  'Some very pretty giraffes standing by a big building.',
#  'A man on his ski board next to a mountain.',
#  'A plate of food including bread and an egg.',
#  'A large white bed in a red room',
#  'A man riding a surf board in the ocean while flying a kite. ',
#  'An orange glass vase with blue flowers on a table.',
#  'a number of umbrellas with sprinklers on top',
#  'A vase that is sitting on a table.\n\n',
#  'A street sign attached to a traffic light pole in an intersection.',
#  'Two surfers at dusk taking their surfboards out for a ride.',
#  'three people in uniform cutting a cake on a table.',
#  'large trains are pulled into the train station',
#  'A skier in red and white jacket jumped and is in midair.',
#  'A large stone tower with a clock on top',
#  'A person on skis going down a hill with trees in background.',
#  'Sweet treats sitting on display in the front of the store.',
#  'A close up picture of a vase and flowers in the vase.',
#  'Man and woman texting on cell phones. ',
#  'A woman holding a tennis racquet on a tennis court.',
#  'A home office with two computers and a bookcase',
#  'A group of men cutting into a celebratory cake',
#  'A clock and ornaments are sitting on top of a fireplace mantle.',
#  'a group of people standing in the park playing with a frisbee',
#  'A messy kitchen with dirty dishes and white cabinets',
#  'a small hand held television set being held by a hand',
#  'Clock tower on side of brick building with window near it.',
#  'Man standing in a family room with a game controller in his hand.',
#  'A group of people dressed as zombies stand in a park.',
#  'A train crowded with people stopping in a train station.',
#  'A man in black hovers over a skateboard while they are both in the air.',
#  'Multiple baskets of recently picked grapefruits on display.',
#  'A large passenger plane is on the runway.',
#  'A pink bear sitting on the limb of a tree.',
#  'Man playing tennis on a fenced in tennis court.',
#  'The person is jumping off of the bridge in the city.',
#  'A flower arrangement is sitting in a black vase.',
#  'A man stands next to his bike at the marina.',
#  'A bed in a room with wooden floor and not much else in the room.',
#  'A man in a baseball uniform winding up to throw the ball.',
#  'A group of 4 women play a Wii game while others watch.',
#  'A boat tied up to a wooden dock.',
#  'A partial close up of a computer keyboard and some electronics.',
#  'a bright building near a regular brick building',
#  'Some zebra and cows in a open grass plain.',
#  'A white bed topped with lots of pillows.',
#  "This seems to be a little girl's room with baby dolls on the shelf. ",
#  'a person jumping a snoe board in the air',
#  'A zebra standing on top of a pile of dirt and rocks.',
#  'A dog sitting in the passenger seat of a vehicle. ',
#  'a group of people with pizza boxes ',
#  'A young boy and a young girl playing catch on a beach.',
#  'A hipster holding a computer mouse over their eye while kneeling before a keyboard.',
#  'children are playing football game in the ground.',
#  'a man with glasses wearing a pink shirt and tie',
#  'Four dogs are following a man into a store.',
#  'The man in the helmet is skateboarding on a walkway.',
#  'A surfer riding a wave on the ocean.',
#  "A day lays its head near a person's hand, which is holding a book.",
#  'A cat sits on a window sill behind the blinds.',
#  'Two cars are stopped at a red light and transit buses are in the background.',
#  'Two adults and a young elephant are standing near a wooden post.',
#  'A white polar bear sitting on large rocks.',
#  'A family prepares to water ski as one man takes off across the water.',
#  'a surfer on a surf board in the midst of a wave',
#  'A pair of red scissors sitting on top of a piece of paper.',
#  'Computers and calendars set up on an office desk',
#  'The white and blue boat is floating on top of the water',
#  'A white male in front of a small plane smiling.',
#  'Two little girls holding umbrellas on a stage ',
#  'A black and white cat that is sitting next to a baseball glove and baseball.',
#  'The skier is doing a trick in the air.',
#  'A traffic light is located near an overpass.',
#  'An airplane is sitting on the runway while passengers get on',
#  'A snow boarder up in the air doing tricks by a bridge',
#  'Several pans of pizzas with different toppings. ',
#  "there's a laptop, glasses, a pen, notebook, and a booklet",
#  "A girl is sticking out her leg while sitting on a child's beach chair. ",
#  'Unhappy females sitting at table with large pizza',
#  'A man is eating a banana while wearing a helmet.',
#  'an image of food items on top of the stove',
#  'a man throwing a tennis ball and others watching the game',
#  'A fountain that has two sculptures of surfers in it\n.\n',
#  'An elephant in a forrest type area standing by itself',
#  'A pitiful looking dandelion in an antique looking vase.',
#  'An orange rusted train car connected to a train.',
#  'A blue ice cream truck with people lined up for ice cream',
#  'A person riding a wave in the ocean with a wet suit on. ',
#  'a bathroom with wooden walls and wooden floors',
#  'A tennis player waits for the ball to be served.',
#  'A family at a camp site flying a kite.',
#  'An old ice cream truck parked and open for business on a sunny day',
#  'A guy dressed in a suite sitting on a toilet on a phone.',
#  'The signs are clearly visible for all of us to see.',
#  'a silver park bench sits in concrete with grass behind',
#  'A plate contains a pizza with many toppings.',
#  'Multiple black and white sheep graze in an open field.',
#  'The bathroom is antique with a clawfoot tub and pull chain.',
#  'There is an airplane flying through clear skies.',
#  'Three girls walking down the street at night',
#  'A cat that is laying down on a couch.',
#  'A large jetliner airplane sitting next to another airplane on a runway.',
#  'Four men are playing Frisbee Basketball on an indoor court.',
#  'Someone patting the head of a large stuffed teddy bear',
#  'An old guy in a kitchen reaching into a refrigerator.',
#  'Group of adults with four women playing video game using controllers.',
#  'A person on a surfboard in the water.',
#  'a man throwing up a tennis ball during  a serve ',
#  'A snowboarder flies through the air in a mountain landscape',
#  'A young man playing frisbee while people watch.',
#  'A wooden crate holding bananas under a roof area.',
#  'The bus is driving down a busy road.',
#  'A large group enjoying a park beneath a cloudy sky.',
#  'The hull of a boat that is producing a wake',
#  'A man in a mask holding a sign',
#  'A MAN IS ON THE SNOW BAORD STANDING ',
#  'A woman that is playing frisbee in the grass.',
#  'A man sitting at a table with a burrito and a cup of coffee in front of him.',
#  'A water buffalo and a calf on a beach near a crowd of people.',
#  'Man pointing to woman who is smiling as she takes a picture with her phone.',
#  'A young man riding a skateboard up a black ramp.',
#  'A person is riding down a hill on skis. ',
#  'Giraffe with head extended up and two along fence eating from food trough',
#  'Three men who are cutting a cake together.',
#  'There is a woman walking by a subway compartment with people on it.',
#  'A few bikes are arranged by a bike lock',
#  'A tiled shower, molded plastic bathtub, shelf, mirror, wooden vanity, lamp, and sink make up a beige colored bathroom.',
#  'A black bear sitting high up in a tree.',
#  'A hot dog in tin foil with mustard, onions and other toppings.',
#  'kitchen with withe counter tops and white appliences',
#  'A man in the ocean on a surfboard, riding in with a wave crashing behind him.',
#  'A man standing in a darkened room next to flowers.',
#  'A photograph of Washington D.C. at night time. ',
#  'A persons legs with a dark colored cat rubbing against their legs and shoes.',
#  'A clock that is also a store sign.',
#  'A piece of pizza sitting on top of a white plate.',
#  'A bird is sitting on a bench in the grass.',
#  'a green and white street sign and a traffic light',
#  'A graphic promoting the NaNoWriMo event that authors nationwide participate in. ',
#  'a metal park bench on a cement slab',
#  'A person on a skateboard does a trick.',
#  'A women who is holding a tennis racket trying to hit a tennis ball.',
#  'a view of a flock of sheep grazing in a field.',
#  'People walking down the street together and sharing a stars and stripes umbrella.',
#  'two people eating at a table and many people are watching them',
#  'A hotel room with two beds and a basket of fruit.',
#  'A close up of an apple and a banana. ',
#  'A plastic fork on top of a lid sitting on a bench.',
#  'A man on a cell phone by a car on the street ',
#  'A person in a red sweatshirt on a motorcycle',
#  'A dog sits and looks out a window. ',
#  'The school bus has stopped on the side of the road. ',
#  'A stack of luggage by a chair and table.',
#  'The pizza has been cooked and prepared and is ready to eat.',
#  'A man on a surf board sprays water into the air with a trick.',
#  'Three women walk down a sidewalk near a bike and a parking meter.',
#  'A boy sits in a chair reaching into a plate of food on his lap.',
#  'A person hand pressing buttons on a Nintendo Wii controller.',
#  'A man holding a hotdog in front of a kitchen ',
#  'Muddy elephant with large tusks in natural habitat.',
#  'Woman on a tennis court and all spectators looking toward the opposite court.',
#  'A hot dog and bun with mustard is served on a plate.',
#  'A very large ship on land next to a large body of water.',
#  'a airplane that is flying through the sky over some snow',
#  'Coleslaw dresses up a pulled pork sandwich and fries.',
#  'A goat standing next to a tree in the open.',
#  'A shelf holds a clock, candle, vase of shells, and a cat figure.',
#  "A skier jumping in the air without ski's.",
#  'A white toilet in a very small bathroom.',
#  'A person walking into a store with four dogs close behind.',
#  'Intersection and lights for Queen St and Bay St.',
#  'This is an image of a man playing wii',
#  'a small child swinging a bat on a baseball field',
#  'A brown horse with flowing blond hair standing on top of a field.',
#  'A stop light has a blue sign with a P.',
#  'A man in a trench coat, hat, and carrying an umbrella pointing to the shirt collar of another man.',
#  'A man does a trick on a snowboard\n',
#  'A black cow rests in the grass while other cows are grazing in the distance. ',
#  'a butterfly sitting on an orange slice in a blue bowl',
#  'A man in purple shirt opening a box of pizza.',
#  'A room with a wooden bookcase, shelves holding two small objects, a television, and a laptop open to a website.',
#  'Several people in zombie makeup while two look at a phone.',
#  'A person going down a snowy hill on a snowboard.',
#  'A giraffe runs across a plain with nothing else in sight.',
#  'A teddy bear posed in a seated position.',
#  'A sailboat on the water with two persons aboard.',
#  'A man is petting a dog while in the street with other cyclists',
#  'A green lizard is eating a brussel sprout.',
#  'A man in a helmet is eating a banana.',
#  'a person on a motorcycle parked near a building',
#  'A white bear laying on top of a stony ground covered in filth.',
#  'A man skiing on top of a snow-capped slope',
#  'The bathroom with power tools in it is under construction.',
#  'A group of business people smiling and standing together.',
#  'An umbrella sitting in front of a fence.',
#  'A airplane fliyng near a mountain with its wheels out to land',
#  'A man riding a bike across a cross walk.',
#  'a living room with a tv a couch and a dresser',
#  'A baby holds a cell phone while sleeping.',
#  'a tall stone structure with a compass and a clock on the steeple',
#  'A skier wears the emblem of the USA while performing maneuvers.',
#  'A white toilet sitting next to a bathroom sink.',
#  'A little league baseball team on the field, preparing for a play.',
#  'A bowl full of apples sitting next to a vase and a mirror.',
#  'A woman holding a tennis racket at a game.',
#  'A cold and snowy pasture containing numerous sheep.',
#  'A public transportation bus parked by the curb',
#  'A large fighter jet plane flying in the sky. ',
#  'A person on a skateboard does an air trick.',
#  'A woman is preparing for the ball in tennis.',
#  'A white terrier dog on a leash with a brown spot on his eye. ',
#  'Two trains on rail lines near a subway',
#  'A young child in a field of grass holding a baseball bat.',
#  'A white toilet in a very small room.',
#  'A young girl swings a tennis racket on a court.',
#  'A street and sidewalk lined with cars and people with a street sign in foreground.',
#  'A windsurfer gliding along the water surface way out in the ocean',
#  'A woman posing behind several bunches of bananas',
#  'A man standing on a dirty and grass field next to a lake.',
#  'A man walking across a street with an umbrella.',
#  'A man standing on a grass tennis court and holding a tennis racket in his hand.',
#  'A tired, brown dog resting on the floor.',
#  'Two surfing statues glide across the water in the city.',
#  'A yellow cup containing  blue and yellow tooth brushes.',
#  'An open window overlooking a city in a bedroom.',
#  'A half eaten pizza muffin is sitting on a plate with others untouched.',
#  'The lizard is eating the half of a brussel sprout. ',
#  'A single broccoli floret in a larger garden.',
#  'Plates on display above cabinetry work in modern kitchen.',
#  'A person jumping up to catch a frisbee',
#  'A large bridge filled with heavy traffic next to a large city.',
#  'A man sitting on a bench next to a building.',
#  'An entrees made up of meat and broccoli sits upon a plate.',
#  'Three yellow plates with birds painted on ',
#  'A bright yellow boat parked by a dock',
#  'A road sign warning of Resident Permit Parking Only.',
#  'The food and drink are sitting on the table.',
#  'There is a dish of potatoes, steak, and broccoli.',
#  'A lady is trying to pull off a skiing trick in the winter. ',
#  'A person sitting at a table with a meal in front of them.',
#  'You are proudly witnessing a 360 Ollie in progression',
#  'A dog laying on the grass with a frisbee.',
#  'A pole with a clock on it in the winter.',
#  'A cup of coffee sitting next to a bunch of ripe bananas.',
#  'A group of people walk through the middle of the street.',
#  'Empty aqua bathroom with toilet, sink, mirror, and outside window.',
#  'An old and complex clock is built into the side of a building.',
#  'A side of a delivery truck with a picture of people in chefs outfits.',
#  'Surfer in board shorts walking in to the ocean',
#  'A man holding a Nintendo Wii controller in front of a TV.',
#  'A duck walking across a dry grass covered field.',
#  'A metallic bench on a path in the park.',
#  'A blocked off street that is ready for a event to happen.',
#  'Two dogs sitting in the back seat of a car looking out the windwo',
#  'Two children laying in bed together, the girl is holding up one finger.',
#  'a young man is throwing a red frisbee to a friend',
#  'a big plane sits parked in a air port ',
#  'A Gladiator movie dvd sits on top of a computer case.',
#  'Zebras standing in the dirt with a pond of water behind them.',
#  'A man sitting behind a counter selling food',
#  'A woman cooks in a large black skillet.',
#  'A fighter jet plane ascending into the sky.',
#  'a bathroom with a toilet and a sink and a shower',
#  'A man that is on a tennis court holding a racquet.',
#  'The small pizza is next to a bottle of wine.',
#  'A skateboard hobbyist doing a wheelie on a sidewalk.',
#  'Derelict billboard in a rural field next to pine forest.',
#  'A large neon sign sitting next to a green traffic sign.',
#  'Stuffed toys sit next to a garbage bin.',
#  'Some glazed donuts have chocolate frosting with sprinkles.',
#  'A cat lays on the concrete and looks underneath an object.',
#  'A mouse and keyboard are depicted in a blurry and dimly lit photo.',
#  'A shower and a white toilet in a small bathroom.',
#  'Three people hugging and smiling while drinking wine.',
#  'A street is empty and the traffic light is red.',
#  'A few cars are approaching an in intersection.',
#  'Bunches of bananas are hanging from wooden poles.',
#  "The hair in this horse 's mane is long. ",
#  'a cowboy with his hat in the saddle of a horse ',
#  'A person holding a rainbow colored umbrella with words written on it.',
#  'A large brown dog laying on top of a floor.',
#  'A man is smiling while sitting on a horse.',
#  'Two men listen as another man speaks to them.',
#  'A woman opens a suitcase in a hotel room.',
#  'Dog out on the baseball field bringing a bat back to the dugout.',
#  'A city bus driving past a group of men riding skateboards.',
#  'a boy is looking at his cellphone in a bathroom',
#  'A man and woman sitting on a bench watching a toddle play with a tennis racket.',
#  'A zebra and a small antelope graze near trees.',
#  'A black-and-white photo of a young man brushing his teeth.',
#  'A striped cat eating food from a bowl.',
#  'A jet takes off from a runway on a sunny day.',
#  'a person standing on the beach flying a kite',
#  'A large silver jetliner sitting on top of a runway.',
#  'a stop sign and across the street are some vehicles',
#  'The people are skiing on the small slopes.',
#  'A close up of some very pretty zebras close together.',
#  'A close up of four mini pizzas on a plate.',
#  'This pizza has mushrooms, eggs, olives, and ham on it.',
#  'A kitchen with clean counter tops and a window.',
#  'a group of people sitting on a couch playing a video game',
#  'A person on a snowboard in the snow.',
#  'a zebra standing by himself in a cage',
#  'A child holds a balloon while someone with a pair of scissors is about to pop it.',
#  'Two women in grassy field playing with a frisbee.',
#  'Surfing instructor teaching man to paddle surfboard on ocean.',
#  'Young children playing soccer on a grass field.',
#  'A metal park bench sitting on a slap of cement next to a lush green park.',
#  'a close up of an open box of doughnuts',
#  'DIFFERENT TYPES OF TWO WHEELED VEHICLES JUMPING IN THE AIR, WHILE FLAMES ARE PRESENT',
#  'A human converses with Marvin the Paranoid Laptop.',
#  'Two zebras are standing in the grass near a tree.',
#  'People are walking across the street during a storm.',
#  'A large shower with glass doors surrounding it',
#  'A room with many vases on a desk.',
#  'The table  top was white with brown chairs',
#  'Group of men at a market filled with fruit. ',
#  'A group of people sitting next to each other near a window.',
#  'Two men and two children under a flap, and one of the men is mixing juice in a blender.',
#  'A bathroom with a large mirror next to a toilet.',
#  'This shows an innovative Apple device and a keyboard. ',
#  'Living room that includes television, chair and multiple windows.',
#  'a boat docked at a wooden dock on a lake',
#  'People parasailing over the ocean while others enjoy the beach.',
#  'a lake that has all kinds of boats on it',
#  'a desk with a laptop a keyboard and sticky notes',
#  'Two cross country skiers stand in the snow.',
#  'A man is playing with a Frisbee in front of a car park sign.',
#  'An close up of some pink flowers in a glass bottle.',
#  'a small store with coca cola signs in the front of it',
#  'A yellow and green checkered motorcycle parked in front of a store window.',
#  'A small boy sitting on a luggage cart',
#  'A view of a living room couch, windows, and mirror.',
#  'A stove is covered with a boiler full of water and various plates of food.',
#  'A boy sitting on top of a truck with a bunch of goats. ',
#  'A bed sitting on a hard wood floor.',
#  'A woman looks at the camera as a picture is taken',
#  'A very big lit up clock near a set of stairs.',
#  'A zebra in a cage at a zoo next to a walkway.',
#  'A group of boats making their way into a harbor past the Sydney Opera House.',
#  'Public Car Park Entrance sign with an arrow',
#  'a box of donuts one has green topping another brown and another has sprinkles',
#  'The authentic Midwestern kitchen has elements similar to a  pottery studio.',
#  'A bunch of people with snow boards by a big snowy hill.',
#  'Sandwiches of different types sit in the open on the table.',
#  'Many people behind a barricade hold up four surf boards. ',
#  'A large white museum entrance sign in front of a building.',
#  'a woman on the ground with her feet on a umbrella. ',
#  'A street sign has stickers all over it.',
#  'A bridge runs across the water in the city.',
#  'a pair of skis next to a pair of ski boots.',
#  'A fire hydrant is across the street from a house.',
#  'A person tries to get a cat interested in a Wii-mote.',
#  'A large sign sitting on the front of a building.',
#  'A couple of sinks and a bath in a room.',
#  'There is a woman and a boy feeding an elephant.',
#  'A man driving a motorcycle with a woman holding a cell phone.',
#  'a close up of a pair of scissors next to a cup on a canvas',
#  'Two sheep walking in the grass on a sunny day. ',
#  'A person snowboarding down some snowy slopes with tall mountains in the background',
#  'A helmeted and goggled skier leans to get around an obstacle.',
#  'Wrought iron bars over a round window in a stone building face.',
#  'A cup of coffee has a fancy white design in the coffee.',
#  'A purple plate holding two slices of pizza.',
#  'A bride and a man talking next to a cake.',
#  'a close up of a person holding a really old cell phone',
#  'A very big table filled with many assorted food items.',
#  'A pizza that is sitting on a plate on a table.',
#  'There are motorcyclists doing tricks on a ramp.',
#  'three sheep standing around a field of grass',
#  'A group of people standing near some bananas.',
#  'Three people riding on the back of an elephant.',
#  'A double decker bus in a parking lot.',
#  'a bunch of bikes sit inside of a store ',
#  'A cat lying down on a large pillow.',
#  'Stuffed toy bears on display through window setting.',
#  'A man is cutting a decorated cake with a long knife.',
#  'A blond woman sitting at a table eating food wearing a t-shirt that says "Stop staring at my donuts".',
#  'Signs with directions are hanging on a light post.',
#  'A bunch of children are sitting at a birthday party',
#  'A ripe banana atop a vinyl phonograph record on a turn table.',
#  'three concrete dividers stacked up and sitting in front of trees',
#  'A girl in a bathroom blow-drying her hair.',
#  'The man is walking forward but the road is blocked off.',
#  'A horse and carriage waits on a brick street next to buildings.',
#  'A kitchen has a free standing oven and a wall oven.',
#  'The old metal bed with dirty linens is the only furnishing in the abandoned room',
#  'Small brown bears by a large log in their zoo enclosure',
#  'A bus pulls up the road to a sidewalk.',
#  'a large air plane on an air port run way',
#  'A large airplane flying through a blue sky.',
#  'there is a dog in the field playing with a frisbee',
#  'A red fire hydrant all alone in a field.',
#  'A living area with couch, cabinet and many windows.',
#  'A bus is driving down a busy street',
#  'A pizza with dessert toppings on it in four different ways.',
#  'Assortment of items displayed on wooden table in dark room.',
#  'A parrot sitting on a branch looking down.',
#  'A person stands on a beach in low tide.',
#  'A girl that has hit the softball in the game.',
#  'A dog that is standing on a frisbee.',
#  'A kid in a red shirt holding a plate with a piece of pizza on it.',
#  'A large kitchen has a refrigerator with magnets.',
#  'A man skiing in the snow at a resort.',
#  'A person using their cellphone. The time reads 13:04 on the clock.',
#  'Two children peel bananas at a picnic table.',
#  'A jet shoots up into the cloudy sky.',
#  'this is a zebra and a giraffe walking on the dirt',
#  'A man sits at a table and takes a drink of his beverage.',
#  'Two Pug dogs sitting on a bench at the beach.',
#  'A vintage STOP sign in black & white',
#  'This photo includes a rusty primitive refrigerator against a wall.',
#  'Camera person standing in the snow with a camera.',
#  'A dog is sitting in the passenger seat of a car.',
#  'Two small white pugs sitting on top of a white wooden bench.',
#  'A man looks at the fruit for sale on a card.',
#  'A plastic fork and lid sit on a wooden bench. ',
#  'A baby zebra rests while two other zebras graze nearby.',
#  'A woman cutting a birthday cake on a tray.',
#  'A public bus transporting people through a city.',
#  'A living room has a glowing brick fireplace.',
#  'Dog standing on an empty beach in front of some birds.',
#  'A chirch is littered with cars in its parking lot',
#  'A leaned over stop sign in a snowy parking lot.',
#  'A man, wearing glasses, holds a pan of food with his ovenmits on. ',
#  'A group of people sitting at a table that has a bunch of lap tops on them.',
#  'A man jumping up in the air catching a Frisbee.',
#  'Someone lifting a slice of deep dish pizza.',
#  'A white toilet hanging off the side of a wall.',
#  'A skateboarder in the air, as people watch on.',
#  'Fuzzy picture of people walking and a boy on a skateboard.',
#  'A man standing in a large kitchen looking into a pot.',
#  'an image of a group of people walking on the sidewalk',
#  'The white building is behind the street signs',
#  'A small group of people standing around a small motor bike.',
#  'a woman holding onto her tennis racket as she plays the game ',
#  'A double Decker bus that is being driven on a road. ',
#  'a kitchen that has some stoves in it',
#  'A cat wearing a neck tie laying on top of a pillow.',
#  'Some skiers hanging out together in the snow.',
#  "Two boys sitting with legs out on a chaise posing for camera and holding a Reese's Frisbee, with two stuffed animal monkeys behind them, one wearing a hat with ears, all in front of drapery.",
#  'Mother sheep with her calf on side of brown green hill.',
#  'a brown horse with a mask behind a fence',
#  'A white toilet missing seat in an old bathroom.',
#  'A group of different types of doughnuts in a box.',
#  'A green and yellow motorcycle is parked in front of some stores.',
#  'A piece of meat surrounded by broccoli and other food.',
#  'A man standing next to a woman while holding a smart phone.',
#  'a lady sitting in a half shell hut',
#  'A wild horse is pictured in profile in a mountainous setting.',
#  'a person jumping in the air while standing on a skateboard.',
#  'A skier jumps a snow ramp adjacent to a ski lift.',
#  'an image of a group of people walking near a stop sign',
#  'A man and woman riding on the back of a motorcycle.',
#  'A baseball player swinging at a baseball while the catcher is behind him with hand extended to catch the ball.',
#  'A bathroom sink with a tile design on the vanity.',
#  'A man and a woman looking at their cell phones.',
#  'A dog looks up where a Frisbee is just above him.',
#  'The sink is on the island of a large kitchen.',
#  'A skier is emmersed in flying snow while trying to straighten up.',
#  'Fans watch as a baseball player steps up to the plate.',
#  'A horse is looking over a fence with a shield on its face.',
#  'Sheep standing next to a stone wall in front of a tree.',
#  'A man putting a hot dog in a bun at a table.',
#  'A wooden bench with cushions beside a built in bookcase.',
#  'A man in a suit and tie holding a violin bow.',
#  'Two ladies are sitting down with a huge pizza at their table. ',
#  'people on the street with their cars  moving',
#  'An older man with a baseball cap on is sitting in the stands at a baseball stadium.',
#  'A person wearing a mask holds a sign.',
#  'A scenic view of a grassland with mountains in the background.',
#  'A fancy bathroom with a stand up shower.',
#  'An elephant raises its trunk to interact with a crowd.',
#  'A lone fire hydrant is in the middle of a grassy field.',
#  'Two men riding a ski lift above a snow covered mountain.',
#  'A man holding a surfboard watching a woman on a surfboard. ',
#  'A toilet made of metal sits next to a window. ',
#  'Collection of vintage motorcycles sitting on display at a museum. ',
#  'The bedroom has two beds and a basket of fruit.',
#  'A baseball player is waiting his turn to catch the ball.',
#  'A group of basket ball players in action on the court.',
#  'A stuffed animal is shown with glasses on it.',
#  'A dog is laying on a dirty bathroom floor.',
#  'A woman in jeans and a jacket on a horse riding through a large green field.',
#  'A man sitting on a chair working on a laptop.',
#  'A man with a brown jacket and cowboy hat carries a youngster through muddy water.',
#  'An old man scratching his head at a baseball game',
#  'Man standing in a field with leaves while holding up a frisbee. ',
#  'Two dogs in a car looking out the window.',
#  'A sign on a pole on a city street.',
#  'A group of people standing on a runway holding umbrellas.',
#  'a fire truck on a city street ',
#  'A baseball player holding a baseball bat standing on home plate.',
#  'A kite with a skull on it flying in the air on a beach.',
#  'A piece of bread with whipped cream and sauce on it. ',
#  'A toilet in a bathroom suspended in the air',
#  'Home living room with brown walls with white trim, fireplace, and tan furnishings.',
#  'people in costume using a cell phone near one another ',
#  'People at a sheep judging contest looking over the sheep ',
#  'A bed with several pillows in a room.',
#  'Bike shop inside with many prospective buyers also',
#  'A gray cat sits over the edge of a basket.',
#  'A herd of horses standing on top of a sandy beach.',
#  'Four donuts in a box with a variety of frostings.',
#  'A skateboarder jumps off a bowl while doing a trick.',
#  'A man up in the air on a skateboard.',
#  'An all white room with cloths hanging and flowers ',
#  'Two giraffes sitting in front of a tree together.',
#  'A mission style bed is dressed with bright white sheets and a striped folded quilt sitting in between two matching nightstands and lamps.',
#  'a man standing sideways on a surf board',
#  'A sexy young lady holding a tennis ball and tennis racquet.',
#  'A bento box with broccoli, tomatoes, blackberries, carrots, edamame, and rice with a smiley face.',
#  'A man standing next to a baby elephant in the city.',
#  'Five people smile as they pose before going on a trip.',
#  'an image of a red fire hydrant in the grass',
#  'a white bedroom a bed a brown chair and some white drawers',
#  'A dog laying on green grass next to a frisbee.',
#  'People celebrating on the water in a boat parade.',
#  'Four skateboarders stand at the top of a ramp, with their boards, ready to skate.',
#  'A woman riding skis on a snow covered slope.',
#  'An old locomotive on a rail line next to trees ',
#  'A man posing with a mouse and keyboard',
#  'A stop sign in the middle of the road',
#  'A woman is holding open scissors in front of her face.',
#  'a red black and white airplane parked on a grass field',
#  'A produce market filled with fresh fruits and vegetables.',
#  'Three people stand with two large adult sheep.',
#  'A bedroom scene with focus on a made bed.',
#  'A small train engine pulling a freight car',
#  'A metal counter topped with lots of cheesy pizzas.',
#  'A large dog sitting on top of a roof.',
#  'A snowboarder wearing a red jacket heading down the slope',
#  'A street scene with a couple taxis lined up.',
#  'A small cat peeking its head from under a blanket.',
#  'Several people walking on the ramp toward a boat.',
#  'A couple of cars at a traffic light by a sign saying Keep Moving.',
#  'A man that is standing in the grass.',
#  'A little girl putting on a tie for her school uniform.',
#  'A man holding a baseball bat in front of a crowd.',
#  'This is an image of a hotel room.',
#  'A drawing of a man riding a wave on a surfboard.',
#  'A person is sitting in the snow on a snowboard.',
#  'a black and white room with all black or white objects ',
#  ...]

# %%
# %%time
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())

#pool = multiprocessing.Pool(64)
#processes = [pool.apply_async(text_preprocessing, args=(cc_3M_texts_array[i],)) for i in range(len(cc_3M_texts_array))]
p = Pool(processes=16)
processed_MSCOCO = p.map(text_preprocessing, [processed_MSCOCO_text[i] for i in range(len(processed_MSCOCO_text))])
p.close()
# Out:
# Number of cpu :  256
# CPU times: user 257 ms, sys: 184 ms, total: 441 ms
# Wall time: 36 s

# %%
print(len(processed_MSCOCO))
processed_MSCOCO
# Out:
# 591753
# ['three young men playing game frisbee',
#  'kitchen area sink refrigerator stove',
#  'bear resting top rocks zoo',
#  'couple dogs fighting red frisbee',
#  'bathroom sink soap urinal beside',
#  'sunset lit sky traffic street light',
#  'well kept kitchen marble counter tops stainless steel fridge',
#  'zebra standing alone grassy field',
#  'baseball player stands batters box awaiting pitch',
#  'group three horses sitting middle grass',
#  'old truck parked grass',
#  'person snowboarding snowy hill',
#  'group military officers cutting cake',
#  'man skateboard sidewalk',
#  'two goats sheep crossing road',
#  'man beanie sitting red white snowboard',
#  'white bathroom sink tile countertop wood cabinet',
#  'brown tiled bathroom large bath shower',
#  'clock fan desk chair room',
#  'egg vegetables sits top plate',
#  'metal dark green park bench base incline',
#  'man home plate swinging bat',
#  'plate food looks delicious broccoli onions potatoes',
#  'young man leaving water surf board',
#  'group friends sitting together sharing meal',
#  'office desk desk top computer lap top',
#  'ball player crouches glove close ground',
#  'small boy holding frisbee many vehicles behind',
#  'beautiful kitchen nice house',
#  'skateboarder flying concrete stairs park',
#  'bed big grey comforter',
#  'television small wood stand',
#  'three men tennis court photographed metal gate',
#  'remote control car movie back future',
#  'black white yellow bird sitting edge plastic cup',
#  'clock tower top building',
#  'giraffe standing fenced enclosure',
#  'people watch little boy holding tennis racquet',
#  'woman posing beach surfboard',
#  'appears elephant eating green straw',
#  'video camera sitting front counter',
#  'baseball field man home plate',
#  'large bus parked front red building',
#  'groups young men women playing frisbee grassy field',
#  'bathroom toilet bath tub',
#  'sheep standing green grass',
#  'pitcher getting ready throw pitch game',
#  'little girl smiling camera holding hair dryer',
#  'red double decker bus side street',
#  'woman holding donut decorated confetti',
#  'woman stands next fenced horse',
#  'snow skiers snow tower mountain',
#  'baseball player playing catcher umpire behind',
#  'cheese pizza mushrooms olives',
#  'two people formal wear standing right next',
#  'man taking photo mirror',
#  'guy smiling standing grass',
#  'kitchen refrigerator stove microwave',
#  'young man dressed formally posing camera',
#  'man woman ride red motorcycle others background',
#  'two giraffes standing next one another two tree grass',
#  'three people standing grass playing frisbee',
#  'man pressing buttons cell phone',
#  'pizza white sauce white cutting board',
#  'child petting small horse stands beside',
#  'young person jumping catch frisbee legs',
#  'three smiling people posing picture',
#  'airplane going steep mountain',
#  'bathroom bath tub toilet different designed light beige tile',
#  'small boat anchored water couple explores',
#  'lizard eating brussels sprouts next carrots',
#  'new york mets play atlanta braves',
#  'man riding skis side snow covered slope',
#  'dog lying bed head pillow sleeping',
#  'sony computer website theory istherreason',
#  'three elephants surround calf behind fence',
#  'living room television rug sitting chair',
#  'large crowd people gathered water event',
#  'person one foot snowboard',
#  'two sheep stand near grassy pasture',
#  'empty street signals red',
#  'modern kitchen large clear counter space',
#  'kids playing game soccer rain',
#  'set three wall mounted urinals pictures men top',
#  'people beach watching looks like kites flying air',
#  'man sitting barrel talking cellular phone',
#  'elderly man cutting cake white frosting',
#  'young boy holding putter golf club practicing swing',
#  'man red jacket red tie walking crowd',
#  'old dirty freight train parked near tracks',
#  'close bowl food broccoli',
#  'street sign hangs city intersection',
#  'guys park playing frisbee golf cold day',
#  'brown dog trying hump black dog',
#  'small bathroom lacking toilet tissue dispenser',
#  'dusk skiers abandoned skis snow boards social interaction',
#  'girl sits chair porch summer',
#  'two men playing together park',
#  'toilet push button plunger',
#  'outdoor market red umbrellas food',
#  'two dogs back seat looking windows',
#  'black white photo park benches people background',
#  'base ball game man bat umpire ready',
#  'red stop sign sitting side street',
#  'stop sign end road block wall fence',
#  'three ladies using music instruments living room',
#  'person jumping air pair skis',
#  'bowl something next two fruits',
#  'zebras standing grass plain animals background',
#  'overhead sign leads three lanes three destinations',
#  'display full giraffe figurines made glass',
#  'man skis walking skis across grass',
#  'laptop sitting next computer monitor keyboard tablet pad',
#  'one lama front another lama standing outdoors',
#  'people waiting dinner busy restaurant',
#  'open box pastries front stack boxes doughnuts',
#  'home work station two laptop computers',
#  'two dogs playing frisbee snow',
#  'large green couch sitting top wooden floor',
#  'new unopened toothbrush plate near eating utensils glasses',
#  'man holding drink game controller',
#  'article seen extraordinary picture',
#  'table couple computers',
#  'young boy attempts hit ball tennis racquet',
#  'two horses running around dirt race track',
#  'scissors chained prevent stolen',
#  'toilet outside covered snow next house',
#  'group men playing nintendo wii',
#  'white clock tower towering small town',
#  'young girl wearing tie matches skirt',
#  'three cats sitting window looking outside',
#  'three men playing tennis outdoor court',
#  'group young men playing game frisbee',
#  'two cows lined door house',
#  'zebra stands brown grass',
#  'white vase fully opened red rose stands next overflowing bowl apples next mirror window ledge',
#  'woman rolling sand dune red frisbee',
#  'smiling children holding stuffed animals outdoor event',
#  'two boys two teddy bears one frisbee',
#  'pair orange white vans steps upon underside skateboard',
#  'dog frisbe mouth walking water',
#  'man skateboard performing trick',
#  'plate food cut pair scissors',
#  'stack suitcases brown table next wall',
#  'dog frisbee mouth person trying take',
#  'black puppy chewing blue sheet',
#  'five kids playing frisbees sunny day',
#  'two giraffes eating top trees together',
#  'home kitchen showing desk area refrigerator',
#  'wood bathroom white porcelain fixtures dark wood accents',
#  'person taking jump snowy peak snowboard',
#  'many bunches bananas table',
#  'three zebras standing together drink water',
#  'kitchen counter glass sitting saucer',
#  'parking meter word fail written',
#  'sign reading factory trained technicians glass wall',
#  'blurry skateboarder foreground catches air looks like rail yard',
#  'two passenger jets sit wait airport',
#  'hotel room made next guest',
#  'two zebras walking around pen zoo',
#  'african american man flies kite field',
#  'large building corner city street',
#  'tennis player white shirt holding racket green court',
#  'yellow fire hydrant green piece grass next road',
#  'two people standing next holding snowboards',
#  'two men riding respective elephants',
#  'two trains parked tracks next platforms',
#  'cell phone placed top keyboard',
#  'man wetsuit holding surfboard dirt path',
#  'sandwich sits plate dipping bowl next cup',
#  'box filled cakes next boxes cakes',
#  'phone mounted apparatus next desk',
#  'people standing dock waiting board boat',
#  'red bus sitting front building',
#  'kitchen black appliances beautiful wood cabinets',
#  'car highway following signs france',
#  'simple office red chair wooden table',
#  'group people motorcycles street',
#  'room wit ha chair bed multiple windows',
#  'man cuts cake wedding',
#  'photo taken behind fence tennis players court',
#  'someone taking slefie large camera large mirror',
#  'group small children playing pebble covered ground',
#  'traffic light misty mountain backdrop',
#  'professional baseball player middle swing',
#  'sheep dog always travel together',
#  'sign hangs road pointing direction cities',
#  'cat looking person lying bed',
#  'boy jumping fire hydrant skateboard',
#  'young woman beach jumps air',
#  'people standing besides bus taking',
#  'frisbee sitting sports bag sitting ground',
#  'dental instruments pinned whiteboard holes',
#  'man ridding surfboard air wave crashes',
#  'person scarf cooking wok',
#  'young person standing middle half pipe',
#  'bathroom toilet sink attached wall',
#  'couple zebras standing behind cows',
#  'stop sign sits front building',
#  'young girl smiles holds piece luggage',
#  'flowers landscaped make design clock',
#  'small blue tray different types food',
#  'elephant inspecting top womans head trunk',
#  'wooden table ripe yellow banana cut',
#  'small herd sheep grazing grassy field',
#  'clean ultra modern kitchen island hood',
#  'frisebeedisc standing along side objets',
#  'white table chairs umbrella',
#  'old apple sitting next spotted banana',
#  'bathroom walk shower next toilet',
#  'crowded city street filled traffic night',
#  'person standing playing nintendo wii',
#  'man woman eating meal watched onlookers',
#  'white red train traveling city',
#  'woman making pizzas inside professional kitchen',
#  'dog gripping skateboard ground',
#  'woman cooking wok wearing scarf',
#  'yellow bananas hanging holder cabinets',
#  'bench looks like round hut',
#  'four bears walk around sun field',
#  'person red top gray cat',
#  'man makes face woman holds phone',
#  'bathroom toilet buttons',
#  'neatly made bed hotel room',
#  'man holding smoking device tents',
#  'toilet soap dispenser',
#  'baseball batter make attempt hit baseball',
#  'traffic stopped road red light',
#  'person sitting bed pants',
#  'two women standing beach holding surfboards',
#  'band wearing suits playing room',
#  'young person holding golf club looking frisbee ground',
#  'person ripped jeans riding skateboard',
#  'individual entering cat dog shop four dogs',
#  'person glasses holding white plate',
#  'web page displayed laptop screen',
#  'two men standing table eating food',
#  'multiple people beach playing kites',
#  'three people smile pose standing together',
#  'plane taking runway',
#  'computer chair umbrella',
#  'older floor light sits deserted abandoned hospital',
#  'three dogs fighting red frisbee',
#  'snowboarder performing trick air',
#  'fruit stand many varieties fruit price signs',
#  'blissful dog laying windscreen car',
#  'small boy feeding elephants fence',
#  'strawberries fruits cream english muffin',
#  'white bowl holding ramen broccoli carrots',
#  'cat laying top tie dyed pillow',
#  'woman seen ocean holding surfboard',
#  'number elephants standing near one another',
#  'woman holding tennis racquet tennis court',
#  'small white black cat sitting front bright red light',
#  'close electric blender counter',
#  'kichen dirty dishes sink',
#  'large white bird flying sandy beach',
#  'skyscraper bright clock lit brightly lit name',
#  'person holding plate strawberry cake',
#  'man riding skis top snow covered slope',
#  'giraffe running open barren desert',
#  'tell plantains unripe bananas',
#  'two cups sitting front mirror',
#  'man sitting table front laptop computer',
#  'athlete snow board performing city street',
#  'l shaped desk fits well window space',
#  'kid bike several smiling onlookers tent',
#  'ball player running reach goal',
#  'white bag contents sitting top bed',
#  'two boys playing soccer girl watching',
#  'helmeted baseball player swinging bat',
#  'skinny cat looking side ledge next bottles',
#  'couple men field playing baseball',
#  'girl bakery pointing donut display',
#  'skier orange jacket takes air small jump',
#  'train train track near building',
#  'bathroom four urinals together stainless steel wall',
#  'man kneeling top tennis court racquet',
#  'two young men holding nintendo wii controllers standing next',
#  'black white dog sheep',
#  'hot dog toppings piece foil',
#  'person riding bike street cross path',
#  'little girl stamp hand stands beside fire hydrant',
#  'men trying play game frisbee grassy field park',
#  'water slowly flowing fire hydrant',
#  'two people motorcycle head line making turn',
#  'nut cup coffee table',
#  'little boy snow boarding snow self',
#  'two horses one brown one gray stand behind fence field trees behind',
#  'warning sign busy street near large three story building',
#  'image kitchen setting ceramic backsplash',
#  'parking meter graffiti',
#  'young man plays frisbee park',
#  'person red jacket snowboarding slope',
#  'man holds cell phone striped cross walk',
#  'cat laying couch',
#  'woman tying shoe bench',
#  'beautiful young girl riding skateboard sidewalk',
#  'small bird perched top tree branch',
#  'black white cat ball next',
#  'thin crust pizza next wrapped knife fork plate',
#  'ceresota building intersection nd st th av minneapolis',
#  'two people wearing snowboards sitting snowy slope',
#  'open living room large window front forrest',
#  'two small birds perched two tree branches',
#  'person chairs black cellphone',
#  'three mature men wearing suit tie sitting table',
#  'two sheep poking heads white cement wall',
#  'group boys playing kites field',
#  'man two small children luggage cart filled luggage',
#  'city street blue white informational sign set flower garden',
#  'lot people snow horses cats',
#  'two soldiers slicing cake knife',
#  'living room photos carvings knick knacks television',
#  'couple dogs playing frizbee',
#  'woman walking next snowboard ski covered slope',
#  'person fixing window kitchen',
#  'white red aircraft sitting grass',
#  'large black bear trekking grass covered field',
#  'airplanes lineup airport ready go next flight',
#  'large kitchen metallic refrigerator freezer next microwave',
#  'man suit tie umbrella rain',
#  'person trying get falling skiing',
#  'serving boxes full fresh vegetablesrice meats',
#  'several umbrella covered areas placed field',
#  'small plate holds pieces assorted fruits',
#  'man leans inside refrigerator door examines contents',
#  'group men green field playing frisbee',
#  'doubledecker bus people sitting inside',
#  'man riding snowboard side rail',
#  'suitcases sitting next chair',
#  'display case many different kinds donuts',
#  'pitcher throw baseball baseball diamond',
#  'black cat turning away large computer screen',
#  'woman taking selfie bathroom using regular camera',
#  'two zebras walking together across barren savanah',
#  'glazed donut displayed next open styrofoam cup table circular patterns',
#  'woman approaching kiosk selling wood ties',
#  'two skiers traveling snowy mountain',
#  'two cold glasses chardonnay wicker table',
#  'group three different mobile phones one showing time',
#  'elephant stands amidst trees white eating leaves held trunk',
#  'view anime character eating slice pizza',
#  'cell phone showing date time display screen',
#  'baseball player standing home base bat',
#  'red double decker bus driving past building',
#  'man green hat glasses oregon state tshirt blue jeans sits closed toilet',
#  'person umbrella city street',
#  'one long hot dog bun order onion rings tall drink await hungry diner',
#  'man suit plaza holding blue umbrella rain',
#  'well designed entertainment area tv set play video game',
#  'business sign attached wooden post',
#  'skier going slop snow',
#  'woman wearing military uniform injecting cow',
#  'young boy rinding skateboard ledge',
#  'baseball player swinging bat top field',
#  'clock two archways castle',
#  'man sitting behind counter preparing food',
#  'person jumps snow hill skis',
#  'four small loaves bread baking inside oven',
#  'big sign leaning middle bare field',
#  'striped cat lays top striped blanket',
#  'close knife orange desk',
#  'multiple electronic items pile cords tangled',
#  'elephant sandy ring entertaining entertaining zoo guests',
#  'cooked pizza olives onions peppers pizza stone',
#  'tooth brush pair pliers sit together table',
#  'number large air planes run way',
#  'several cows grazing fenced area',
#  'bed lamps night stands clock phone',
#  'shepherd dog walks puddle horse grazes background',
#  'black white photo teddy bears counter next photos',
#  'street signs shown front public market fish market',
#  'couple men hot rod motorcycles parked lot',
#  'hands move among hot dog foods counter',
#  'plate food including meat carrots dipping sauce',
#  'empty cup coffee next laptop open book cafe',
#  'two people snowboards feet knees snow',
#  'airplane landing strip',
#  'tractor trailer truck loaded cargo',
#  'large brick building sitting behind tree',
#  'desk corner window',
#  'holder toothbrushes toothpaste makeup earrings',
#  'person ridding elephant road jungle',
#  'vase filled flowers greens shelf',
#  'green traffic light different signs',
#  'two dogs walking rocky beach one carries frisbee',
#  'man canoe dog get deck',
#  'motorcycle moped bus parked street',
#  'gray teddy bear leaning counter next ocean',
#  'brown bear walking lush green forest',
#  'neon sign sitting top building giant clock',
#  'man wearing glasses checks camera street',
#  'brown bear laying rock trees',
#  'steamboat travels along river large green hills side',
#  'truck drives street bunch bananas back',
#  'person surfs wave blue ocean near green cliffs',
#  'closeup picture pizza salad wooden',
#  'contemporary living room features leather furniture oak storage garden view',
#  'professional ball team fans stands mastercard sponsor',
#  'golden statue top clock tower next american flag',
#  'pizza sitting plate dining table',
#  'bed brown head board orange cover bed',
#  'close jet flying air',
#  'skateboarder performing aerial manuever competition',
#  'adult child horseback heading towards three cows barren land',
#  'several people playing frisbee suburban park',
#  'kid wearing backpack rides bike near beach',
#  'girafee running open field',
#  'championship series minor league baseball league',
#  'laptop drink doughnut next',
#  'sandwich fries plate',
#  'man flying air halfpipe skateboard',
#  'toothbrush laying white sink',
#  'baseball player standing next home plate',
#  'white car chrome rims parked next older lady',
#  'man snow mobile watching skier',
#  'man holding package brand new toothbrush',
#  'airport red white airplanes wait',
#  'boy jumping bench skateboard',
#  'woman rides horse drawn carriage',
#  'two giraffes trees grass one sitting',
#  'black dog asleep next person reading book',
#  'kitchen white appliances tile flooring',
#  'small dog playing tug war owner',
#  'long knife leftover cake platter',
#  'bathroom clean ready us use',
#  'bathroom scene cat bathtub',
#  'stop sign graffiti reads capitalism',
#  'man holding child high water',
#  'lobster roll side sauce plate',
#  'parking area various buses vehicles parked bumper bumper together building background',
#  'many different foods tis fridge',
#  'bunch giraffes standing around grassy field',
#  'many young children kick around ball grass',
#  'two people riding parasols background man riding jet ski holding rope',
#  'man dog yellow kayak',
#  'two pizzas served restaurant water',
#  'fruits blend carton icecream next',
#  'towel rack hangs wall two mirrors',
#  'american airlines airplane parked tarmac',
#  'women cheerleader outfits carrying umbrellas walk city street',
#  'two computers phone books paper office desk',
#  'sign blue showing direction besides road',
#  'bird long neck sitting pole water',
#  'women lying underwear bed',
#  'man leaping skateboard tricks city',
#  'dog water frisbee',
#  'street sign sitting corner city block',
#  'man catching frisbee leg',
#  'boat dock harbor number boats tied dock',
#  'man standing next red silver fire hydrant',
#  'kite pirate symbol hanging pole beach',
#  'group people skies going snowy slope',
#  'city bus drives dark city road',
#  'two tan dogs sitting fancy tiled bench',
#  'little kids play game soccer field',
#  'small train sitting empty train track kids ride',
#  'pretty giraffes standing big building',
#  'man ski board next mountain',
#  'plate food including bread egg',
#  'large white bed red room',
#  'man riding surf board ocean flying kite',
#  'orange glass vase blue flowers table',
#  'number umbrellas sprinklers top',
#  'vase sitting table',
#  'street sign attached traffic light pole intersection',
#  'two surfers dusk taking surfboards ride',
#  'three people uniform cutting cake table',
#  'large trains pulled train station',
#  'skier red white jacket jumped midair',
#  'large stone tower clock top',
#  'person skis going hill trees background',
#  'sweet treats sitting display front store',
#  'close picture vase flowers vase',
#  'man woman texting cell phones',
#  'woman holding tennis racquet tennis court',
#  'home office two computers bookcase',
#  'group men cutting celebratory cake',
#  'clock ornaments sitting top fireplace mantle',
#  'group people standing park playing frisbee',
#  'messy kitchen dirty dishes white cabinets',
#  'small hand held television set held hand',
#  'clock tower side brick building window near',
#  'man standing family room game controller hand',
#  'group people dressed zombies stand park',
#  'train crowded people stopping train station',
#  'man black hovers skateboard air',
#  'multiple baskets recently picked grapefruits display',
#  'large passenger plane runway',
#  'pink bear sitting limb tree',
#  'man playing tennis fenced tennis court',
#  'person jumping bridge city',
#  'flower arrangement sitting black vase',
#  'man stands next bike marina',
#  'bed room wooden floor much else room',
#  'man baseball uniform winding throw ball',
#  'group women play wii game others watch',
#  'boat tied wooden dock',
#  'partial close computer keyboard electronics',
#  'bright building near regular brick building',
#  'zebra cows open grass plain',
#  'white bed topped lots pillows',
#  'seems little girls room baby dolls shelf',
#  'person jumping snoe board air',
#  'zebra standing top pile dirt rocks',
#  'dog sitting passenger seat vehicle',
#  'group people pizza boxes',
#  'young boy young girl playing catch beach',
#  'hipster holding computer mouse eye kneeling keyboard',
#  'children playing football game ground',
#  'man glasses wearing pink shirt tie',
#  'four dogs following man store',
#  'man helmet skateboarding walkway',
#  'surfer riding wave ocean',
#  'day lays head near persons hand holding book',
#  'cat sits window sill behind blinds',
#  'two cars stopped red light transit buses background',
#  'two adults young elephant standing near wooden post',
#  'white polar bear sitting large rocks',
#  'family prepares water ski one man takes across water',
#  'surfer surf board midst wave',
#  'pair red scissors sitting top piece paper',
#  'computers calendars set office desk',
#  'white blue boat floating top water',
#  'white male front small plane smiling',
#  'two little girls holding umbrellas stage',
#  'black white cat sitting next baseball glove baseball',
#  'skier trick air',
#  'traffic light located near overpass',
#  'airplane sitting runway passengers get',
#  'snow boarder air tricks bridge',
#  'several pans pizzas different toppings',
#  'theres laptop glasses pen notebook booklet',
#  'girl sticking leg sitting childs beach chair',
#  'unhappy females sitting table large pizza',
#  'man eating banana wearing helmet',
#  'image food items top stove',
#  'man throwing tennis ball others watching game',
#  'fountain two sculptures surfers',
#  'elephant forrest type area standing',
#  'pitiful looking dandelion antique looking vase',
#  'orange rusted train car connected train',
#  'blue ice cream truck people lined ice cream',
#  'person riding wave ocean wet suit',
#  'bathroom wooden walls wooden floors',
#  'tennis player waits ball served',
#  'family camp site flying kite',
#  'old ice cream truck parked open business sunny day',
#  'guy dressed suite sitting toilet phone',
#  'signs clearly visible us see',
#  'silver park bench sits concrete grass behind',
#  'plate contains pizza many toppings',
#  'multiple black white sheep graze open field',
#  'bathroom antique clawfoot tub pull chain',
#  'airplane flying clear skies',
#  'three girls walking street night',
#  'cat laying couch',
#  'large jetliner airplane sitting next another airplane runway',
#  'four men playing frisbee basketball indoor court',
#  'someone patting head large stuffed teddy bear',
#  'old guy kitchen reaching refrigerator',
#  'group adults four women playing video game using controllers',
#  'person surfboard water',
#  'man throwing tennis ball serve',
#  'snowboarder flies air mountain landscape',
#  'young man playing frisbee people watch',
#  'wooden crate holding bananas roof area',
#  'bus driving busy road',
#  'large group enjoying park beneath cloudy sky',
#  'hull boat producing wake',
#  'man mask holding sign',
#  'man snow baord standing',
#  'woman playing frisbee grass',
#  'man sitting table burrito cup coffee front',
#  'water buffalo calf beach near crowd people',
#  'man pointing woman smiling takes picture phone',
#  'young man riding skateboard black ramp',
#  'person riding hill skis',
#  'giraffe head extended two along fence eating food trough',
#  'three men cutting cake together',
#  'woman walking subway compartment people',
#  'bikes arranged bike lock',
#  'tiled shower molded plastic bathtub shelf mirror wooden vanity lamp sink make beige colored bathroom',
#  'black bear sitting high tree',
#  'hot dog tin foil mustard onions toppings',
#  'kitchen withe counter tops white appliences',
#  'man ocean surfboard riding wave crashing behind',
#  'man standing darkened room next flowers',
#  'photograph washington dc night time',
#  'persons legs dark colored cat rubbing legs shoes',
#  'clock also store sign',
#  'piece pizza sitting top white plate',
#  'bird sitting bench grass',
#  'green white street sign traffic light',
#  'graphic promoting nanowrimo event authors nationwide participate',
#  'metal park bench cement slab',
#  'person skateboard trick',
#  'women holding tennis racket trying hit tennis ball',
#  'view flock sheep grazing field',
#  'people walking street together sharing stars stripes umbrella',
#  'two people eating table many people watching',
#  'hotel room two beds basket fruit',
#  'close apple banana',
#  'plastic fork top lid sitting bench',
#  'man cell phone car street',
#  'person red sweatshirt motorcycle',
#  'dog sits looks window',
#  'school bus stopped side road',
#  'stack luggage chair table',
#  'pizza cooked prepared ready eat',
#  'man surf board sprays water air trick',
#  'three women walk sidewalk near bike parking meter',
#  'boy sits chair reaching plate food lap',
#  'person hand pressing buttons nintendo wii controller',
#  'man holding hotdog front kitchen',
#  'muddy elephant large tusks natural habitat',
#  'woman tennis court spectators looking toward opposite court',
#  'hot dog bun mustard served plate',
#  'large ship land next large body water',
#  'airplane flying sky snow',
#  'coleslaw dresses pulled pork sandwich fries',
#  'goat standing next tree open',
#  'shelf holds clock candle vase shells cat figure',
#  'skier jumping air without skis',
#  'white toilet small bathroom',
#  'person walking store four dogs close behind',
#  'intersection lights queen st bay st',
#  'image man playing wii',
#  'small child swinging bat baseball field',
#  'brown horse flowing blond hair standing top field',
#  'stop light blue sign p',
#  'man trench coat hat carrying umbrella pointing shirt collar another man',
#  'man trick snowboard',
#  'black cow rests grass cows grazing distance',
#  'butterfly sitting orange slice blue bowl',
#  'man purple shirt opening box pizza',
#  'room wooden bookcase shelves holding two small objects television laptop open website',
#  'several people zombie makeup two look phone',
#  'person going snowy hill snowboard',
#  'giraffe runs across plain nothing else sight',
#  'teddy bear posed seated position',
#  'sailboat water two persons aboard',
#  'man petting dog street cyclists',
#  'green lizard eating brussel sprout',
#  'man helmet eating banana',
#  'person motorcycle parked near building',
#  'white bear laying top stony ground covered filth',
#  'man skiing top snowcapped slope',
#  'bathroom power tools construction',
#  'group business people smiling standing together',
#  'umbrella sitting front fence',
#  'airplane fliyng near mountain wheels land',
#  'man riding bike across cross walk',
#  'living room tv couch dresser',
#  'baby holds cell phone sleeping',
#  'tall stone structure compass clock steeple',
#  'skier wears emblem usa performing maneuvers',
#  'white toilet sitting next bathroom sink',
#  'little league baseball team field preparing play',
#  'bowl full apples sitting next vase mirror',
#  'woman holding tennis racket game',
#  'cold snowy pasture containing numerous sheep',
#  'public transportation bus parked curb',
#  'large fighter jet plane flying sky',
#  'person skateboard air trick',
#  'woman preparing ball tennis',
#  'white terrier dog leash brown spot eye',
#  'two trains rail lines near subway',
#  'young child field grass holding baseball bat',
#  'white toilet small room',
#  'young girl swings tennis racket court',
#  'street sidewalk lined cars people street sign foreground',
#  'windsurfer gliding along water surface way ocean',
#  'woman posing behind several bunches bananas',
#  'man standing dirty grass field next lake',
#  'man walking across street umbrella',
#  'man standing grass tennis court holding tennis racket hand',
#  'tired brown dog resting floor',
#  'two surfing statues glide across water city',
#  'yellow cup containing blue yellow tooth brushes',
#  'open window overlooking city bedroom',
#  'half eaten pizza muffin sitting plate others untouched',
#  'lizard eating half brussel sprout',
#  'single broccoli floret larger garden',
#  'plates display cabinetry work modern kitchen',
#  'person jumping catch frisbee',
#  'large bridge filled heavy traffic next large city',
#  'man sitting bench next building',
#  'entrees made meat broccoli sits upon plate',
#  'three yellow plates birds painted',
#  'bright yellow boat parked dock',
#  'road sign warning resident permit parking',
#  'food drink sitting table',
#  'dish potatoes steak broccoli',
#  'lady trying pull skiing trick winter',
#  'person sitting table meal front',
#  'proudly witnessing ollie progression',
#  'dog laying grass frisbee',
#  'pole clock winter',
#  'cup coffee sitting next bunch ripe bananas',
#  'group people walk middle street',
#  'empty aqua bathroom toilet sink mirror outside window',
#  'old complex clock built side building',
#  'side delivery truck picture people chefs outfits',
#  'surfer board shorts walking ocean',
#  'man holding nintendo wii controller front tv',
#  'duck walking across dry grass covered field',
#  'metallic bench path park',
#  'blocked street ready event happen',
#  'two dogs sitting back seat car looking windwo',
#  'two children laying bed together girl holding one finger',
#  'young man throwing red frisbee friend',
#  'big plane sits parked air port',
#  'gladiator movie dvd sits top computer case',
#  'zebras standing dirt pond water behind',
#  'man sitting behind counter selling food',
#  'woman cooks large black skillet',
#  'fighter jet plane ascending sky',
#  'bathroom toilet sink shower',
#  'man tennis court holding racquet',
#  'small pizza next bottle wine',
#  'skateboard hobbyist wheelie sidewalk',
#  'derelict billboard rural field next pine forest',
#  'large neon sign sitting next green traffic sign',
#  'stuffed toys sit next garbage bin',
#  'glazed donuts chocolate frosting sprinkles',
#  'cat lays concrete looks underneath object',
#  'mouse keyboard depicted blurry dimly lit photo',
#  'shower white toilet small bathroom',
#  'three people hugging smiling drinking wine',
#  'street empty traffic light red',
#  'cars approaching intersection',
#  'bunches bananas hanging wooden poles',
#  'hair horse mane long',
#  'cowboy hat saddle horse',
#  'person holding rainbow colored umbrella words written',
#  'large brown dog laying top floor',
#  'man smiling sitting horse',
#  'two men listen another man speaks',
#  'woman opens suitcase hotel room',
#  'dog baseball field bringing bat back dugout',
#  'city bus driving past group men riding skateboards',
#  'boy looking cellphone bathroom',
#  'man woman sitting bench watching toddle play tennis racket',
#  'zebra small antelope graze near trees',
#  'blackandwhite photo young man brushing teeth',
#  'striped cat eating food bowl',
#  'jet takes runway sunny day',
#  'person standing beach flying kite',
#  'large silver jetliner sitting top runway',
#  'stop sign across street vehicles',
#  'people skiing small slopes',
#  'close pretty zebras close together',
#  'close four mini pizzas plate',
#  'pizza mushrooms eggs olives ham',
#  'kitchen clean counter tops window',
#  'group people sitting couch playing video game',
#  'person snowboard snow',
#  'zebra standing cage',
#  'child holds balloon someone pair scissors pop',
#  'two women grassy field playing frisbee',
#  'surfing instructor teaching man paddle surfboard ocean',
#  'young children playing soccer grass field',
#  'metal park bench sitting slap cement next lush green park',
#  'close open box doughnuts',
#  'different types two wheeled vehicles jumping air flames present',
#  'human converses marvin paranoid laptop',
#  'two zebras standing grass near tree',
#  'people walking across street storm',
#  'large shower glass doors surrounding',
#  'room many vases desk',
#  'table top white brown chairs',
#  'group men market filled fruit',
#  'group people sitting next near window',
#  'two men two children flap one men mixing juice blender',
#  'bathroom large mirror next toilet',
#  'shows innovative apple device keyboard',
#  'living room includes television chair multiple windows',
#  'boat docked wooden dock lake',
#  'people parasailing ocean others enjoy beach',
#  'lake kinds boats',
#  'desk laptop keyboard sticky notes',
#  'two cross country skiers stand snow',
#  'man playing frisbee front car park sign',
#  'close pink flowers glass bottle',
#  'small store coca cola signs front',
#  'yellow green checkered motorcycle parked front store window',
#  'small boy sitting luggage cart',
#  'view living room couch windows mirror',
#  'stove covered boiler full water various plates food',
#  'boy sitting top truck bunch goats',
#  'bed sitting hard wood floor',
#  'woman looks camera picture taken',
#  'big lit clock near set stairs',
#  'zebra cage zoo next walkway',
#  'group boats making way harbor past sydney opera house',
#  'public car park entrance sign arrow',
#  'box donuts one green topping another brown another sprinkles',
#  'authentic midwestern kitchen elements similar pottery studio',
#  'bunch people snow boards big snowy hill',
#  'sandwiches different types sit open table',
#  'many people behind barricade hold four surf boards',
#  'large white museum entrance sign front building',
#  'woman ground feet umbrella',
#  'street sign stickers',
#  'bridge runs across water city',
#  'pair skis next pair ski boots',
#  'fire hydrant across street house',
#  'person tries get cat interested wiimote',
#  'large sign sitting front building',
#  'couple sinks bath room',
#  'woman boy feeding elephant',
#  'man driving motorcycle woman holding cell phone',
#  'close pair scissors next cup canvas',
#  'two sheep walking grass sunny day',
#  'person snowboarding snowy slopes tall mountains background',
#  'helmeted goggled skier leans get around obstacle',
#  'wrought iron bars round window stone building face',
#  'cup coffee fancy white design coffee',
#  'purple plate holding two slices pizza',
#  'bride man talking next cake',
#  'close person holding really old cell phone',
#  'big table filled many assorted food items',
#  'pizza sitting plate table',
#  'motorcyclists tricks ramp',
#  'three sheep standing around field grass',
#  'group people standing near bananas',
#  'three people riding back elephant',
#  'double decker bus parking lot',
#  'bunch bikes sit inside store',
#  'cat lying large pillow',
#  'stuffed toy bears display window setting',
#  'man cutting decorated cake long knife',
#  'blond woman sitting table eating food wearing tshirt says stop staring donuts',
#  'signs directions hanging light post',
#  'bunch children sitting birthday party',
#  'ripe banana atop vinyl phonograph record turn table',
#  'three concrete dividers stacked sitting front trees',
#  'girl bathroom blowdrying hair',
#  'man walking forward road blocked',
#  'horse carriage waits brick street next buildings',
#  'kitchen free standing oven wall oven',
#  'old metal bed dirty linens furnishing abandoned room',
#  'small brown bears large log zoo enclosure',
#  'bus pulls road sidewalk',
#  'large air plane air port run way',
#  'large airplane flying blue sky',
#  'dog field playing frisbee',
#  'red fire hydrant alone field',
#  'living area couch cabinet many windows',
#  'bus driving busy street',
#  'pizza dessert toppings four different ways',
#  'assortment items displayed wooden table dark room',
#  'parrot sitting branch looking',
#  'person stands beach low tide',
#  'girl hit softball game',
#  'dog standing frisbee',
#  'kid red shirt holding plate piece pizza',
#  'large kitchen refrigerator magnets',
#  'man skiing snow resort',
#  'person using cellphone time reads clock',
#  'two children peel bananas picnic table',
#  'jet shoots cloudy sky',
#  'zebra giraffe walking dirt',
#  'man sits table takes drink beverage',
#  'two pug dogs sitting bench beach',
#  'vintage stop sign black white',
#  'photo includes rusty primitive refrigerator wall',
#  'camera person standing snow camera',
#  'dog sitting passenger seat car',
#  'two small white pugs sitting top white wooden bench',
#  'man looks fruit sale card',
#  'plastic fork lid sit wooden bench',
#  'baby zebra rests two zebras graze nearby',
#  'woman cutting birthday cake tray',
#  'public bus transporting people city',
#  'living room glowing brick fireplace',
#  'dog standing empty beach front birds',
#  'chirch littered cars parking lot',
#  'leaned stop sign snowy parking lot',
#  'man wearing glasses holds pan food ovenmits',
#  'group people sitting table bunch lap tops',
#  'man jumping air catching frisbee',
#  'someone lifting slice deep dish pizza',
#  'white toilet hanging side wall',
#  'skateboarder air people watch',
#  'fuzzy picture people walking boy skateboard',
#  'man standing large kitchen looking pot',
#  'image group people walking sidewalk',
#  'white building behind street signs',
#  'small group people standing around small motor bike',
#  'woman holding onto tennis racket plays game',
#  'double decker bus driven road',
#  'kitchen stoves',
#  'cat wearing neck tie laying top pillow',
#  'skiers hanging together snow',
#  'two boys sitting legs chaise posing camera holding reeses frisbee two stuffed animal monkeys behind one wearing hat ears front drapery',
#  'mother sheep calf side brown green hill',
#  'brown horse mask behind fence',
#  'white toilet missing seat old bathroom',
#  'group different types doughnuts box',
#  'green yellow motorcycle parked front stores',
#  'piece meat surrounded broccoli food',
#  'man standing next woman holding smart phone',
#  'lady sitting half shell hut',
#  'wild horse pictured profile mountainous setting',
#  'person jumping air standing skateboard',
#  'skier jumps snow ramp adjacent ski lift',
#  'image group people walking near stop sign',
#  'man woman riding back motorcycle',
#  'baseball player swinging baseball catcher behind hand extended catch ball',
#  'bathroom sink tile design vanity',
#  'man woman looking cell phones',
#  'dog looks frisbee',
#  'sink island large kitchen',
#  'skier emmersed flying snow trying straighten',
#  'fans watch baseball player steps plate',
#  'horse looking fence shield face',
#  'sheep standing next stone wall front tree',
#  'man putting hot dog bun table',
#  'wooden bench cushions beside built bookcase',
#  'man suit tie holding violin bow',
#  'two ladies sitting huge pizza table',
#  'people street cars moving',
#  'older man baseball cap sitting stands baseball stadium',
#  'person wearing mask holds sign',
#  'scenic view grassland mountains background',
#  'fancy bathroom stand shower',
#  'elephant raises trunk interact crowd',
#  'lone fire hydrant middle grassy field',
#  'two men riding ski lift snow covered mountain',
#  'man holding surfboard watching woman surfboard',
#  'toilet made metal sits next window',
#  'collection vintage motorcycles sitting display museum',
#  'bedroom two beds basket fruit',
#  'baseball player waiting turn catch ball',
#  'group basket ball players action court',
#  'stuffed animal shown glasses',
#  'dog laying dirty bathroom floor',
#  'woman jeans jacket horse riding large green field',
#  'man sitting chair working laptop',
#  'man brown jacket cowboy hat carries youngster muddy water',
#  'old man scratching head baseball game',
#  'man standing field leaves holding frisbee',
#  'two dogs car looking window',
#  'sign pole city street',
#  'group people standing runway holding umbrellas',
#  'fire truck city street',
#  'baseball player holding baseball bat standing home plate',
#  'kite skull flying air beach',
#  'piece bread whipped cream sauce',
#  'toilet bathroom suspended air',
#  'home living room brown walls white trim fireplace tan furnishings',
#  'people costume using cell phone near one another',
#  'people sheep judging contest looking sheep',
#  'bed several pillows room',
#  'bike shop inside many prospective buyers also',
#  'gray cat sits edge basket',
#  'herd horses standing top sandy beach',
#  'four donuts box variety frostings',
#  'skateboarder jumps bowl trick',
#  'man air skateboard',
#  'white room cloths hanging flowers',
#  'two giraffes sitting front tree together',
#  'mission style bed dressed bright white sheets striped folded quilt sitting two matching nightstands lamps',
#  'man standing sideways surf board',
#  'sexy young lady holding tennis ball tennis racquet',
#  'bento box broccoli tomatoes blackberries carrots edamame rice smiley face',
#  'man standing next baby elephant city',
#  'five people smile pose going trip',
#  'image red fire hydrant grass',
#  'white bedroom bed brown chair white drawers',
#  'dog laying green grass next frisbee',
#  'people celebrating water boat parade',
#  'four skateboarders stand top ramp boards ready skate',
#  'woman riding skis snow covered slope',
#  'old locomotive rail line next trees',
#  'man posing mouse keyboard',
#  'stop sign middle road',
#  'woman holding open scissors front face',
#  'red black white airplane parked grass field',
#  'produce market filled fresh fruits vegetables',
#  'three people stand two large adult sheep',
#  'bedroom scene focus made bed',
#  'small train engine pulling freight car',
#  'metal counter topped lots cheesy pizzas',
#  'large dog sitting top roof',
#  'snowboarder wearing red jacket heading slope',
#  'street scene couple taxis lined',
#  'small cat peeking head blanket',
#  'several people walking ramp toward boat',
#  'couple cars traffic light sign saying keep moving',
#  'man standing grass',
#  'little girl putting tie school uniform',
#  'man holding baseball bat front crowd',
#  'image hotel room',
#  'drawing man riding wave surfboard',
#  'person sitting snow snowboard',
#  'black white room black white objects',
#  ...]

# %% [markdown]
# ## Processing LAION

# %%
path_dir_laion = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/LAION/dataset/laion/laion400m-meta/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        path_dir_laion.append(os.path.join(dirname, filename))

# %%
def collect_laion_data(path):
    df_laion = pd.read_parquet(path)
    N_laion = len(df_laion)  # number of samples from one parquet of laion 
    small_laion = df_laion.sample(n=N_laion)

    laion_texts_array = small_laion["TEXT"].iloc[0:N_laion].values
    return laion_texts_array.tolist()

# %%
## cal feature info 
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())
import time
start_time = time.time()

common_lst = []
for i in range(len(path_dir_laion)):
    laion_texts = collect_laion_data(path_dir_laion[i])
    
    laion_text_re = []
    for val in laion_texts:
        if val != None :
            laion_text_re.append(val)

    p = Pool(processes=16)
    laion_text_processed = p.map(text_preprocessing, [laion_text_re[i] for i in range(len(laion_text_re))])
    p.close()    
    common = set(laion_text_processed).intersection(set(processed_MSCOCO)) 
    print(f"length of common set {len(common)}")
    print("--- %s seconds ---" % (time.time() - start_time))
    common_lst.append(common)
# Out:
# Number of cpu :  256
# length of common set 242
# --- 845.5874762535095 seconds ---
# length of common set 248
# --- 1715.2872474193573 seconds ---
# length of common set 220
# --- 2575.1364512443542 seconds ---
# length of common set 253
# --- 3455.853912830353 seconds ---
# length of common set 261
# --- 4331.457944869995 seconds ---
# length of common set 235
# --- 5181.130166769028 seconds ---
# length of common set 251
# --- 6033.268998146057 seconds ---
# length of common set 232
# --- 7020.787367343903 seconds ---
# length of common set 247
# --- 8223.802123308182 seconds ---
# length of common set 253
# --- 9301.142758131027 seconds ---
# length of common set 253
# --- 10168.278317451477 seconds ---
# length of common set 239
# --- 11032.144304990768 seconds ---
# length of common set 230
# --- 11901.713087320328 seconds ---
# length of common set 253
# --- 12756.369405031204 seconds ---
# length of common set 254
# --- 13542.899965524673 seconds ---
# length of common set 235
# --- 14354.327021598816 seconds ---
# length of common set 265
# --- 15165.943694591522 seconds ---
# length of common set 224
# --- 15940.311333417892 seconds ---
# length of common set 228
# --- 16661.586414813995 seconds ---
# length of common set 247
# --- 17390.56363749504 seconds ---
# length of common set 246
# --- 18147.197790145874 seconds ---
# length of common set 229
# --- 18891.185206890106 seconds ---
# length of common set 234
# --- 19633.766505002975 seconds ---
# length of common set 234
# --- 20367.16618657112 seconds ---
# length of common set 248
# --- 21097.808542251587 seconds ---
# length of common set 220
# --- 21848.716757774353 seconds ---
# length of common set 248
# --- 22631.665870189667 seconds ---

# %%
common_lst_re = []
for common_ in common_lst:
    common_lst_re.extend(common_)

# %%
np.save('./MSCOCO_LAION_commonset.npy',common_lst_re)
np.save('./MSCOCO_LAION_unqiue_commonset.npy',np.unique(np.array(common_lst_re)))

# %% [markdown]
# # LAION vs SBU Captions

# %% [markdown]
# ## Processing SBU Captions

# %%
path_dir = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/Open_clip_training/src/data/sbucaptions/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        if filename.split('.')[-1] == 'parquet':
            path_dir.append(os.path.join(dirname, filename))

# %%
def collect_sbu_data(path):
    df_sbu = pd.read_parquet(path)
    N_sub = len(df_sbu)  # number of samples from one parquet of laion 
    small_sbu = df_sbu.sample(n=N_sub)

    sbu_texts_array = small_sbu["caption"].iloc[0:N_sub].values
    return sbu_texts_array.tolist()

# %%
## cal feature info 
import time
start_time = time.time()

processed_SBU_text = []
for i in range(len(path_dir)):
    sbu_texts = collect_sbu_data(path_dir[i])
    
    sbu_texts_re = []
    for val in sbu_texts:
        if val != None :
            sbu_texts_re.append(val)
    processed_SBU_text.extend(sbu_texts_re)
print("--- %s seconds ---" % (time.time() - start_time))

print(f" the length of processed data is ============================ {len(processed_SBU_text)}")

# %%
# %%time
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())

p = Pool(processes=16)
processed_SBU = p.map(text_preprocessing, [processed_SBU_text[i] for i in range(len(processed_SBU_text))])
p.close()

print(f" the length of text processed data is ============================ {len(processed_SBU)}")

# %% [markdown]
# ## Processing LAION

# %%
path_dir_laion = []
for dirname, _, filenames in os.walk('/home/myeongseob/clip-privacy/LAION/dataset/laion/laion400m-meta/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        path_dir_laion.append(os.path.join(dirname, filename))

# %%
def collect_laion_data(path):
    df_laion = pd.read_parquet(path)
    N_laion = len(df_laion)  # number of samples from one parquet of laion 
    small_laion = df_laion.sample(n=N_laion)

    laion_texts_array = small_laion["TEXT"].iloc[0:N_laion].values
    return laion_texts_array.tolist()

# %%
## cal feature info 
import multiprocessing
from multiprocessing import Pool
print("Number of cpu : ", multiprocessing.cpu_count())
import time
start_time = time.time()

common_lst = []
for i in range(len(path_dir_laion)):
    laion_texts = collect_laion_data(path_dir_laion[i])
    
    laion_text_re = []
    for val in laion_texts:
        if val != None :
            laion_text_re.append(val)

    p = Pool(processes=16)
    laion_text_processed = p.map(text_preprocessing, [laion_text_re[i] for i in range(len(laion_text_re))])
    p.close()    
    common = set(laion_text_processed).intersection(set(processed_SBU)) 
    print(f"length of common set {len(common)}")
    print("--- %s seconds ---" % (time.time() - start_time))
    common_lst.append(common)

# %%
common_lst_re = []
for common_ in common_lst:
    common_lst_re.extend(common_)

# %%
np.save('./SBU_LAION_commonset.npy',common_lst_re)
np.save('./SBU_LAION_unqiue_commonset.npy',np.unique(np.array(common_lst_re)))
